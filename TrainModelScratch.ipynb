# %%
import numpy as np
import pandas as pd
import dataframe_image as dfi
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %% [markdown]
# <h1>Read Datasets<h1>

# %%
df = pd.read_excel('Datasets_Final.xlsx')

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4140 non-null   int64
#  1   text_emoji  4140 non-null   object
#  2   Sarcasm     4140 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 97.2+ KB
#    Unnamed: 0                                         text_emoji  Sarcasm
# 0           0  mencemooh putus asa marah sejenis menekankan s...  Positif
# 1           1   jagat jagat mengenal tuhan mengenal mengenal m 😨  Positif
# 2           2  mbah nun s b yudhoyono j k kubu negarawan poli...  Positif
# 3           3  mbah nun banci komunis sengkuni sembunyi akun ...  Positif
# 4           4  mbah nun berlagak sandiwara silakan baca foto ...  Negatif

# %%
# Remove unused column/feature
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#                                           text_emoji  Sarcasm
# 0  mencemooh putus asa marah sejenis menekankan s...  Positif
# 1   jagat jagat mengenal tuhan mengenal mengenal m 😨  Positif
# 2  mbah nun s b yudhoyono j k kubu negarawan poli...  Positif
# 3  mbah nun banci komunis sengkuni sembunyi akun ...  Positif
# 4  mbah nun berlagak sandiwara silakan baca foto ...  Negatif

# %% [markdown]
# <h1>Checking Max Length In Every Record</h1>

# %%
df['token'] = df['text_emoji'].apply(lambda x: x.split())

# %%
df['max_words'] = df['token'].apply(lambda x: len(x))

# %%
df['max_words'].describe()
# Out:
# count    4140.000000
# mean       11.430193
# std         6.560750
# min         1.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        39.000000
# Name: max_words, dtype: float64

# %%
df = df.drop(columns=['token', 'max_words'])

# %%
print(f'Total Duplicated Data: {df.duplicated().sum()}')
# Out:
# Total Duplicated Data: 209

# %%
df.loc[df.duplicated(), :]
# Out:
#                                              text_emoji  Sarcasm
# 79        contoh firaun suka menginjak harkat pribumi 😨  Negatif
# 80        contoh firaun suka menginjak harkat pribumi 😨  Negatif
# 86             opini cak nun kafir haman qorun suroto 😨  Negatif
# 115   andre menilai pernyataan cak nun prabowo subia...  Negatif
# 118   prabowo subianto penyakit basmi prabowo memuji...  Positif
# ...                                                 ...      ...
# 4134  rt pohon kuat guncangan masyaallah sehat anies...  Negatif
# 4135  gue suka anies baswedan pimpin pakai narasi in...  Negatif
# 4136  rt orang bugis mendukung anies baswedan capres...  Negatif
# 4137  contoh kepemimpinan patut contoh tingkat keped...  Negatif
# 4138      anies baswedan gubernur terbaik milik jakarta  Negatif
#
# [209 rows x 2 columns]

# %%
df = df.drop_duplicates(ignore_index = True)

# %%
df.head()
# Out:
#                                           text_emoji  Sarcasm
# 0  mencemooh putus asa marah sejenis menekankan s...  Positif
# 1   jagat jagat mengenal tuhan mengenal mengenal m 😨  Positif
# 2  mbah nun s b yudhoyono j k kubu negarawan poli...  Positif
# 3  mbah nun banci komunis sengkuni sembunyi akun ...  Positif
# 4  mbah nun berlagak sandiwara silakan baca foto ...  Negatif

# %%
print(f'Total Duplicated Data After Handling: {df.duplicated().sum()}')
# Out:
# Total Duplicated Data After Handling: 0

# %%
# df_duplicated = pd.DataFrame(df.loc[df['text_emoji'].duplicated()])

# %%
# df_duplicated.to_excel('Duplicated_Data.xlsx')

# %%
print(f'Total Missing Value: \n{df.isnull().sum()}')
# Out:
# Total Missing Value:
# text_emoji    0
# Sarcasm       0
# dtype: int64

# %% [markdown]
# <h1>Feature Extraction Using GloVe Method</h1>

# %%
class GloVe:
    # constructors
    def __init__(self, corpus, embedding_size, window_size=5):
        self.corpus = corpus
        self.embedding_size = embedding_size
        self.window_size = window_size
        self.word2id = {}
        self.id2word = {}
        self.word2count = {}
        self.vocab_size = 0
        self.co_matrix = None
        self.embedding = None
        self.bias = None

    def build_vocab_information(self):
        for sentence in self.corpus:
            for word in sentence.split():
                if word not in self.word2id:
                    self.word2id[word] = self.vocab_size
                    self.id2word[self.vocab_size] = word
                    self.vocab_size += 1
                self.word2count[word] = self.word2count.get(word, 0) + 1
        print(f'Vocab Size: {self.vocab_size}')

    def build_co_matrix(self):
        self.co_matrix = np.zeros((self.vocab_size, self.vocab_size))
        for sentence in self.corpus:
            sentence = sentence.split()
            for i, center_word in enumerate(sentence):
                for j in range(max(0, i - self.window_size), i):
                    context_word = sentence[j]
                    self.co_matrix[self.word2id[center_word]][self.word2id[context_word]] += 1
                    self.co_matrix[self.word2id[context_word]][self.word2id[center_word]] += 1

    def train(self, num_epochs=300, learning_rate=0.01):
        self.embedding = (np.random.rand(self.vocab_size, self.embedding_size) - 0.5) / self.embedding_size
        self.bias = np.zeros(self.vocab_size)
        count = 0
        for epoch in range(num_epochs):
            count += 1
            loss = 0
            for i in range(self.vocab_size):
                for j in range(self.vocab_size):
                    if self.co_matrix[i][j] != 0:
                        diff = (self.embedding[i] @ self.embedding[j]) + self.bias[i] + self.bias[j] - np.log(self.co_matrix[i][j])
                        
                        loss += diff ** 2
                        
                        grad_emb_i = diff * self.embedding[j]
                        grad_emb_j = diff * self.embedding[i]
                        
                        grad_bias_i = diff
                        grad_bias_j = diff

                        self.embedding[i] -= learning_rate * grad_emb_i
                        self.embedding[j] -= learning_rate * grad_emb_j
                        self.bias[i] -= learning_rate * grad_bias_i
                        self.bias[j] -= learning_rate * grad_bias_j
                        
            print(f'Difference Iterasi {count}: {diff}\n')
            print(f'Loss Iterasi {count}: {loss}\n')
            print(f'Gradient Embedding "i" Iterasi {count}: {grad_emb_i}\n')
            print(f'Gradient Embedding "j" Iterasi {count}: {grad_emb_j}\n')
            print(f'Embedding Iterasi {count}: {self.embedding}')

            print(f'Epoch {epoch + 1}/{num_epochs} - loss {round(loss, 3)}')
            
            if loss <= 0.001:
                print('Training Stopped, loss less than equal 0.001')
                break

    def get_all_embeddings(self):
        all_embeddings = {}
        for word, word_id in self.word2id.items():
            all_embeddings[word] = self.embedding[word_id]
        return all_embeddings
    
    def get_embeddings_by_id(self, id):
        return self.embedding[id]
    
    def get_embeddings(self, kata):
        word_embeddings = {}
        for word, word_id in self.word2id.items():
            if word == kata:
                word_embeddings[word] = self.embedding[word_id]
        return word_embeddings

    def embedding2word(self):
        embedding_to_word = {}
        for word, word_id in self.word2id.items():
            embedding_to_word[tuple(self.embedding[word_id])] = word
        return embedding_to_word
    
    def get_glove_embedding(self, sentence):
        sentence = sentence.split()
        embedding_vectors = []
        for word in sentence:
            if word in self.word2id:
                word_id = self.word2id[word]
                word_embedding = self.embedding[word_id]
                embedding_vectors.append(word_embedding)
        return embedding_vectors
    
    def show_comatrix(self):
        # df_co_matrix = pd.DataFrame(self.co_matrix, index=self.word2id.keys(), columns=self.word2id.keys())
        
        return self.co_matrix
    
    def generate_coomatrix_image(self):
        df_co_matrix = pd.DataFrame(self.co_matrix, index=self.word2id.keys(), columns=self.word2id.keys())

        print('Image is being processed...')
        dfi.export(df_co_matrix.head(10), "coocurrenceMatrixBab3.png", max_cols=10)
        
        return print('Coocurrence matrix has been successfully generated into an image')
    
    def show_word2id(self):
        return self.word2id
    
    def show_id2word(self):
        return self.id2word
    
    def show_word2count(self):
        return self.word2count

# %%
# Membangun model GloVe
embedding_size = 150

glove_model = GloVe(df['text_emoji'], embedding_size)

# Membangun vocabulary
glove_model.build_vocab_information()

# Membangun co-occurrence matrix
glove_model.build_co_matrix()

# Melatih model GloVe
glove_model.train()
# Out:
# Vocab Size: 6769
# Difference Iterasi 1: 0.03420737052534675
#
# Loss Iterasi 1: 47313.632457430314
#
# Gradient Embedding "i" Iterasi 1: [-6.13837338e-05 -3.44128678e-05 -1.08514235e-04  9.91227062e-05
#   1.02488833e-04  3.29198235e-05 -8.24988264e-05  8.72708589e-05
#   4.05245792e-05 -9.96382817e-05  5.76318221e-05  6.72849640e-05
#  -2.10001660e-05 -1.11122000e-04 -9.97018211e-05  9.98236538e-05
#   5.05640845e-05  1.10834417e-04 -4.18988774e-05  8.83702572e-05
#  -1.09601313e-04  1.02393634e-04  6.57099909e-05 -6.57659160e-05
#  -7.61511493e-05 -5.63306468e-05  8.35719143e-05 -5.59238925e-05
#  -7.04504899e-05 -2.19199439e-05 -1.19638570e-04 -7.22541855e-05
#   7.58632520e-05  6.62741921e-05  7.21644489e-05 -8.86431311e-05
#  -3.48778836e-06  3.65122310e-05 -1.17151553e-04 -7.58356756e-05
#   6.01609495e-06 -6.30326224e-05  6.82988042e-05 -3.08753352e-05
#  -5.00185553e-05  3.55862043e-05 -3.58599682e-06  2.87117166e-05
#  -4.16207218e-05 -4.63253820e-05 -5.47994705e-05 -9.00408239e-05
#   4.27822160e-05 -7.68466510e-05 -2.38473857e-05 -8.04553844e-07
#   4.02223577e-05  7.08405615e-05  1.71584508e-05 -3.23287071e-05
#  -7.64961527e-05 -8.80081751e-05 -1.04849032e-04  1.10836396e-04
#   3.00434565e-05 -3.41148504e-05 -3.56607426e-05 -2.93020467e-05
#   1.73537854e-07 -6.37438665e-05 -1.16356216e-04 -9.15246032e-05
#  -6.23536792e-05 -2.01301330e-05  3.48296250e-05 -9.77819216e-05
#  -7.55336309e-05 -5.05504636e-05  6.23523801e-06 -1.17393084e-04
#   1.09827112e-04 -5.74974677e-06  5.70175076e-05 -3.56132185e-05
#   7.73469763e-05  8.88817980e-05  7.45758269e-05  9.54341137e-05
#  -6.92013854e-05  8.37371163e-05  9.73894401e-06 -5.75355102e-05
#  -1.17421009e-04 -7.65678938e-05  6.95200459e-05 -1.29474801e-05
#   9.04462164e-05 -6.00526630e-05 -5.74326511e-05  1.52120687e-05
#  -4.99052603e-05 -4.48010292e-05 -7.13235037e-05  2.78483619e-05
#  -2.21656396e-05 -9.06387710e-05  1.89047419e-06  2.78186182e-06
#  -1.05690998e-04 -8.26974677e-05 -1.11039260e-04  5.81650996e-06
#   2.18676073e-05  1.04385193e-05  2.46114422e-05 -7.71473218e-05
#   2.27745718e-05  5.63910270e-05  2.54968170e-05  8.53250988e-05
#  -5.37153681e-05 -5.12542862e-05  2.82860803e-05 -1.03214896e-04
#   1.12740959e-04  3.48730250e-05  5.82726200e-05  9.90522018e-05
#   8.22693266e-05 -7.17001458e-05  1.07692793e-04 -2.44086921e-05
#   1.04786988e-04  3.26101383e-05 -2.12858454e-05  9.52486811e-05
#  -5.19076695e-05 -8.81444476e-05  1.00016705e-04 -8.16379699e-05
#   1.81777585e-05  1.04038251e-04  1.76281161e-05 -7.77200433e-05
#   2.56045350e-05  1.04396982e-04  6.92530813e-05  2.79460857e-05
#  -3.68357721e-05  8.55738577e-05]
#
# Gradient Embedding "j" Iterasi 1: [-3.81105989e-05  7.64312370e-05 -1.53433833e-05 -2.52339801e-05
#  -4.45056573e-05 -9.83148437e-05 -8.68466889e-05  9.36422583e-05
#  -7.19737708e-05  2.29328396e-05  8.11333750e-05 -4.89784379e-05
#   1.12493770e-04 -5.28855334e-05  7.51330363e-05  7.86190091e-05
#   5.01702568e-05 -4.51670112e-05  5.87450593e-05  1.09604450e-04
#  -7.50529189e-05 -9.42709354e-05 -8.96496469e-05 -7.75424223e-06
#  -5.39353850e-05  1.07766362e-04 -3.16581209e-05 -9.92744707e-05
#  -3.65979280e-05 -7.97287342e-05 -1.07096973e-04  1.06424402e-04
#  -8.10861832e-05 -7.19166256e-05 -1.72590455e-05 -1.27990402e-05
#   1.05179839e-04  8.56466968e-05  1.05458895e-04 -7.95711046e-05
#  -3.29173495e-05 -1.95910891e-05 -6.46321784e-05  1.12124101e-04
#   3.99448698e-05 -7.51450060e-05 -7.57949672e-05 -4.33711381e-05
#   7.79127684e-05  5.54836711e-05 -7.72503031e-05 -2.64940436e-05
#  -6.47350082e-06 -2.03159842e-05 -7.14604043e-06 -5.27785552e-05
#  -4.25151429e-05 -3.06072613e-05 -3.28807100e-06 -4.64465105e-05
#  -4.27965676e-06  6.66069250e-05  1.99659324e-06  7.22699749e-05
#  -9.24610524e-05 -3.26478747e-05 -2.93794619e-05 -4.46829525e-05
#  -4.55574525e-05 -5.88471947e-06 -8.89700810e-05  1.09224446e-04
#   7.57960383e-05 -5.84410479e-05  2.40396465e-05  8.21654192e-05
#   1.27573701e-05  1.09227642e-04 -1.08805003e-04 -3.44431403e-05
#  -4.09335352e-06  7.34423818e-05 -1.07538950e-04 -5.12179970e-06
#  -6.83282906e-06  6.77498678e-05  2.82088387e-05  4.51753251e-05
#   5.79457439e-05 -6.93061016e-05 -1.10681304e-04 -9.53847843e-05
#   1.94363378e-05  8.87182569e-05 -8.53809067e-05  7.53946082e-05
#   1.00169118e-04  9.49126140e-05 -1.53928971e-05 -5.62307847e-05
#   9.17341953e-05  5.85836085e-05 -9.59522400e-05  1.09600949e-04
#  -6.28232297e-06  1.47272587e-05  3.79019401e-05  8.26821327e-05
#  -4.70701325e-05 -3.93890513e-05 -4.84768001e-05 -2.25436422e-05
#   6.72363859e-05 -8.08469139e-05 -5.72331304e-05  4.00545408e-05
#  -2.44649153e-05 -2.74058534e-05  4.04306658e-05 -7.93798520e-06
#   7.02272263e-05  2.70354024e-05  6.08829842e-05  3.30951189e-05
#  -4.01436884e-05  3.01258969e-05  4.11955068e-05  7.10574188e-05
#  -1.51125544e-05  1.04853263e-04 -3.35777699e-05  1.05965295e-04
#  -1.62353190e-05 -6.01643508e-05 -1.13276593e-04  4.11864760e-05
#   2.58197040e-05 -3.13804181e-05 -8.16467288e-05 -1.03677836e-04
#  -2.46127598e-05 -2.37146646e-05 -1.91610213e-05 -7.26334394e-05
#  -1.11324794e-05  8.94711372e-05  2.67630928e-05  3.34814713e-05
#   4.55962028e-05 -2.91092224e-06]
#
# Embedding Iterasi 1: [[-2.38046360e-03  3.39871149e-03 -1.78481920e-04 ... -2.24075281e-03
#    3.26493772e-03 -3.48406578e-03]
#  [-2.06889842e-03 -1.63048906e-03 -2.01963495e-03 ... -4.12309918e-04
#    8.78694243e-04 -1.85558920e-03]
#  [-2.70044880e-03  1.61252667e-03 -4.78127680e-04 ... -1.30489345e-03
#    2.89617111e-03 -6.00833006e-04]
#  ...
#  [-1.38917316e-03  2.22044923e-03  1.57708329e-03 ...  1.91134940e-03
#   -3.16614912e-03 -2.23751234e-03]
#  [ 2.78653595e-04  1.31254708e-03 -2.25974623e-03 ...  6.80691435e-05
#   -2.37752895e-03 -8.85916514e-04]
#  [-1.11349106e-03  2.23469409e-03 -4.47455130e-04 ...  9.78499990e-04
#    1.33330340e-03 -8.59520847e-05]]
# Epoch 1/300 - loss 47313.632
# Difference Iterasi 2: 0.034914222928082536
#
# Loss Iterasi 2: 44016.63479641257
#
# Gradient Embedding "i" Iterasi 2: [-5.63433978e-05 -2.83211240e-05 -1.29547253e-04  9.04232844e-05
#   1.10821196e-04  3.50341448e-05 -9.20792718e-05  9.27499005e-05
#   4.54818031e-05 -1.05925115e-04  6.21878940e-05  7.42975684e-05
#  -1.15128239e-05 -1.16406180e-04 -1.00457865e-04  9.71324410e-05
#   5.49140387e-05  1.16772930e-04 -4.66844905e-05  9.13703346e-05
#  -1.16587697e-04  1.06666286e-04  6.20645899e-05 -6.57765838e-05
#  -8.36961129e-05 -5.48245677e-05  8.28990518e-05 -5.47547002e-05
#  -7.70555107e-05 -2.04065412e-05 -1.34347762e-04 -8.31953811e-05
#   8.65606472e-05  7.41878202e-05  7.26397501e-05 -8.76300714e-05
#   5.33264156e-06  3.66933419e-05 -1.26123820e-04 -8.47502304e-05
#  -8.87312407e-07 -6.29597438e-05  6.59955748e-05 -3.07758713e-05
#  -6.44559601e-05  4.11073292e-05 -5.68817215e-06  3.13765270e-05
#  -3.89087388e-05 -4.93978491e-05 -5.99947668e-05 -9.91021434e-05
#   5.19184355e-05 -7.89626713e-05 -2.44269600e-05  1.55333044e-06
#   4.14957309e-05  8.08612154e-05  1.44885725e-05 -2.68018544e-05
#  -8.24659933e-05 -9.05789525e-05 -1.10572154e-04  1.18758834e-04
#   2.63102911e-05 -3.22972860e-05 -3.62788415e-05 -2.34077614e-05
#   1.05307063e-07 -5.63904521e-05 -1.24183797e-04 -9.45851484e-05
#  -6.64984728e-05 -1.63393858e-05  4.51515096e-05 -9.38413934e-05
#  -8.05674635e-05 -6.48310798e-05  5.37165612e-06 -1.30167383e-04
#   1.12093827e-04 -9.93646922e-06  6.04023405e-05 -3.50011750e-05
#   8.10577940e-05  8.89016114e-05  7.61269757e-05  1.04698648e-04
#  -7.97505905e-05  8.35980462e-05  8.79120834e-06 -5.65964175e-05
#  -1.28697869e-04 -8.85333782e-05  6.51337667e-05 -1.59706005e-05
#   8.86115348e-05 -6.18476420e-05 -4.65318712e-05  1.22359007e-05
#  -6.22381464e-05 -5.25918714e-05 -6.84279947e-05  3.71597267e-05
#  -2.68464247e-05 -9.90631019e-05 -2.91894595e-07  5.34130132e-06
#  -1.02426919e-04 -8.87773128e-05 -1.18765901e-04  1.08716151e-05
#   1.82972617e-05  1.76344219e-05  2.97646901e-05 -8.86081728e-05
#   2.51961719e-05  5.51379822e-05  3.45892046e-05  8.50121752e-05
#  -5.61427995e-05 -5.55691961e-05  2.17594879e-05 -1.11385630e-04
#   1.19578470e-04  3.09030487e-05  5.84570968e-05  9.95740172e-05
#   9.55219960e-05 -6.71765859e-05  1.21745708e-04 -2.65766298e-05
#   1.10661081e-04  2.22013865e-05 -2.72926969e-05  9.51044459e-05
#  -4.08127928e-05 -9.13015928e-05  1.15463219e-04 -7.58171245e-05
#   1.08243536e-05  1.07453341e-04  2.06058400e-05 -7.71452231e-05
#   2.46528137e-05  1.13245933e-04  6.60430509e-05  2.84219339e-05
#  -3.24916410e-05  9.06061398e-05]
#
# Gradient Embedding "j" Iterasi 2: [-3.85369839e-05  7.80810921e-05 -1.58290386e-05 -2.59365086e-05
#  -4.55133011e-05 -1.00161302e-04 -8.87054624e-05  9.51335956e-05
#  -7.32003596e-05  2.34666624e-05  8.28968133e-05 -5.02473390e-05
#   1.14768739e-04 -5.38121201e-05  7.69546524e-05  8.02787005e-05
#   5.11779697e-05 -4.61479140e-05  5.95583785e-05  1.11567912e-04
#  -7.65194172e-05 -9.61950367e-05 -9.17018039e-05 -7.74481504e-06
#  -5.53196195e-05  1.09980251e-04 -3.24280045e-05 -1.01353760e-04
#  -3.78252700e-05 -8.12897900e-05 -1.09556691e-04  1.08832505e-04
#  -8.29767986e-05 -7.32690780e-05 -1.75602805e-05 -1.28666177e-05
#   1.07874152e-04  8.75130517e-05  1.08046301e-04 -8.10248984e-05
#  -3.38896002e-05 -2.02988133e-05 -6.61178005e-05  1.14297697e-04
#   4.09357594e-05 -7.66221576e-05 -7.77137570e-05 -4.41542370e-05
#   7.96699965e-05  5.64298774e-05 -7.86550161e-05 -2.70232563e-05
#  -6.43537626e-06 -2.03669031e-05 -7.42383237e-06 -5.38326978e-05
#  -4.35254545e-05 -3.14728691e-05 -3.46202422e-06 -4.73200754e-05
#  -3.96180879e-06  6.80325937e-05  2.25850131e-06  7.35294988e-05
#  -9.38602109e-05 -3.33076576e-05 -2.97489610e-05 -4.53463423e-05
#  -4.65830560e-05 -5.69428831e-06 -9.05461872e-05  1.11258648e-04
#   7.73781916e-05 -5.99003601e-05  2.49435329e-05  8.35814939e-05
#   1.27970978e-05  1.11753071e-04 -1.11315423e-04 -3.54938534e-05
#  -4.21650212e-06  7.51773717e-05 -1.09250252e-04 -4.54969423e-06
#  -7.20688689e-06  6.94496043e-05  2.88136427e-05  4.61771901e-05
#   5.89283477e-05 -7.05797685e-05 -1.12973581e-04 -9.72765822e-05
#   1.97999552e-05  9.05509706e-05 -8.71976045e-05  7.73604769e-05
#   1.02131999e-04  9.66546017e-05 -1.57676540e-05 -5.70758375e-05
#   9.34778995e-05  5.95173759e-05 -9.81727592e-05  1.12092593e-04
#  -6.50578510e-06  1.54270261e-05  3.92454966e-05  8.47873028e-05
#  -4.78745246e-05 -4.01181868e-05 -4.91293133e-05 -2.29053061e-05
#   6.80329466e-05 -8.23112567e-05 -5.82726375e-05  4.10206799e-05
#  -2.52525958e-05 -2.83553842e-05  4.18440843e-05 -8.21486490e-06
#   7.19421796e-05  2.76398676e-05  6.22676382e-05  3.38540787e-05
#  -4.13954233e-05  3.01984841e-05  4.17716410e-05  7.23256964e-05
#  -1.54171934e-05  1.07161337e-04 -3.37909190e-05  1.08380655e-04
#  -1.64858656e-05 -6.14637966e-05 -1.15293191e-04  4.17808003e-05
#   2.64279243e-05 -3.20736209e-05 -8.34469713e-05 -1.05596424e-04
#  -2.53755238e-05 -2.40635702e-05 -1.98301474e-05 -7.37524816e-05
#  -1.16148220e-05  9.11984232e-05  2.72365384e-05  3.43645226e-05
#   4.69023091e-05 -3.08942317e-06]
#
# Embedding Iterasi 2: [[-2.62560123e-03  3.97675609e-03  5.66586974e-05 ... -2.60829160e-03
#    3.40412649e-03 -3.95138034e-03]
#  [-2.06355988e-03 -1.43147979e-03 -2.68829909e-03 ... -5.35292176e-04
#    7.40677052e-04 -1.77305430e-03]
#  [-2.67316038e-03  1.59407180e-03 -1.77283918e-04 ... -9.76286126e-04
#    3.11236037e-03 -3.36357565e-04]
#  ...
#  [-1.36664361e-03  2.21949044e-03  1.56267887e-03 ...  1.91887918e-03
#   -3.16604317e-03 -2.23590798e-03]
#  [ 2.62510832e-04  1.31424846e-03 -2.25473467e-03 ...  6.77718043e-05
#   -2.37023153e-03 -8.57135925e-04]
#  [-1.10319832e-03  2.23665239e-03 -4.52073878e-04 ...  9.83971472e-04
#    1.34368316e-03 -8.93921541e-05]]
# Epoch 2/300 - loss 44016.635
# Difference Iterasi 3: 0.032737388320654245
#
# Loss Iterasi 3: 43310.457645794435
#
# Gradient Embedding "i" Iterasi 3: [-4.30365705e-05 -1.78248064e-05 -1.50992853e-04  7.36522448e-05
#   1.13233754e-04  3.31363425e-05 -1.00118804e-04  9.06736361e-05
#   4.85983653e-05 -1.04491866e-04  5.79430666e-05  7.72408262e-05
#   4.86304114e-06 -1.12259385e-04 -9.50480981e-05  8.58378327e-05
#   5.10820457e-05  1.16159416e-04 -4.51734095e-05  8.50307702e-05
#  -1.14885071e-04  1.04327709e-04  5.09002046e-05 -6.27874562e-05
#  -9.07402587e-05 -4.22727305e-05  7.26274608e-05 -4.60574558e-05
#  -7.60289111e-05 -2.24382516e-05 -1.42105487e-04 -9.06902026e-05
#   9.20731722e-05  8.09285451e-05  6.53546936e-05 -8.25474321e-05
#   1.71838863e-05  3.47485100e-05 -1.27498236e-04 -9.18046745e-05
#  -8.19907318e-06 -5.17745241e-05  5.79661378e-05 -2.65534385e-05
#  -7.58546073e-05  4.38180028e-05 -5.22518123e-06  3.55026709e-05
#  -3.20670463e-05 -5.02306612e-05 -6.44386029e-05 -1.03320081e-04
#   6.29834224e-05 -7.37994938e-05 -2.40381645e-05  1.30558525e-06
#   3.92478225e-05  8.80759772e-05  9.10108294e-06 -2.14149573e-05
#  -8.25280303e-05 -8.39374724e-05 -1.09777643e-04  1.17541032e-04
#   1.89016650e-05 -2.31380227e-05 -3.70344084e-05 -1.52468928e-05
#   6.36264325e-07 -3.88604165e-05 -1.23862541e-04 -8.63824324e-05
#  -6.64471478e-05 -9.74083129e-06  5.37104016e-05 -8.06210660e-05
#  -7.80535954e-05 -7.66129608e-05  3.21864600e-06 -1.33744549e-04
#   1.04684838e-04 -1.62939099e-05  5.17042511e-05 -3.51609174e-05
#   7.51260210e-05  8.21836455e-05  7.18636380e-05  1.08867255e-04
#  -8.33393974e-05  7.96146559e-05  1.19922598e-05 -5.09105928e-05
#  -1.35071814e-04 -9.33580748e-05  5.22735714e-05 -1.74697106e-05
#   7.80506397e-05 -5.72212022e-05 -3.17975773e-05  5.10158907e-06
#  -7.59613106e-05 -6.06256613e-05 -5.96851867e-05  4.57893770e-05
#  -3.51123550e-05 -1.00326758e-04 -8.63337797e-06  8.50344339e-06
#  -9.06182593e-05 -8.68389069e-05 -1.17825469e-04  2.02249964e-05
#   1.67120615e-05  2.47903865e-05  3.12285404e-05 -9.64537169e-05
#   2.61765061e-05  5.06373381e-05  4.15356274e-05  7.75975290e-05
#  -5.69514019e-05 -5.37306121e-05  8.36210842e-06 -1.14316339e-04
#   1.22898883e-04  2.75385196e-05  5.19269664e-05  8.99697857e-05
#   1.02718286e-04 -5.39474870e-05  1.26262453e-04 -2.55144656e-05
#   1.09978867e-04  7.26131624e-06 -3.43618629e-05  8.75282544e-05
#  -2.29869338e-05 -8.83946880e-05  1.25451820e-04 -5.92863116e-05
#   3.36622957e-06  1.04420988e-04  2.45510314e-05 -7.07305079e-05
#   2.13913895e-05  1.15202980e-04  6.19495158e-05  2.67448223e-05
#  -2.87773834e-05  8.68057792e-05]
#
# Gradient Embedding "j" Iterasi 3: [-3.57492863e-05  7.31932796e-05 -1.47009176e-05 -2.46187922e-05
#  -4.28013070e-05 -9.36883865e-05 -8.30653483e-05  8.86653444e-05
#  -6.84509157e-05  2.19641919e-05  7.80480043e-05 -4.72962530e-05
#   1.07322542e-04 -5.01774548e-05  7.26224504e-05  7.53581152e-05
#   4.81775289e-05 -4.33687431e-05  5.51306460e-05  1.04373324e-04
#  -7.17372416e-05 -9.01966937e-05 -8.62132939e-05 -7.09694002e-06
#  -5.18964277e-05  1.02895754e-04 -3.03792851e-05 -9.52951118e-05
#  -3.60776277e-05 -7.58754519e-05 -1.02803176e-04  1.02263154e-04
#  -7.80563892e-05 -6.88414503e-05 -1.63592463e-05 -1.17868856e-05
#   1.01685961e-04  8.20900511e-05  1.01817116e-04 -7.55741145e-05
#  -3.19730213e-05 -1.95253537e-05 -6.20702501e-05  1.06919083e-04
#   3.84678422e-05 -7.17881716e-05 -7.33451823e-05 -4.15693632e-05
#   7.47838861e-05  5.27934096e-05 -7.32539355e-05 -2.52123395e-05
#  -6.11994221e-06 -1.87745344e-05 -7.10220539e-06 -5.02724114e-05
#  -4.08459219e-05 -2.97919423e-05 -3.38191576e-06 -4.40651478e-05
#  -3.23845994e-06  6.36590786e-05  2.44274076e-06  6.86398687e-05
#  -8.75374067e-05 -3.12226125e-05 -2.74566815e-05 -4.22511266e-05
#  -4.37403051e-05 -5.06570813e-06 -8.44795082e-05  1.03755123e-04
#   7.26449200e-05 -5.64945628e-05  2.36490468e-05  7.79339972e-05
#   1.16558034e-05  1.05067880e-04 -1.04577180e-04 -3.36259393e-05
#  -3.97513025e-06  7.08066375e-05 -1.01490638e-04 -3.31505512e-06
#  -6.75655068e-06  6.54102394e-05  2.71335441e-05  4.32922388e-05
#   5.50037338e-05 -6.61068761e-05 -1.06126134e-04 -9.10190331e-05
#   1.87123608e-05  8.47033558e-05 -8.20152715e-05  7.28275239e-05
#   9.56127945e-05  9.02876461e-05 -1.48192583e-05 -5.32243079e-05
#   8.76079787e-05  5.57036597e-05 -9.22298046e-05  1.05227783e-04
#  -6.12190283e-06  1.47576691e-05  3.76426411e-05  7.98706652e-05
#  -4.47032211e-05 -3.77045875e-05 -4.57758794e-05 -2.14741214e-05
#   6.29664356e-05 -7.69216317e-05 -5.44925866e-05  3.86437055e-05
#  -2.40801383e-05 -2.68811912e-05  3.98456361e-05 -7.88013387e-06
#   6.78752020e-05  2.59898338e-05  5.87975889e-05  3.19315581e-05
#  -3.97041174e-05  2.75714460e-05  3.89747605e-05  6.77746939e-05
#  -1.44490454e-05  1.00733566e-04 -3.09725625e-05  1.01855858e-04
#  -1.52653239e-05 -5.78115508e-05 -1.07754271e-04  3.89792327e-05
#   2.47172297e-05 -3.00769673e-05 -7.83991394e-05 -9.89669785e-05
#  -2.40473041e-05 -2.23234955e-05 -1.90765954e-05 -6.86938446e-05
#  -1.10427427e-05  8.53050108e-05  2.51691364e-05  3.24198892e-05
#   4.46526914e-05 -2.90440217e-06]
#
# Embedding Iterasi 3: [[-2.80901302e-03  4.74714910e-03  5.30904646e-06 ... -3.13547138e-03
#    3.33867591e-03 -4.45528318e-03]
#  [-1.95092125e-03 -1.21106636e-03 -3.43731472e-03 ... -5.92021650e-04
#    7.69120262e-04 -1.58709098e-03]
#  [-2.66550338e-03  1.51662104e-03  6.42096243e-04 ... -5.90365098e-04
#    3.75622805e-03  1.11391131e-04]
#  ...
#  [-1.34225655e-03  2.22015488e-03  1.55653387e-03 ...  1.92441598e-03
#   -3.15286641e-03 -2.23049774e-03]
#  [ 2.47431170e-04  1.31437514e-03 -2.23933631e-03 ...  6.87685466e-05
#   -2.35684697e-03 -8.21972656e-04]
#  [-1.09157141e-03  2.23594852e-03 -4.47545977e-04 ...  9.90034186e-04
#    1.36425398e-03 -8.95862581e-05]]
# Epoch 3/300 - loss 43310.458
# Difference Iterasi 4: 0.030532692619480648
#
# Loss Iterasi 4: 42347.21663075459
#
# Gradient Embedding "i" Iterasi 4: [-2.56199085e-05 -3.13937900e-06 -1.92952914e-04  5.86464800e-05
#   1.21320538e-04  2.77557742e-05 -1.20525902e-04  8.98380594e-05
#   5.50524333e-05 -1.03072403e-04  4.44103333e-05  8.17766069e-05
#   3.28782475e-05 -1.10039882e-04 -9.60400856e-05  7.31928812e-05
#   3.91364965e-05  1.19649556e-04 -3.42739923e-05  7.40885893e-05
#  -1.12599695e-04  1.05440407e-04  3.79267662e-05 -6.37553753e-05
#  -1.09373021e-04 -1.65169958e-05  5.63550796e-05 -2.85853478e-05
#  -7.01408761e-05 -3.67643724e-05 -1.57485560e-04 -1.02656282e-04
#   1.00892753e-04  9.84704655e-05  5.35316883e-05 -8.42071110e-05
#   3.18562034e-05  3.46034171e-05 -1.33947448e-04 -1.09944602e-04
#  -1.77837424e-05 -2.97826158e-05  4.88157031e-05 -1.89836868e-05
#  -8.87278459e-05  4.75940687e-05  1.26621567e-06  5.01866929e-05
#  -2.33372460e-05 -5.55142282e-05 -8.05004293e-05 -1.12940762e-04
#   8.56411440e-05 -6.67478231e-05 -2.42516819e-05 -5.44461321e-06
#   3.43311696e-05  1.01557138e-04  2.66718047e-06 -2.42148773e-05
#  -8.56482425e-05 -6.96867724e-05 -1.13546374e-04  1.18584591e-04
#   1.04217698e-05 -8.07921359e-06 -4.60085273e-05 -7.18987746e-06
#   1.93557629e-06 -1.33169962e-05 -1.29463143e-04 -6.78526938e-05
#  -6.87279926e-05  6.60695363e-07  6.56974598e-05 -6.28863968e-05
#  -7.13990843e-05 -9.14565365e-05 -2.17888849e-06 -1.38386596e-04
#   9.57470669e-05 -2.87901822e-05  2.45283937e-05 -4.54756710e-05
#   6.05399427e-05  7.60440435e-05  6.72432822e-05  1.18300041e-04
#  -8.55025359e-05  8.14100727e-05  2.69708019e-05 -4.68038211e-05
#  -1.52267326e-04 -9.42573284e-05  3.77921761e-05 -1.53426446e-05
#   6.68546371e-05 -4.91046423e-05 -1.84085217e-05 -6.67339020e-06
#  -9.98029723e-05 -7.79801901e-05 -5.08533293e-05  6.01838948e-05
#  -5.22109457e-05 -1.00328451e-04 -3.13890247e-05  1.39282403e-05
#  -7.88080097e-05 -8.04519982e-05 -1.17460340e-04  3.81093746e-05
#   2.39576552e-05  3.21649953e-05  2.91873361e-05 -1.09196851e-04
#   2.98463466e-05  4.70626673e-05  4.87910433e-05  7.09194857e-05
#  -6.55179087e-05 -5.01521567e-05 -1.62564593e-05 -1.23730869e-04
#   1.42657989e-04  3.30897466e-05  4.18867338e-05  7.41459485e-05
#   1.11246525e-04 -3.88031015e-05  1.26094440e-04 -2.17740329e-05
#   1.10885420e-04 -8.49645526e-06 -4.64431108e-05  8.04458966e-05
#   5.23883323e-07 -8.83595824e-05  1.41858262e-04 -3.38776516e-05
#  -2.97999519e-06  1.03896566e-04  3.61427320e-05 -6.61821084e-05
#   1.61559671e-05  1.22034926e-04  6.96099112e-05  2.50425651e-05
#  -3.52755190e-05  7.92354703e-05]
#
# Gradient Embedding "j" Iterasi 4: [-3.28287072e-05  6.81353229e-05 -1.27444473e-05 -2.36174383e-05
#  -4.02397831e-05 -8.69983405e-05 -7.68379315e-05  8.18473451e-05
#  -6.38419811e-05  2.02365226e-05  7.36867801e-05 -4.41327350e-05
#   9.91658215e-05 -4.62381192e-05  6.87671260e-05  7.03935864e-05
#   4.55434166e-05 -4.06022902e-05  4.99184867e-05  9.72914261e-05
#  -6.69956708e-05 -8.41452180e-05 -8.07431605e-05 -6.39484208e-06
#  -4.78738391e-05  9.52643778e-05 -2.79716838e-05 -8.97369188e-05
#  -3.46316697e-05 -6.96568673e-05 -9.56063296e-05  9.56038725e-05
#  -7.31922663e-05 -6.49970840e-05 -1.50194068e-05 -1.04208897e-05
#   9.55033323e-05  7.63991261e-05  9.57760555e-05 -6.95266984e-05
#  -2.97038224e-05 -1.90074437e-05 -5.77754227e-05  9.91556673e-05
#   3.57638248e-05 -6.69641959e-05 -6.92892663e-05 -3.97210785e-05
#   6.96861115e-05  4.94341996e-05 -6.69672880e-05 -2.31682750e-05
#  -6.36804353e-06 -1.72762683e-05 -6.82710549e-06 -4.62917477e-05
#  -3.77767636e-05 -2.82620222e-05 -3.45472746e-06 -4.00913050e-05
#  -2.25571812e-06  5.86939522e-05  2.84069954e-06  6.34948930e-05
#  -8.12324386e-05 -2.90945065e-05 -2.45852269e-05 -3.91659359e-05
#  -4.09029677e-05 -4.46929406e-06 -7.79650208e-05  9.52902804e-05
#   6.80453550e-05 -5.33331757e-05  2.20623771e-05  7.18830902e-05
#   1.01308537e-05  9.84326476e-05 -9.75664536e-05 -3.17704581e-05
#  -3.67844954e-06  6.65819438e-05 -9.25031392e-05 -1.42567884e-06
#  -5.69635391e-06  6.12421550e-05  2.56644241e-05  4.02931324e-05
#   5.09444556e-05 -6.18008813e-05 -9.98094592e-05 -8.44354087e-05
#   1.80918068e-05  7.83120476e-05 -7.72240352e-05  6.77965187e-05
#   8.88871825e-05  8.35165209e-05 -1.37255576e-05 -4.94752364e-05
#   8.18514358e-05  5.22919333e-05 -8.60356435e-05  9.79149689e-05
#  -5.52235078e-06  1.37521740e-05  3.66883747e-05  7.48369306e-05
#  -4.14741621e-05 -3.56491520e-05 -4.25163686e-05 -2.02716730e-05
#   5.74251896e-05 -7.13164891e-05 -5.05672351e-05  3.63945029e-05
#  -2.32452943e-05 -2.51515717e-05  3.77708000e-05 -7.64872836e-06
#   6.41539731e-05  2.44419842e-05  5.59317009e-05  3.03313277e-05
#  -3.90589416e-05  2.43787640e-05  3.62653515e-05  6.36865220e-05
#  -1.34052788e-05  9.46006781e-05 -2.75649622e-05  9.51630510e-05
#  -1.37551486e-05 -5.44348215e-05 -1.00120181e-04  3.62493754e-05
#   2.25741973e-05 -2.80793486e-05 -7.34438664e-05 -9.26445314e-05
#  -2.26144686e-05 -2.04050225e-05 -1.88668236e-05 -6.33806236e-05
#  -1.03128709e-05  7.90901300e-05  2.23684712e-05  3.04868005e-05
#   4.31211296e-05 -2.43080297e-06]
#
# Embedding Iterasi 4: [[-2.92413101e-03  5.81836876e-03 -9.10932486e-04 ... -3.91841685e-03
#    2.55422653e-03 -5.18675123e-03]
#  [-1.54936113e-03 -9.17843549e-04 -3.95655805e-03 ... -5.70500700e-04
#    1.39782677e-03 -1.11251016e-03]
#  [-2.53353840e-03  1.32752927e-03  3.04647285e-03 ... -7.22243372e-05
#    5.77027883e-03  1.11641244e-03]
#  ...
#  [-1.30875687e-03  2.22387489e-03  1.57548790e-03 ...  1.92704558e-03
#   -3.10909235e-03 -2.21312788e-03]
#  [ 2.35212416e-04  1.31221593e-03 -2.19671923e-03 ...  7.15353417e-05
#   -2.32381323e-03 -7.75357320e-04]
#  [-1.07494236e-03  2.23158443e-03 -4.15473793e-04 ...  9.98246527e-04
#    1.41264646e-03 -8.04054763e-05]]
# Epoch 4/300 - loss 42347.217
# Difference Iterasi 5: 0.028084168982677606
#
# Loss Iterasi 5: 39496.635230963686
#
# Gradient Embedding "i" Iterasi 5: [-8.73277625e-07  1.93525871e-05 -2.63026973e-04  4.39238496e-05
#   1.36419264e-04  1.66325575e-05 -1.57944499e-04  8.80982613e-05
#   6.52000641e-05 -1.01615355e-04  1.80572029e-05  8.90364380e-05
#   7.57938955e-05 -1.09392622e-04 -1.03422932e-04  5.69268475e-05
#   1.55180046e-05  1.28052405e-04 -1.11234676e-05  5.54878809e-05
#  -1.07998830e-04  1.12054606e-04  2.16734054e-05 -6.96828604e-05
#  -1.42521397e-04  2.99616915e-05  3.16389693e-05  1.31241748e-06
#  -5.75989933e-05 -6.57026910e-05 -1.83054331e-04 -1.21461124e-04
#   1.13900985e-04  1.29917682e-04  3.35793920e-05 -9.43165372e-05
#   5.09704455e-05  3.49216703e-05 -1.45403150e-04 -1.43104817e-04
#  -2.98167611e-05  9.13569166e-06  3.81501106e-05 -8.32896671e-06
#  -1.05024144e-04  5.24952041e-05  1.55151874e-05  7.72615506e-05
#  -1.21688827e-05 -6.56230076e-05 -1.10580824e-04 -1.28491869e-04
#   1.23853302e-04 -5.65750634e-05 -2.46110104e-05 -2.15789599e-05
#   2.64185912e-05  1.23554234e-04 -6.69447525e-06 -3.52409034e-05
#  -9.17953273e-05 -4.38431281e-05 -1.22031998e-04  1.22106897e-04
#   2.05985060e-07  1.58904035e-05 -6.47416066e-05  1.27227364e-07
#   3.17781512e-06  2.59316217e-05 -1.42892851e-04 -3.70604510e-05
#  -7.29170263e-05  1.56771118e-05  8.21686560e-05 -3.85196497e-05
#  -6.00909082e-05 -1.08612858e-04 -1.28430718e-05 -1.44174692e-04
#   8.34882341e-05 -5.09970791e-05 -2.62104156e-05 -6.86548638e-05
#   3.45302814e-05  6.91035655e-05  6.33450249e-05  1.35821472e-04
#  -8.62346442e-05  9.06246754e-05  5.78759131e-05 -4.41381711e-05
#  -1.83612624e-04 -9.03373249e-05  1.84315975e-05 -9.31255290e-06
#   5.39439487e-05 -3.77826668e-05 -4.58199101e-06 -2.72851035e-05
#  -1.38781743e-04 -1.07939944e-04 -3.95149674e-05  8.24454812e-05
#  -8.10322812e-05 -9.89711872e-05 -7.47641775e-05  2.38309866e-05
#  -6.58293421e-05 -6.76904172e-05 -1.17623323e-04  6.80174386e-05
#   4.40376348e-05  4.03289090e-05  2.19216542e-05 -1.27322737e-04
#   3.47843882e-05  4.53403140e-05  5.54100286e-05  6.48266838e-05
#  -8.44862079e-05 -4.29363074e-05 -5.58291166e-05 -1.39744703e-04
#   1.83750884e-04  4.99294924e-05  2.61075795e-05  5.10509726e-05
#   1.22127591e-04 -1.77189817e-05  1.18773257e-04 -1.39797785e-05
#   1.14889127e-04 -2.66437752e-05 -6.68415045e-05  7.43925921e-05
#   3.02219656e-05 -9.41979049e-05  1.67318306e-04  4.75733760e-06
#  -7.24559003e-06  1.06919450e-04  5.69989692e-05 -6.26600658e-05
#   6.95848836e-06  1.34445232e-04  9.25829075e-05  2.33490052e-05
#  -5.42865396e-05  6.70019779e-05]
#
# Gradient Embedding "j" Iterasi 5: [-2.95398948e-05  6.23905713e-05 -9.60794994e-06 -2.28759881e-05
#  -3.76341114e-05 -7.94226762e-05 -6.93005627e-05  7.40314403e-05
#  -5.89405207e-05  1.80934643e-05  6.94097847e-05 -4.03897484e-05
#   8.94687502e-05 -4.15880715e-05  6.50521647e-05  6.48686818e-05
#   4.29352464e-05 -3.75600632e-05  4.34325711e-05  8.97220750e-05
#  -6.18015055e-05 -7.74699503e-05 -7.47371785e-05 -5.59379740e-06
#  -4.27732012e-05  8.63061358e-05 -2.49622333e-05 -8.41699736e-05
#  -3.33205144e-05 -6.19680221e-05 -8.72052867e-05  8.81841131e-05
#  -6.79375018e-05 -6.13964679e-05 -1.33856109e-05 -8.58050082e-06
#   8.86819094e-05  6.98383470e-05  8.93160435e-05 -6.22505753e-05
#  -2.67703033e-05 -1.86442502e-05 -5.27855458e-05  9.02387895e-05
#   3.25377422e-05 -6.17036789e-05 -6.51857188e-05 -3.85112210e-05
#   6.38192919e-05  4.61123478e-05 -5.91325109e-05 -2.07122231e-05
#  -7.29592609e-06 -1.57717564e-05 -6.56480817e-06 -4.14754000e-05
#  -3.39211256e-05 -2.67232075e-05 -3.69636737e-06 -3.48796428e-05
#  -9.39686163e-07  5.25847492e-05  3.44042577e-06  5.75722272e-05
#  -7.43474276e-05 -2.66892962e-05 -2.08074355e-05 -3.58598831e-05
#  -3.78316975e-05 -3.87820217e-06 -7.03708332e-05  8.49917487e-05
#   6.31246074e-05 -5.01548496e-05  2.00084040e-05  6.48901586e-05
#   8.06878169e-06  9.12401396e-05 -8.95285988e-05 -2.97472769e-05
#  -3.31150616e-06  6.20778215e-05 -8.13686045e-05  1.28535342e-06
#  -3.86305873e-06  5.65031494e-05  2.42478743e-05  3.69080393e-05
#   4.63601916e-05 -5.73177796e-05 -9.35637690e-05 -7.68423190e-05
#   1.79520781e-05  7.07716322e-05 -7.23586116e-05  6.17138497e-05
#   8.12967186e-05  7.57264338e-05 -1.23972103e-05 -4.55794877e-05
#   7.56790745e-05  4.90085127e-05 -7.89139262e-05  8.93377070e-05
#  -4.58945850e-06  1.22658927e-05  3.63169388e-05  6.91723080e-05
#  -3.78835756e-05 -3.37572447e-05 -3.90771129e-05 -1.92481395e-05
#   5.09721144e-05 -6.49592703e-05 -4.61131836e-05  3.40736831e-05
#  -2.26873443e-05 -2.29206229e-05  3.53041113e-05 -7.48738614e-06
#   6.04346891e-05  2.28726044e-05  5.34166982e-05  2.89447476e-05
#  -3.93778546e-05  2.03310103e-05  3.33667155e-05  5.97279852e-05
#  -1.22040787e-05  8.81933777e-05 -2.32315700e-05  8.76059539e-05
#  -1.18044195e-05 -5.10399694e-05 -9.17062924e-05  3.33213122e-05
#   1.97324666e-05 -2.58882299e-05 -6.81355216e-05 -8.60736968e-05
#  -2.08800065e-05 -1.81752197e-05 -1.92194585e-05 -5.73337764e-05
#  -9.34665363e-06  7.19333691e-05  1.84987389e-05  2.83894142e-05
#   4.21935962e-05 -1.59975524e-06]
#
# Embedding Iterasi 5: [[-2.99122424e-03  7.40775045e-03 -3.87371196e-03 ... -5.13776230e-03
#    5.40194322e-05 -6.48246372e-03]
#  [-5.86709509e-04 -4.58952377e-04 -3.81480232e-03 ... -4.40081155e-04
#    3.27650619e-03 -6.16951036e-05]
#  [-2.14539927e-03  9.60544375e-04  8.19180466e-03 ...  6.68096174e-04
#    1.01558341e-02  3.07554868e-03]
#  ...
#  [-1.25727048e-03  2.23446545e-03  1.63279792e-03 ...  1.92456699e-03
#   -3.01896339e-03 -2.17549059e-03]
#  [ 2.27155199e-04  1.30632797e-03 -2.11282889e-03 ...  7.63839708e-05
#   -2.25968958e-03 -7.13666445e-04]
#  [-1.05182566e-03  2.22136309e-03 -3.39482397e-04 ...  1.01063545e-03
#    1.50294075e-03 -5.76329030e-05]]
# Epoch 5/300 - loss 39496.635
# Difference Iterasi 6: 0.02538678643794933
#
# Loss Iterasi 6: 36868.66968894608
#
# Gradient Embedding "i" Iterasi 6: [ 3.75930015e-05  5.30260163e-05 -3.55449212e-04  2.06578158e-05
#   1.55850621e-04 -1.45634002e-07 -2.08854956e-04  7.63168792e-05
#   7.62771625e-05 -1.03899331e-04 -1.53918538e-05  1.04301503e-04
#   1.25780983e-04 -1.05230417e-04 -1.04898136e-04  3.48008821e-05
#  -1.79423092e-05  1.42092672e-04  1.26360574e-05  2.92264587e-05
#  -1.00927584e-04  1.28264136e-04 -1.85146364e-06 -8.10075626e-05
#  -1.84326596e-04  9.91531897e-05  1.60662908e-06  3.71435568e-05
#  -4.38222222e-05 -9.67118729e-05 -2.16661268e-04 -1.50953275e-04
#   1.29458961e-04  1.68225621e-04  3.30210526e-06 -1.09543241e-04
#   7.99180216e-05  2.90501779e-05 -1.56267411e-04 -1.86334478e-04
#  -3.77159470e-05  6.89769991e-05  2.96157309e-05 -1.37198443e-06
#  -1.31974101e-04  5.70011714e-05  3.11358907e-05  1.03151785e-04
#  -1.14273750e-06 -7.44248360e-05 -1.40150917e-04 -1.46966205e-04
#   1.72711219e-04 -4.35049698e-05 -2.56142409e-05 -4.38281702e-05
#   2.29972573e-05  1.54247130e-04 -2.49086283e-05 -3.89719883e-05
#  -9.57925484e-05 -1.31322548e-05 -1.31360900e-04  1.24371133e-04
#  -1.34875682e-05  5.37858607e-05 -8.35030893e-05  4.23517480e-06
#   8.79831869e-07  8.68030557e-05 -1.59609480e-04 -9.97858019e-06
#  -7.51405106e-05  2.93726078e-05  1.00200904e-04 -1.22437070e-05
#  -5.26223933e-05 -1.22679421e-04 -2.76973125e-05 -1.53305386e-04
#   6.62755109e-05 -8.42058256e-05 -8.23860437e-05 -9.45079464e-05
#   6.35812676e-06  5.90003631e-05  6.77385582e-05  1.65763659e-04
#  -8.87136212e-05  1.05900401e-04  9.67421604e-05 -3.80115694e-05
#  -2.24824061e-04 -9.01358327e-05 -1.91231265e-05 -7.74823928e-06
#   3.57467112e-05 -3.16983434e-05  1.54757489e-05 -6.60427281e-05
#  -1.96980087e-04 -1.46464302e-04 -1.90084370e-05  1.07784987e-04
#  -1.21430694e-04 -1.03431654e-04 -1.33543637e-04  4.14619125e-05
#  -5.04117936e-05 -5.42925874e-05 -1.20566702e-04  1.10407300e-04
#   7.51038999e-05  5.33957961e-05  9.73873027e-06 -1.48142406e-04
#   2.96231542e-05  5.16276280e-05  5.87490553e-05  5.80422750e-05
#  -1.08692108e-04 -2.69629756e-05 -1.01732215e-04 -1.55227905e-04
#   2.32270925e-04  6.98915599e-05  2.46859133e-06  3.17998246e-05
#   1.39096650e-04  2.34150802e-05  1.12701400e-04 -2.39050520e-06
#   1.30228117e-04 -5.57453991e-05 -1.00959289e-04  7.27664698e-05
#   5.71598618e-05 -1.12650426e-04  2.02984499e-04  5.45184535e-05
#  -5.78041112e-06  1.18429397e-04  7.74510067e-05 -5.43593840e-05
#  -6.85291399e-06  1.48359213e-04  1.22482613e-04  2.28804197e-05
#  -7.30664937e-05  5.53806274e-05]
#
# Gradient Embedding "j" Iterasi 6: [-2.61550221e-05  5.58942870e-05 -6.12473129e-06 -2.19827227e-05
#  -3.47348955e-05 -7.10906938e-05 -6.09988654e-05  6.56796222e-05
#  -5.34806442e-05  1.57684766e-05  6.45519637e-05 -3.61880360e-05
#   7.90458828e-05 -3.65047019e-05  6.07602400e-05  5.87875170e-05
#   3.97360538e-05 -3.41693372e-05  3.66910406e-05  8.15337600e-05
#  -5.60369372e-05 -7.02020849e-05 -6.80547159e-05 -4.86280382e-06
#  -3.71624920e-05  7.64036259e-05 -2.17459523e-05 -7.78337305e-05
#  -3.16812972e-05 -5.37833317e-05 -7.79249158e-05  8.00046686e-05
#  -6.21827045e-05 -5.72441719e-05 -1.15584191e-05 -6.57890983e-06
#   8.09796113e-05  6.26422801e-05  8.19979188e-05 -5.44002970e-05
#  -2.35889731e-05 -1.82434758e-05 -4.73619458e-05  8.05611576e-05
#   2.90411195e-05 -5.59290037e-05 -6.05379489e-05 -3.69361058e-05
#   5.72958043e-05  4.24331941e-05 -5.08310511e-05 -1.81740995e-05
#  -8.38425290e-06 -1.42002553e-05 -6.25825138e-06 -3.62223433e-05
#  -2.97204044e-05 -2.48876952e-05 -3.78633036e-06 -2.92571759e-05
#   2.46348771e-07  4.59711282e-05  3.88717567e-06  5.11106534e-05
#  -6.67382886e-05 -2.40318949e-05 -1.68454588e-05 -3.22791307e-05
#  -3.44450860e-05 -3.41734476e-06 -6.21590707e-05  7.39976480e-05
#   5.75975204e-05 -4.66100182e-05  1.77738941e-05  5.74278154e-05
#   6.05531149e-06  8.32813800e-05 -8.06358101e-05 -2.75118312e-05
#  -2.96381716e-06  5.70933542e-05 -6.95831850e-05  3.94950290e-06
#  -2.01673920e-06  5.12872150e-05  2.24701245e-05  3.31976843e-05
#   4.13848825e-05 -5.25067514e-05 -8.66850632e-05 -6.84386790e-05
#   1.77726738e-05  6.27490348e-05 -6.67646110e-05  5.52542919e-05
#   7.30156750e-05  6.74772915e-05 -1.11359246e-05 -4.14117393e-05
#   6.89969912e-05  4.53403074e-05 -7.10014451e-05  7.98942964e-05
#  -3.51382856e-06  1.07498957e-05  3.57043352e-05  6.28584510e-05
#  -3.39342948e-05 -3.15007343e-05 -3.53506142e-05 -1.82417481e-05
#   4.41623216e-05 -5.81230066e-05 -4.13360200e-05  3.14726137e-05
#  -2.18575458e-05 -2.03933377e-05  3.24358129e-05 -7.26141299e-06
#   5.62023542e-05  2.10975784e-05  5.04697556e-05  2.73026584e-05
#  -3.92753693e-05  1.62602874e-05  3.01530983e-05  5.51442492e-05
#  -1.10332983e-05  8.08986448e-05 -1.87052826e-05  7.93324435e-05
#  -9.82745823e-06 -4.72152549e-05 -8.25283288e-05  3.00508458e-05
#   1.67638889e-05 -2.32654156e-05 -6.22923598e-05 -7.88812322e-05
#  -1.89959660e-05 -1.58406301e-05 -1.94049459e-05 -5.08854265e-05
#  -8.23119827e-06  6.41876040e-05  1.44127760e-05  2.61311829e-05
#   4.09272994e-05 -7.90994449e-07]
#
# Embedding Iterasi 6: [[-2.47651714e-03  1.00395832e-02 -8.50198390e-03 ... -7.05243201e-03
#   -3.43718665e-03 -7.93904655e-03]
#  [ 6.48981349e-04  2.02238817e-04 -5.44239669e-03 ... -2.41866001e-04
#    4.40112196e-03  7.98106717e-04]
#  [-2.44716923e-03  2.70104889e-04  1.26169485e-02 ...  1.54289830e-03
#    1.32883511e-02  4.61775346e-03]
#  ...
#  [-1.18110466e-03  2.25868030e-03  1.72338113e-03 ...  1.91164591e-03
#   -2.88200591e-03 -2.11502106e-03]
#  [ 2.16469890e-04  1.29334111e-03 -2.01491078e-03 ...  8.39382450e-05
#   -2.19040291e-03 -6.48906960e-04]
#  [-1.03063717e-03  2.20117759e-03 -2.37702167e-04 ...  1.02909340e-03
#    1.61288034e-03 -3.17115289e-05]]
# Epoch 6/300 - loss 36868.67
# Difference Iterasi 7: 0.02235040672222467
#
# Loss Iterasi 7: 35613.7031434579
#
# Gradient Embedding "i" Iterasi 7: [ 9.40236128e-05  9.91219895e-05 -4.61046778e-04 -1.90869310e-05
#   1.75495749e-04 -2.21701317e-05 -2.68343415e-04  4.68743364e-05
#   8.60962354e-05 -1.11838510e-04 -5.13706374e-05  1.31758392e-04
#   1.75779248e-04 -9.20972217e-05 -8.74081054e-05  6.10744795e-06
#  -6.07517394e-05  1.61136344e-04  2.70059768e-05 -4.23706340e-06
#  -9.07820784e-05  1.56983776e-04 -3.58376079e-05 -9.81319325e-05
#  -2.27981352e-04  1.90826953e-04 -3.11747742e-05  7.35842834e-05
#  -3.40137339e-05 -1.18330343e-04 -2.54495244e-04 -1.92920649e-04
#   1.44505543e-04  2.06943112e-04 -3.88456743e-05 -1.25861749e-04
#   1.22509025e-04  1.01459118e-05 -1.60942738e-04 -2.33891489e-04
#  -3.57114138e-05  1.51628571e-04  2.60356183e-05 -3.75933265e-06
#  -1.74869267e-04  5.94137250e-05  4.17607435e-05  1.15502384e-04
#   6.89146909e-06 -7.65322424e-05 -1.55135365e-04 -1.65727170e-04
#   2.25420144e-04 -2.72654056e-05 -2.81035188e-05 -6.82417659e-05
#   3.05814194e-05  1.93562815e-04 -5.54657602e-05 -2.10859801e-05
#  -9.38339081e-05  1.57083657e-05 -1.37455704e-04  1.20911665e-04
#  -3.11802363e-05  1.09489985e-04 -9.29852910e-05  2.67181029e-06
#  -8.90857146e-06  1.74251559e-04 -1.74001111e-04 -3.29608969e-07
#  -7.21563271e-05  3.59274859e-05  1.15768869e-04  1.21016735e-05
#  -5.54477534e-05 -1.26868398e-04 -4.51633790e-05 -1.67144710e-04
#   4.09278694e-05 -1.28411919e-04 -1.27823903e-04 -1.12935134e-04
#  -1.56133008e-05  4.43577951e-05  8.66567518e-05  2.10960591e-04
#  -9.57505976e-05  1.24573462e-04  1.34737639e-04 -2.30730504e-05
#  -2.70191472e-04 -9.97363919e-05 -8.58139743e-05 -1.59196621e-05
#   9.46067630e-06 -3.73738245e-05  4.53424626e-05 -1.31249735e-04
#  -2.75784799e-04 -1.88890216e-04  1.67616537e-05  1.30904948e-04
#  -1.72379656e-04 -1.19125958e-04 -2.01618104e-04  6.95504001e-05
#  -3.11485408e-05 -4.48051796e-05 -1.27211966e-04  1.64505550e-04
#   1.15446372e-04  7.37134907e-05 -8.08196457e-06 -1.68305985e-04
#   3.13352672e-06  7.17605813e-05  5.60767330e-05  4.92651226e-05
#  -1.32476414e-04  1.76333585e-06 -1.44777512e-04 -1.62656873e-04
#   2.74386100e-04  8.62165666e-05 -3.17651043e-05  2.53055067e-05
#   1.63708331e-04  9.59010410e-05  1.14777378e-04  1.35320654e-05
#   1.62187222e-04 -1.02490720e-04 -1.53363399e-04  7.82682320e-05
#   7.25873282e-05 -1.48021213e-04  2.48589122e-04  1.12208677e-04
#   4.52867898e-06  1.41706681e-04  8.88538131e-05 -3.49463581e-05
#  -2.55741297e-05  1.59175875e-04  1.51207366e-04  2.44160270e-05
#  -7.91426969e-05  4.89569190e-05]
#
# Gradient Embedding "j" Iterasi 7: [-2.27687916e-05  4.84213079e-05 -3.02013019e-06 -2.05074192e-05
#  -3.12135131e-05 -6.18931361e-05 -5.22321225e-05  5.69256980e-05
#  -4.70696187e-05  1.34400036e-05  5.83330980e-05 -3.15229325e-05
#   6.82998959e-05 -3.10825308e-05  5.51483603e-05  5.19757749e-05
#   3.53717681e-05 -3.02752526e-05  3.03785213e-05  7.23032536e-05
#  -4.94482437e-05 -6.20909084e-05 -6.03661843e-05 -4.30453166e-06
#  -3.13961681e-05  6.56494026e-05 -1.85696620e-05 -6.98165587e-05
#  -2.92265423e-05 -4.57049793e-05 -6.77749018e-05  7.07944238e-05
#  -5.56188385e-05 -5.17001467e-05 -9.61383732e-06 -4.68532702e-06
#   7.19239051e-05  5.47730007e-05  7.31811625e-05 -4.63624997e-05
#  -2.04276884e-05 -1.75850862e-05 -4.15368621e-05  7.01732623e-05
#   2.53580524e-05 -4.93944404e-05 -5.47159697e-05 -3.40537597e-05
#   5.00332118e-05  3.79074895e-05 -4.27337547e-05 -1.57396721e-05
#  -9.13957473e-06 -1.24472707e-05 -5.84731734e-06 -3.07389684e-05
#  -2.54745957e-05 -2.24063976e-05 -3.43589245e-06 -2.38342560e-05
#   9.16866558e-07  3.91998559e-05  3.94527402e-06  4.41338949e-05
#  -5.81208053e-05 -2.10602661e-05 -1.32642541e-05 -2.82473489e-05
#  -3.05752558e-05 -3.18841740e-06 -5.34866955e-05  6.30000213e-05
#   5.10618509e-05 -4.22399722e-05  1.54732023e-05  4.96533925e-05
#   4.55735137e-06  7.40759440e-05 -7.07507197e-05 -2.48738399e-05
#  -2.70962771e-06  5.12639228e-05 -5.81206144e-05  5.86176458e-06
#  -7.63403389e-07  4.54860571e-05  1.99750366e-05  2.90798195e-05
#   3.59878985e-05 -4.70191336e-05 -7.82269735e-05 -5.91627366e-05
#   1.70555192e-05  5.45138864e-05 -5.97178896e-05  4.87572828e-05
#   6.39188175e-05  5.89232945e-05 -1.00739455e-05 -3.66977949e-05
#   6.14765364e-05  4.07340580e-05 -6.21752130e-05  6.96647305e-05
#  -2.50007921e-06  9.48709749e-06  3.39930898e-05  5.56665352e-05
#  -2.95279856e-05 -2.83712413e-05 -3.11326719e-05 -1.69970668e-05
#   3.72662285e-05 -5.08462455e-05 -3.62945389e-05  2.83024215e-05
#  -2.02431601e-05 -1.76592910e-05  2.90579944e-05 -6.83513558e-06
#   5.08541568e-05  1.88833477e-05  4.63132620e-05  2.49453872e-05
#  -3.75500907e-05  1.27828137e-05  2.64084240e-05  4.91554273e-05
#  -9.97683052e-06  7.19512422e-05 -1.45472291e-05  7.01931135e-05
#  -8.13183921e-06 -4.24503937e-05 -7.23137532e-05  2.62716428e-05
#   1.40801727e-05 -1.99459883e-05 -5.54933632e-05 -7.04819631e-05
#  -1.70354333e-05 -1.34710523e-05 -1.87567492e-05 -4.40925190e-05
#  -6.98902312e-06  5.58868623e-05  1.07962064e-05  2.35843841e-05
#   3.84182060e-05 -2.96360803e-07]
#
# Embedding Iterasi 7: [[-5.04212730e-04  1.45294921e-02 -1.43852588e-02 ... -1.00660206e-02
#   -6.91928610e-03 -8.92216952e-03]
#  [ 2.19185920e-03  1.14763657e-03 -1.04968851e-02 ...  2.89969550e-05
#    3.67482865e-03  1.08422182e-03]
#  [-4.11034701e-03 -9.74972752e-04  1.50017727e-02 ...  2.62704341e-03
#    1.33707062e-02  5.07804968e-03]
#  ...
#  [-1.07421822e-03  2.30416077e-03  1.83775102e-03 ...  1.88141639e-03
#   -2.70065622e-03 -2.03018718e-03]
#  [ 1.89956454e-04  1.26299299e-03 -1.93136408e-03 ...  9.84415015e-05
#   -2.14941694e-03 -5.95583638e-04]
#  [-1.01965958e-03  2.16547083e-03 -1.30515941e-04 ...  1.05496635e-03
#    1.71969554e-03 -1.37493191e-05]]
# Epoch 7/300 - loss 35613.703
# Difference Iterasi 8: 0.017776669615925472
#
# Loss Iterasi 8: 34131.421856905865
#
# Gradient Embedding "i" Iterasi 8: [ 1.52713491e-04  1.40973466e-04 -5.23238228e-04 -7.17777427e-05
#   1.77886453e-04 -4.22704296e-05 -3.03621149e-04 -2.67904677e-07
#   8.65418174e-05 -1.15689946e-04 -7.72254418e-05  1.58510457e-04
#   2.04545881e-04 -6.24089331e-05 -4.17853592e-05 -2.49325430e-05
#  -1.02013542e-04  1.71466390e-04  2.40957707e-05 -3.69187525e-05
#  -7.35519701e-05  1.80925054e-04 -7.50544367e-05 -1.11849778e-04
#  -2.47370112e-04  2.71951516e-04 -5.78015511e-05  9.67618929e-05
#  -2.91991739e-05 -1.13513299e-04 -2.70112736e-04 -2.25965168e-04
#   1.44312746e-04  2.22431652e-04 -8.20456985e-05 -1.28928146e-04
#   1.64754069e-04 -2.12509252e-05 -1.46324167e-04 -2.58337704e-04
#  -2.05957729e-05  2.30301088e-04  2.59556691e-05 -1.58576976e-05
#  -2.15533584e-04  5.47178477e-05  3.92423593e-05  9.97448242e-05
#   9.86069266e-06 -6.36403379e-05 -1.36683188e-04 -1.70811956e-04
#   2.51962206e-04 -8.31541432e-06 -3.12134869e-05 -8.20887687e-05
#   4.75900406e-05  2.21662255e-04 -8.89228863e-05  2.22531564e-05
#  -7.93858074e-05  3.22411314e-05 -1.27941440e-04  1.00473868e-04
#  -4.78616323e-05  1.66916811e-04 -8.08699843e-05 -3.45263168e-06
#  -2.45953778e-05  2.60800204e-04 -1.67153354e-04 -1.32135932e-05
#  -5.80962222e-05  2.84181863e-05  1.16898264e-04  2.80617856e-05
#  -6.51176878e-05 -1.10309108e-04 -5.74004357e-05 -1.72472382e-04
#   6.98156325e-06 -1.64736178e-04 -1.39805920e-04 -1.07460373e-04
#  -2.40618208e-05  2.51645510e-05  1.10192679e-04  2.49167216e-04
#  -1.00577009e-04  1.31826137e-04  1.50415571e-04  3.56413656e-06
#  -2.89865682e-04 -1.12748049e-04 -1.67011693e-04 -3.09049622e-05
#  -2.37143710e-05 -5.14081866e-05  7.73420449e-05 -2.05319025e-04
#  -3.41387276e-04 -2.11941813e-04  6.25933398e-05  1.35777589e-04
#  -2.11773989e-04 -1.35839867e-04 -2.48672722e-04  9.80596810e-05
#  -7.26405337e-06 -3.93607812e-05 -1.27645074e-04  2.07837805e-04
#   1.46949844e-04  9.29808309e-05 -2.85132045e-05 -1.71336644e-04
#  -4.27021524e-05  9.90953390e-05  4.38428853e-05  3.50168392e-05
#  -1.38148015e-04  3.94683370e-05 -1.62834510e-04 -1.47373675e-04
#   2.75646605e-04  8.66852259e-05 -7.08623182e-05  3.27464997e-05
#   1.80199504e-04  1.82868397e-04  1.20792704e-04  3.14643707e-05
#   1.93506175e-04 -1.54744725e-04 -2.06559491e-04  8.32386612e-05
#   6.81058548e-05 -1.81436819e-04  2.78287078e-04  1.57396385e-04
#   1.99170953e-05  1.64213171e-04  7.90004650e-05 -3.39367769e-06
#  -4.26432715e-05  1.51757906e-04  1.58707612e-04  2.71621500e-05
#  -6.01878408e-05  4.62283664e-05]
#
# Gradient Embedding "j" Iterasi 8: [-1.81336117e-05  3.75327835e-05 -5.34989470e-07 -1.71956553e-05
#  -2.53145200e-05 -4.86315913e-05 -4.04558654e-05  4.47934688e-05
#  -3.71775110e-05  1.04639832e-05  4.73985952e-05 -2.47567977e-05
#   5.37343017e-05 -2.37862627e-05  4.50966796e-05  4.16203706e-05
#   2.79275575e-05 -2.42484340e-05  2.30860536e-05  5.80368303e-05
#  -3.93755512e-05 -4.97112205e-05 -4.83820376e-05 -3.66525335e-06
#  -2.39954606e-05  5.08287093e-05 -1.45294423e-05 -5.61793307e-05
#  -2.42292505e-05 -3.54921423e-05 -5.32586673e-05  5.66906499e-05
#  -4.51384183e-05 -4.18116360e-05 -7.15232928e-06 -2.82585316e-06
#   5.76041662e-05  4.33165147e-05  5.88288678e-05 -3.58853980e-05
#  -1.62285360e-05 -1.54731965e-05 -3.30746321e-05  5.54018048e-05
#   2.01219281e-05 -3.94347260e-05 -4.45924821e-05 -2.78472710e-05
#   3.94041868e-05  3.04178747e-05 -3.27749380e-05 -1.25785261e-05
#  -8.76910722e-06 -9.82979633e-06 -4.97624545e-06 -2.35520190e-05
#  -1.99114320e-05 -1.79855785e-05 -2.46767380e-06 -1.75780930e-05
#   9.47041143e-07  3.03340457e-05  3.38171479e-06  3.43910086e-05
#  -4.54994280e-05 -1.66325840e-05 -9.57339157e-06 -2.22756389e-05
#  -2.45835838e-05 -2.95181858e-06 -4.16506739e-05  4.88824208e-05
#   4.07469284e-05 -3.46049070e-05  1.22725262e-05  3.90081936e-05
#   3.41061542e-06  5.95552929e-05 -5.61173955e-05 -2.03832456e-05
#  -2.40834995e-06  4.16710017e-05 -4.42588853e-05  6.41280903e-06
#  -1.86141323e-07  3.66045235e-05  1.57450249e-05  2.30294583e-05
#   2.82874707e-05 -3.81749917e-05 -6.36898987e-05 -4.60012248e-05
#   1.46709513e-05  4.31838606e-05 -4.79541939e-05  3.95537222e-05
#   5.06110900e-05  4.68945909e-05 -8.56217680e-06 -2.94480910e-05
#   4.96663713e-05  3.28857074e-05 -4.91439589e-05  5.50200976e-05
#  -1.55594613e-06  7.91647343e-06  2.89644987e-05  4.46002091e-05
#  -2.31449250e-05 -2.27884897e-05 -2.47523645e-05 -1.44059588e-05
#   2.85034348e-05 -4.04330460e-05 -2.90732901e-05  2.29482175e-05
#  -1.66765332e-05 -1.37998296e-05  2.35561251e-05 -5.78207327e-06
#   4.14836133e-05  1.51770973e-05  3.82215374e-05  2.04373909e-05
#  -3.18197011e-05  9.39655018e-06  2.07071805e-05  3.90817932e-05
#  -8.42431976e-06  5.74523237e-05 -1.02360413e-05  5.63702100e-05
#  -6.31583416e-06 -3.43601387e-05 -5.72390514e-05  2.06481629e-05
#   1.09909526e-05 -1.49927829e-05 -4.46211283e-05 -5.69210492e-05
#  -1.40225456e-05 -1.03768794e-05 -1.60469187e-05 -3.46296058e-05
#  -5.29427928e-06  4.40911436e-05  7.34756411e-06  1.93699164e-05
#   3.23049203e-05 -1.31666222e-07]
#
# Embedding Iterasi 8: [[ 3.69254405e-03  2.16158294e-02 -2.21687382e-02 ... -1.46429800e-02
#   -1.02842459e-02 -9.16131659e-03]
#  [ 5.03693580e-03  2.62235540e-03 -1.75592071e-02 ...  4.83998304e-04
#    3.36559369e-03  1.79554524e-03]
#  [-6.97882305e-03 -2.81111884e-03  1.75948005e-02 ...  4.13827993e-03
#    1.20701392e-02  5.20514076e-03]
#  ...
#  [-9.32296076e-04  2.37457780e-03  1.95745416e-03 ...  1.82751064e-03
#   -2.48482198e-03 -1.92296414e-03]
#  [ 1.39307221e-04  1.20135528e-03 -1.85268498e-03 ...  1.27100574e-04
#   -2.13863859e-03 -5.55198821e-04]
#  [-1.02160638e-03  2.10994095e-03 -2.48626513e-05 ...  1.08935410e-03
#    1.81786692e-03 -7.86897034e-06]]
# Epoch 8/300 - loss 34131.422
# Difference Iterasi 9: 0.010897763776996389
#
# Loss Iterasi 9: 32317.214931930455
#
# Gradient Embedding "i" Iterasi 9: [ 1.57505612e-04  1.33905130e-04 -4.30295714e-04 -9.76920117e-05
#   1.36034630e-04 -4.09752202e-05 -2.48096507e-04 -3.66444504e-05
#   6.46112925e-05 -9.40789393e-05 -6.66954537e-05  1.42246613e-04
#   1.70270200e-04 -2.20441428e-05  8.59948649e-06 -4.05741704e-05
#  -1.02334969e-04  1.43567663e-04  4.92258203e-06 -4.47764198e-05
#  -4.82012637e-05  1.53592468e-04 -8.95130704e-05 -9.63776042e-05
#  -1.97577802e-04  2.53738168e-04 -5.59585712e-05  7.97221835e-05
#  -2.33226780e-05 -7.05793700e-05 -2.14240859e-04 -1.95256683e-04
#   1.07875984e-04  1.72480643e-04 -8.87935590e-05 -9.75248791e-05
#   1.58652966e-04 -4.02868704e-05 -1.01158488e-04 -2.07661636e-04
#  -3.75940179e-07  2.25507170e-04  2.28371912e-05 -2.48539641e-05
#  -1.95403193e-04  3.83620381e-05  2.09833424e-05  5.35564652e-05
#   9.20527971e-06 -3.31087275e-05 -7.95093104e-05 -1.35427453e-04
#   2.00609216e-04  5.07379552e-06 -2.91363355e-05 -6.43747603e-05
#   5.41289798e-05  1.87891023e-04 -9.23691309e-05  5.69595983e-05
#  -4.81808384e-05  2.41729421e-05 -8.85597971e-05  5.75892454e-05
#  -4.94281709e-05  1.67644377e-04 -4.38864400e-05 -5.41241550e-06
#  -2.96159683e-05  2.57095065e-04 -1.14919445e-04 -3.12836315e-05
#  -3.13732706e-05  9.27700361e-06  8.83149992e-05  2.46534167e-05
#  -6.25642192e-05 -7.27904727e-05 -4.80977025e-05 -1.37856928e-04
#  -1.67057227e-05 -1.45956651e-04 -9.72389804e-05 -6.72110774e-05
#  -1.60749686e-05  7.80092322e-06  1.01778913e-04  2.18132952e-04
#  -8.25373226e-05  1.02943624e-04  1.13944153e-04  2.56995106e-05
#  -2.30194706e-04 -1.03890793e-04 -1.88515317e-04 -3.88871753e-05
#  -4.55332474e-05 -5.28989765e-05  8.30446777e-05 -2.12095539e-04
#  -3.05050273e-04 -1.71012795e-04  8.12334687e-05  9.96908976e-05
#  -1.85543406e-04 -1.20604590e-04 -2.10912218e-04  9.18148012e-05
#   1.19401417e-05 -3.29873446e-05 -1.00732802e-04  1.84831815e-04
#   1.25756269e-04  8.65887589e-05 -3.45550024e-05 -1.31047949e-04
#  -6.75396089e-05  9.95151082e-05  2.50260193e-05  1.55211249e-05
#  -1.00478166e-04  5.78709262e-05 -1.25947619e-04 -9.98210012e-05
#   1.93245055e-04  5.64531518e-05 -8.28638703e-05  3.95796273e-05
#   1.51521159e-04  2.04280126e-04  1.08997489e-04  3.69498411e-05
# ...
#  -2.62185259e-04 -6.20391146e-04  4.49772074e-04 -3.03131706e-04
#   3.61986676e-04 -3.59225179e-04 -8.30226596e-04 -2.44930281e-04
#   7.18780188e-04  1.24414039e-03 -2.31057675e-04  2.80091849e-04
#  -1.92984578e-04  3.87587525e-05 -4.29116024e-07 -4.39904154e-04
#  -4.32937352e-04  8.56670845e-05 -9.68720421e-05 -5.19376001e-05
#   6.84121859e-04 -2.47145238e-05 -4.70537305e-04  2.51418113e-04
#  -1.12436303e-04  6.91145868e-04 -4.98387231e-05  2.18110810e-04
#   4.29384813e-04 -6.27770963e-04  3.37060190e-05  4.63310190e-04
#   7.34414139e-05  6.88448736e-04  1.27509826e-04 -1.02158567e-04
#   9.04352753e-04  8.63618023e-04  2.47330044e-04  9.69775941e-05
#   3.51757275e-04  1.76831569e-04  6.81631411e-04  6.33175051e-05
#   2.03610099e-04 -4.42939873e-04 -2.33720687e-04  4.47501216e-04
#  -2.24837707e-04  3.30023228e-04 -3.82429242e-04 -3.99058675e-04
#  -7.21448933e-04  6.52324016e-04  1.32275347e-04  2.74072383e-04
#  -2.56332324e-04  2.51804560e-04  7.84542722e-05 -2.78644551e-04
#  -3.47218410e-04 -1.37970638e-04 -5.93181819e-04 -1.05470525e-04
#   4.31705636e-04  1.40519948e-03 -1.37911564e-04  2.75408756e-04
#  -8.25587770e-04 -2.40270387e-04 -2.20487081e-04 -3.72050948e-04
#   1.71576435e-05 -1.13746953e-04 -3.61319825e-04  7.85911443e-04
#  -8.70599047e-04 -4.56086901e-04 -3.77874838e-04  1.51444948e-04
#  -9.80830788e-04 -4.36641704e-06]
#
# Gradient Embedding "j" Iterasi 298: [ 3.14703087e-05 -4.86307248e-05  2.76805688e-05  2.74744787e-05
#  -7.28715284e-06 -1.47491328e-05  3.76084600e-05  3.52028746e-06
#   1.68943123e-05  3.68308859e-05 -6.03710373e-05  5.30081018e-06
#  -8.37930159e-05 -2.04486090e-05  1.41792256e-06  2.65319424e-06
#   2.02963455e-05 -2.76307176e-05  2.04758511e-05 -4.74194513e-05
#  -3.44149402e-05 -7.21442388e-08  1.53088674e-05  3.90448003e-05
#   7.46769117e-05 -9.71650474e-05  4.07531155e-05  5.90223186e-05
#   2.47044367e-05  1.80265815e-05  2.91245872e-05 -8.88858204e-06
#   4.09386708e-05  7.87658818e-06 -1.76210053e-05  2.54843391e-05
#  -5.23029215e-05 -2.89270027e-05  2.33144931e-06 -5.65440882e-06
#   5.49284336e-05  9.13457633e-06 -2.13175220e-05 -2.06346894e-05
#  -6.35807305e-06  1.86541002e-05  2.12037922e-05  1.66952157e-05
#   2.01618165e-05 -1.98936478e-05  2.47264968e-05  2.82156086e-06
#  -4.26985640e-05 -1.39532072e-05  1.62978245e-05  1.53311657e-05
#  -8.42565989e-07  1.16903624e-05  1.67491393e-05  1.48563076e-05
#   2.18814939e-05 -4.31151609e-05  4.58524233e-05 -4.12859235e-06
#  -5.71941340e-07 -1.72647139e-05  5.69888819e-05  6.88824993e-06
#  -3.23410545e-05 -1.60094676e-05  2.49843953e-05 -2.86220131e-05
#   3.86577846e-06 -4.10740372e-05 -1.26539151e-04 -3.57425930e-06
#   3.97898302e-05  2.85840585e-05  2.19944269e-05 -2.17073399e-06
#  -3.20830335e-05  2.89640448e-05  2.33546920e-05 -2.50951644e-05
#   2.43707315e-05 -5.16155113e-05 -1.58225046e-05 -4.76907363e-05
#  -4.63283417e-05  4.72328053e-05  3.49946984e-06  4.64268529e-05
#  -1.11874122e-06  2.79957430e-05 -1.59815275e-06 -1.77526177e-05
#  -1.45413491e-05 -4.54257770e-05  2.39327913e-05  4.75600779e-05
#   4.98762839e-06  6.87726667e-05  5.61371879e-05 -4.85533618e-06
#  -2.50442647e-06  1.78559450e-05  1.36447693e-05 -3.71117491e-06
#   4.67585785e-05 -1.68642388e-05  3.09902502e-05  6.20262634e-05
#   3.63065714e-05 -5.21187413e-05  7.80236073e-06  5.59289958e-05
#  -4.11969618e-06  8.32159793e-05 -3.92534068e-05  9.78636554e-08
#  -7.34022346e-05  4.40068327e-05  3.39609387e-05  1.82265372e-05
#  -2.08301377e-05  4.68577816e-05  3.45844942e-05  3.20953571e-06
#  -3.63764497e-06  4.97782514e-07 -3.91895005e-05 -3.90161965e-05
#   1.48777966e-05  1.15779629e-04  1.86770225e-05  2.68096527e-06
#  -5.94191428e-05 -3.29747735e-05  1.89559392e-05  2.80353969e-05
#   6.25087942e-06 -3.40471322e-05 -6.52417279e-05  3.93902965e-05
#  -9.82152599e-06 -4.45711956e-05 -2.60447352e-05  6.50885653e-06
#   6.96760330e-06  3.37887986e-05]
#
# Embedding Iterasi 298: [[ 1.38431551e-01  2.19036880e-01  9.23307687e-02 ... -8.93378679e-02
#   -2.34868516e-01 -1.07141391e-01]
#  [ 2.59516602e-02  3.54037100e-01 -3.15852056e-01 ...  2.02139729e-01
#   -1.24840773e-01  9.09699779e-03]
#  [-2.49589327e-01 -4.76215684e-02 -3.68246654e-02 ...  1.72769227e-01
#    7.67777462e-02  1.07218672e-01]
#  ...
#  [-2.34772974e-04  1.42123002e-02 -1.39108998e-02 ...  1.02530575e-03
#    1.43605010e-02  2.64951152e-02]
#  [-4.55428311e-03  1.61343969e-03 -6.04660766e-05 ... -1.50556945e-03
#   -5.04217154e-03  4.61119259e-03]
#  [-6.96325334e-03  1.07605938e-02 -6.13604329e-03 ... -1.44174053e-03
#   -1.53192547e-03 -7.47646295e-03]]
# Epoch 298/300 - loss 2586.619
# Difference Iterasi 299: -0.004505230352233054
#
# Loss Iterasi 299: 2585.5556175013644
#
# Gradient Embedding "i" Iterasi 299: [-2.38919352e-05  8.41916885e-07  1.10839473e-03  1.85984150e-04
#   3.25273488e-05 -4.97036057e-04  3.27066314e-04 -4.24317232e-04
#  -5.33506121e-04  3.90276020e-04 -5.42441984e-04 -4.69807946e-04
#  -8.78230410e-04 -7.80899786e-04  2.83956673e-04  3.89000661e-04
#   1.31767356e-04 -2.54136563e-08 -2.56666555e-04  3.46175691e-04
#   6.07628065e-05 -2.27106107e-04 -1.01612147e-04  5.20263126e-04
#   5.29549083e-04 -7.60913988e-04  4.95552004e-04  5.63511785e-04
#   2.08219187e-04  4.34601302e-04  5.19257863e-04  7.42199830e-04
#  -7.53855818e-06  2.30640310e-05 -3.78602057e-04 -1.43109994e-04
#  -6.40383922e-04 -2.17856745e-05  2.93911892e-04 -1.07858539e-04
#  -1.37593233e-04 -4.29035138e-04 -3.65730610e-04 -1.17484870e-04
#   6.96769032e-06 -2.03900337e-04  3.48724192e-04  3.75887071e-04
#  -4.28508315e-04  9.12615747e-05  2.35711095e-04  1.62358002e-04
#  -5.15494258e-04 -3.16198913e-04 -1.58666891e-04 -1.55018678e-04
#   4.95018548e-04 -1.35588707e-04  2.44225417e-04 -1.21706148e-04
#   6.23017981e-04  5.32281766e-04  1.75278480e-04  4.93628367e-04
#   1.02374253e-03 -6.06787822e-04  6.13515751e-04  3.70522759e-04
#  -2.60412248e-04 -6.17899769e-04  4.48069362e-04 -3.01832263e-04
#   3.60830828e-04 -3.57826010e-04 -8.27526383e-04 -2.44630243e-04
#   7.17168184e-04  1.23947690e-03 -2.30396525e-04  2.78730936e-04
#  -1.92326303e-04  3.88831900e-05 -5.98212480e-07 -4.38600603e-04
#  -4.31875507e-04  8.47804785e-05 -9.66083339e-05 -5.21695670e-05
#   6.82685146e-04 -2.54578516e-05 -4.69093240e-04  2.51038921e-04
#  -1.12100254e-04  6.89191791e-04 -4.91994854e-05  2.17352824e-04
#   4.28208414e-04 -6.26477855e-04  3.28043653e-05  4.62010271e-04
#   7.32657965e-05  6.86009266e-04  1.26312632e-04 -1.02042337e-04
#   9.01596938e-04  8.60579632e-04  2.46462775e-04  9.66137510e-05
#   3.50561629e-04  1.75744263e-04  6.79211317e-04  6.34659948e-05
#   2.03180244e-04 -4.41534840e-04 -2.32748648e-04  4.45744196e-04
#  -2.24131746e-04  3.28221659e-04 -3.80969055e-04 -3.98357718e-04
#  -7.18442593e-04  6.50200571e-04  1.32346970e-04  2.73327138e-04
#  -2.56665262e-04  2.50480568e-04  7.86155106e-05 -2.77835780e-04
#  -3.45884556e-04 -1.37818128e-04 -5.90465068e-04 -1.05190360e-04
#   4.29662845e-04  1.40096855e-03 -1.37830934e-04  2.73863048e-04
#  -8.22444676e-04 -2.39647180e-04 -2.19642428e-04 -3.71639725e-04
#   1.73375350e-05 -1.12973666e-04 -3.60382554e-04  7.83497453e-04
#  -8.68030914e-04 -4.54676050e-04 -3.77329107e-04  1.51324571e-04
#  -9.78313107e-04 -3.81226059e-06]
#
# Gradient Embedding "j" Iterasi 299: [ 3.14125857e-05 -4.84838106e-05  2.76791698e-05  2.73534867e-05
#  -7.23717990e-06 -1.47026544e-05  3.75541262e-05  3.49303739e-06
#   1.68522484e-05  3.67276637e-05 -6.01965070e-05  5.25808849e-06
#  -8.36333914e-05 -2.04017724e-05  1.41517637e-06  2.69773599e-06
#   2.02795367e-05 -2.75826897e-05  2.03811281e-05 -4.72438186e-05
#  -3.43764418e-05 -5.63739639e-08  1.52652408e-05  3.89939794e-05
#   7.44790597e-05 -9.69318776e-05  4.06427053e-05  5.89083784e-05
#   2.46201847e-05  1.80790423e-05  2.90905120e-05 -8.81236977e-06
#   4.08128024e-05  7.88260305e-06 -1.76088338e-05  2.53448364e-05
#  -5.22244458e-05 -2.88068422e-05  2.38293130e-06 -5.64531452e-06
#   5.47903637e-05  9.08752798e-06 -2.12806727e-05 -2.05914121e-05
#  -6.38225810e-06  1.85814810e-05  2.11759483e-05  1.66888058e-05
#   2.00463050e-05 -1.98670991e-05  2.46805111e-05  2.77334516e-06
#  -4.26940210e-05 -1.39776860e-05  1.62714866e-05  1.52775672e-05
#  -8.17177591e-07  1.15541316e-05  1.67534038e-05  1.47884743e-05
#   2.18587746e-05 -4.30075434e-05  4.57140944e-05 -4.08024951e-06
#  -5.07438522e-07 -1.72459245e-05  5.68847645e-05  6.91062771e-06
#  -3.23487765e-05 -1.60264949e-05  2.49733301e-05 -2.86157699e-05
#   3.89578045e-06 -4.09325578e-05 -1.26282750e-04 -3.59082314e-06
#   3.97667985e-05  2.86175311e-05  2.19212705e-05 -2.10921382e-06
#  -3.20229149e-05  2.89382334e-05  2.32898143e-05 -2.50292053e-05
#   2.42671487e-05 -5.14247944e-05 -1.57892449e-05 -4.76056336e-05
#  -4.61515788e-05  4.70956325e-05  3.42351217e-06  4.63959273e-05
#  -1.13829771e-06  2.80063124e-05 -1.65302714e-06 -1.76282869e-05
#  -1.45266383e-05 -4.53613487e-05  2.38676271e-05  4.74540980e-05
#   4.95749940e-06  6.86252528e-05  5.60295452e-05 -4.90012768e-06
#  -2.40374585e-06  1.78193935e-05  1.36505015e-05 -3.65679750e-06
#   4.66760215e-05 -1.67973491e-05  3.09570064e-05  6.19008610e-05
#   3.61875040e-05 -5.19932812e-05  7.71729421e-06  5.58010561e-05
#  -4.16586933e-06  8.30444872e-05 -3.91887206e-05  3.10837005e-08
#  -7.31897834e-05  4.39616681e-05  3.39032455e-05  1.82411917e-05
#  -2.08502439e-05  4.67840668e-05  3.45393678e-05  3.22338650e-06
#  -3.60345947e-06  5.67838498e-07 -3.90944803e-05 -3.89192201e-05
#   1.48611141e-05  1.15542654e-04  1.86129779e-05  2.65425807e-06
#  -5.93141476e-05 -3.28882001e-05  1.88714842e-05  2.78974051e-05
#   6.21678521e-06 -3.39385097e-05 -6.51579614e-05  3.93860361e-05
#  -9.81817957e-06 -4.44613947e-05 -2.59815087e-05  6.54512004e-06
#   6.90225235e-06  3.37070045e-05]
#
# Embedding Iterasi 299: [[ 1.38547367e-01  2.18969756e-01  9.22587068e-02 ... -8.94633250e-02
#   -2.34722072e-01 -1.07246981e-01]
#  [ 2.57156644e-02  3.54186234e-01 -3.15986977e-01 ...  2.02303702e-01
#   -1.25055786e-01  9.12619557e-03]
#  [-2.49610551e-01 -4.75436807e-02 -3.68487535e-02 ...  1.72847406e-01
#    7.69947202e-02  1.07155825e-01]
#  ...
#  [-2.39510448e-04  1.42255761e-02 -1.39320414e-02 ...  1.02879802e-03
#    1.43692053e-02  2.65361073e-02]
#  [-4.59574811e-03  1.62647313e-03 -6.95781636e-05 ... -1.53389221e-03
#   -5.06732562e-03  4.59500917e-03]
#  [-6.97223158e-03  1.07616634e-02 -6.15486965e-03 ... -1.45429580e-03
#   -1.52227002e-03 -7.48171128e-03]]
# Epoch 299/300 - loss 2585.556
# Difference Iterasi 300: -0.0044912036764697474
#
# Loss Iterasi 300: 2584.499613375033
#
# Gradient Embedding "i" Iterasi 300: [-2.40855139e-05  5.03072711e-07  1.10526837e-03  1.85431961e-04
#   3.27386798e-05 -4.95001431e-04  3.25890771e-04 -4.23202819e-04
#  -5.32168724e-04  3.89274362e-04 -5.40269412e-04 -4.68512354e-04
#  -8.75433156e-04 -7.78471191e-04  2.82715720e-04  3.88242701e-04
#   1.31637085e-04 -3.67695495e-07 -2.55994883e-04  3.45406686e-04
#   6.02942796e-05 -2.26439095e-04 -1.01312971e-04  5.17862331e-04
#   5.28239601e-04 -7.58794533e-04  4.94072951e-04  5.61857205e-04
#   2.07808532e-04  4.34211000e-04  5.17206269e-04  7.40736288e-04
#  -7.13158141e-06  2.34012098e-05 -3.78354829e-04 -1.42470477e-04
#  -6.38479653e-04 -2.14927175e-05  2.92873639e-04 -1.08378234e-04
#  -1.36813304e-04 -4.27730202e-04 -3.65128671e-04 -1.16571446e-04
#   7.18043178e-06 -2.02371584e-04  3.47755274e-04  3.75698158e-04
#  -4.27247668e-04  9.10035459e-05  2.34029979e-04  1.61844576e-04
#  -5.13645362e-04 -3.15108767e-04 -1.57590425e-04 -1.54158392e-04
#   4.93428095e-04 -1.35325131e-04  2.43730388e-04 -1.21755128e-04
#   6.21340865e-04  5.30736676e-04  1.74025894e-04  4.91997019e-04
#   1.02045711e-03 -6.04837332e-04  6.12100566e-04  3.69209269e-04
#  -2.58652891e-04 -6.15425397e-04  4.46374521e-04 -3.00543068e-04
#   3.59679419e-04 -3.56435349e-04 -8.24839436e-04 -2.44331113e-04
#   7.15561279e-04  1.23484168e-03 -2.29737834e-04  2.77379464e-04
#  -1.91670294e-04  3.90085027e-05 -7.64555245e-07 -4.37301838e-04
#  -4.30818570e-04  8.39025246e-05 -9.63431913e-05 -5.23989668e-05
#   6.81251280e-04 -2.61922907e-05 -4.67658479e-04  2.50657857e-04
#  -1.11764494e-04  6.87244098e-04 -4.85659467e-05  2.16599247e-04
#   4.27036310e-04 -6.25186609e-04  3.19095680e-05  4.60714852e-04
#   7.30903469e-05  6.83583781e-04  1.25125621e-04 -1.01925771e-04
#   8.98852806e-04  8.57556984e-04  2.45601464e-04  9.62521352e-05
#   3.49370198e-04  1.74667593e-04  6.76804243e-04  6.36118353e-05
#   2.02754213e-04 -4.40136731e-04 -2.31783298e-04  4.43999084e-04
#  -2.23429230e-04  3.26434823e-04 -3.79513542e-04 -3.97657469e-04
#  -7.15454188e-04  6.48088047e-04  1.32416459e-04  2.72585829e-04
#  -2.56990209e-04  2.49168248e-04  7.87761649e-05 -2.77031811e-04
#  -3.44556774e-04 -1.37663807e-04 -5.87767511e-04 -1.04910054e-04
#   4.27633750e-04  1.39675877e-03 -1.37745658e-04  2.72330175e-04
#  -8.19321959e-04 -2.39025130e-04 -2.18806201e-04 -3.71226432e-04
#   1.75163410e-05 -1.12205629e-04 -3.59447174e-04  7.81094570e-04
#  -8.65475787e-04 -4.53272902e-04 -3.76781784e-04  1.51202911e-04
#  -9.75804279e-04 -3.26194462e-06]
#
# Gradient Embedding "j" Iterasi 300: [ 3.13548218e-05 -4.83377434e-05  2.76775035e-05  2.72334684e-05
#  -7.18775909e-06 -1.46564878e-05  3.74997159e-05  3.46611539e-06
#   1.68102420e-05  3.66251776e-05 -6.00229206e-05  5.21560546e-06
#  -8.34739365e-05 -2.03552515e-05  1.41254487e-06  2.74189677e-06
#   2.02624443e-05 -2.75347234e-05  2.02870427e-05 -4.70691574e-05
#  -3.43375987e-05 -4.07378744e-08  1.52218935e-05  3.89429906e-05
#   7.42821200e-05 -9.66995963e-05  4.05328203e-05  5.87946761e-05
#   2.45366285e-05  1.81307536e-05  2.90562082e-05 -8.73664042e-06
#   4.06877560e-05  7.88833796e-06 -1.75966160e-05  2.52063903e-05
#  -5.21460452e-05 -2.86875110e-05  2.43376145e-06 -5.63628604e-06
#   5.46528100e-05  9.04088348e-06 -2.12439810e-05 -2.05481018e-05
#  -6.40584768e-06  1.85092704e-05  2.11482586e-05  1.66822097e-05
#   1.99315318e-05 -1.98404606e-05  2.46347116e-05  2.72560805e-06
#  -4.26887195e-05 -1.40016444e-05  1.62452788e-05  1.52241816e-05
#  -7.92241124e-07  1.14193573e-05  1.67573051e-05  1.47210586e-05
#   2.18360094e-05 -4.29003275e-05  4.55764422e-05 -4.03213647e-06
#  -4.43448996e-07 -1.72272641e-05  5.67808270e-05  6.93244850e-06
#  -3.23558203e-05 -1.60429457e-05  2.49619175e-05 -2.86090950e-05
#   3.92532446e-06 -4.07920824e-05 -1.26027206e-04 -3.60718715e-06
#   3.97434248e-05  2.86503114e-05  2.18486841e-05 -2.04815647e-06
#  -3.19629162e-05  2.89121357e-05  2.32250793e-05 -2.49636521e-05
#   2.41643540e-05 -5.12353958e-05 -1.57560424e-05 -4.75205501e-05
#  -4.59756458e-05  4.69589097e-05  3.34841469e-06  4.63645016e-05
#  -1.15745401e-06  2.80163281e-05 -1.70713021e-06 -1.75050477e-05
#  -1.45117790e-05 -4.52969057e-05  2.38026775e-05  4.73486254e-05
#   4.92767658e-06  6.84782216e-05  5.59218945e-05 -4.94437043e-06
#  -2.30392679e-06  1.77831447e-05  1.36558545e-05 -3.60306754e-06
#   4.65935464e-05 -1.67309415e-05  3.09235599e-05  6.17756560e-05
#   3.60692337e-05 -5.18682432e-05  7.63306283e-06  5.56735114e-05
#  -4.21162598e-06  8.28731259e-05 -3.91242728e-05 -3.48798606e-08
#  -7.29783743e-05  4.39162332e-05  3.38456017e-05  1.82553467e-05
#  -2.08697454e-05  4.67103015e-05  3.44940902e-05  3.23700041e-06
#  -3.56960347e-06  6.36795288e-07 -3.90000866e-05 -3.88227296e-05
#   1.48442206e-05  1.15306438e-04  1.85491757e-05  2.62782176e-06
#  -5.92092449e-05 -3.28022326e-05  1.87876005e-05  2.77602203e-05
#   6.18310305e-06 -3.38305251e-05 -6.50739807e-05  3.93811515e-05
#  -9.81490893e-06 -4.43520606e-05 -2.59183060e-05  6.58088334e-06
#   6.83724057e-06  3.36255195e-05]
#
# Embedding Iterasi 300: [[ 1.38662691e-01  2.18902343e-01  9.21867931e-02 ... -8.95883143e-02
#   -2.34576071e-01 -1.07352018e-01]
#  [ 2.54804169e-02  3.54334805e-01 -3.16121395e-01 ...  2.02466507e-01
#   -1.25270137e-01  9.15580536e-03]
#  [-2.49631291e-01 -4.74658544e-02 -3.68722100e-02 ...  1.72925288e-01
#    7.72105938e-02  1.07093200e-01]
#  ...
#  [-2.44242223e-04  1.42387680e-02 -1.39529572e-02 ...  1.03223042e-03
#    1.43778942e-02  2.65767748e-02]
#  [-4.63722015e-03  1.63942240e-03 -7.86436083e-05 ... -1.56221749e-03
#   -5.09251001e-03  4.57887148e-03]
#  [-6.98114411e-03  1.07627541e-02 -6.17365529e-03 ... -1.46679479e-03
#   -1.51260457e-03 -7.48694012e-03]]
# Epoch 300/300 - loss 2584.5

# %%
# Menampilkan Dict word2id
word_2_id = glove_model.show_word2id()
word_2_id
# Out:
# {'kawan': 0,
#  'sunda': 1,
#  'bersatu': 2,
#  'jemput': 3,
#  'arteria': 4,
#  'dahlan': 5,
#  '😁': 6,
#  'sidang': 7,
#  'adat': 8,
#  'daerah': 9,
#  'menuntut': 10,
#  'hukum': 11,
#  'ga': 12,
#  'tafsir': 13,
#  'membanding': 14,
#  'membandingkan': 15,
#  'edy': 16,
#  'menegakkan': 17,
#  'divisi': 18,
#  'humas': 19,
#  'polri': 20,
#  'bilang': 21,
#  'palsu': 22,
#  'mengeluarkan': 23,
#  'membenarkan': 24,
#  'plat': 25,
#  'no': 26,
#  'asli': 27,
#  'urut': 28,
#  'dada': 29,
#  'deh': 30,
#  'kuasa': 31,
#  'mengerti': 32,
#  'tsb': 33,
#  'dengar': 34,
#  'pendapat': 35,
#  'gedung': 36,
#  'dpr': 37,
#  'memiliki': 38,
#  'kekebalan': 39,
#  'atur': 40,
#  'konstitusi': 41,
#  'n': 42,
#  'uu': 43,
#  'maaf': 44,
#  'memaafkan': 45,
#  'kubu': 46,
#  'saran': 47,
#  'dorong': 48,
#  'masyarakat': 49,
#  'jabar': 50,
#  'menangkap': 51,
#  'semoga': 52,
#  'berpegang': 53,
#  'komitmen': 54,
#  'menenggelamkan': 55,
#  'partai': 56,
#  'demokrasi': 57,
#  'indonesia': 58,
#  'perjuangan': 59,
#  'spt': 60,
#  'sumbar': 61,
#  'beruntung': 62,
#  'kabar': 63,
#  'e': 64,
#  'hina': 65,
#  'suku': 66,
#  'pejabat': 67,
#  'sakit': 68,
#  'jiwa': 69,
#  'menantang': 70,
#  'goblok': 71,
#  'rakyat': 72,
#  'turun': 73,
#  'kelar': 74,
#  'provinsi': 75,
#  'manusia': 76,
#  'pasteur': 77,
#  'bandung': 78,
#  'mulut': 79,
#  'busuk': 80,
#  'acara': 81,
#  'resmi': 82,
#  'pakai': 83,
#  'bahasa': 84,
#  'tp': 85,
#  'penyelenggaraan': 86,
#  'sanksi': 87,
#  'memecat': 88,
#  'congkak': 89,
#  'arogan': 90,
#  'yak': 91,
#  'coba': 92,
#  'mas': 93,
#  'kali': 94,
#  'mendadak': 95,
#  'mengganti': 96,
#  'mak': 97,
#  'bangun': 98,
#  'cerdik': 99,
#  'tamparan': 100,
#  'lu': 101,
#  'polisi': 102,
#  'terdaftar': 103,
#  'milik': 104,
#  'emang': 105,
#  'gemas': 106,
#  'ama': 107,
#  'elu': 108,
#  'takut': 109,
#  'doang': 110,
#  '1': 111,
#  'gitu': 112,
#  'memperbaiki': 113,
#  'butuh': 114,
#  'suara': 115,
#  '2024': 116,
#  'kau': 117,
#  'injakan': 118,
#  'kaki': 119,
#  'tanah': 120,
#  'komentar': 121,
#  'jahat': 122,
#  'pernyataan': 123,
#  'berbicara': 124,
#  'pecat': 125,
#  'bikin': 126,
#  'kena': 127,
#  'mental': 128,
#  'orang': 129,
#  'hajat': 130,
#  'pernikahan': 131,
#  'undang': 132,
#  'kusnandar': 133,
#  'cari': 134,
#  'guru': 135,
#  'santet': 136,
#  'jumawa': 137,
#  'kritik': 138,
#  'membangun': 139,
#  'hotel': 140,
#  'jawa': 141,
#  'barat': 142,
#  'minimal': 143,
#  'kasih': 144,
#  'kupon': 145,
#  'menginap': 146,
#  'gratis': 147,
#  'malam': 148,
#  'liat': 149,
#  'berani': 150,
#  'kagak': 151,
#  'silaturahmi': 152,
#  'beliau': 153,
#  'tuan': 154,
#  'terhormat': 155,
#  'cepat': 156,
#  'menikah': 157,
#  'dah': 158,
#  'rt': 159,
#  'bantai': 160,
#  'p': 161,
#  'perkosa': 162,
#  'puan': 163,
#  'maharani': 164,
#  'biar': 165,
#  'miskin': 166,
#  'rindu': 167,
#  'mikropon': 168,
#  'aja': 169,
#  'calon': 170,
#  'presiden': 171,
#  'cawapres': 172,
#  'menang': 173,
#  'lumayan': 174,
#  'pemimpin': 175,
#  'otorita': 176,
#  'kota': 177,
#  'bincang': 178,
#  'manis': 179,
#  'sosok': 180,
#  'semangat': 181,
#  'bu': 182,
#  'baca': 183,
#  'berita': 184,
#  'beras': 185,
#  'foto': 186,
#  'ah': 187,
#  'pos': 188,
#  'isi': 189,
#  'kerjaan': 190,
#  'w': 191,
#  'kaya': 192,
#  'ibuk': 193,
#  'maunya': 194,
#  'cipta': 195,
#  'kerja': 196,
#  'sahkan': 197,
#  'bayangkan': 198,
#  'coklat': 199,
#  'valentine': 200,
#  'gambar': 201,
#  'gatal': 202,
#  'ajak': 203,
#  'dialog': 204,
#  'rajin': 205,
#  'monolog': 206,
#  'pegang': 207,
#  'eman': 208,
#  'kecerdasan': 209,
#  'terkikis': 210,
#  'nikmat': 211,
#  'kekuasaan': 212,
#  'pemegang': 213,
#  'melahirkan': 214,
#  'celaka': 215,
#  'menyediakan': 216,
#  'ruang': 217,
#  'kangen': 218,
#  'konten': 219,
#  'akun': 220,
#  'drama': 221,
#  'megawati': 222,
#  'soekarno': 223,
#  'putri': 224,
#  'capres': 225,
#  'berpasangan': 226,
#  'prabowo': 227,
#  'subianto': 228,
#  'mintak': 229,
#  'rumah': 230,
#  'kalimantan': 231,
#  'timur': 232,
#  'tipe': 233,
#  'ac': 234,
#  'wifi': 235,
#  'tidur': 236,
#  'televisi': 237,
#  'angkat': 238,
#  'ketua': 239,
#  'main': 240,
#  'tau': 241,
#  'politik': 242,
#  'kotor': 243,
#  'rada': 244,
#  'susah': 245,
#  'kalo': 246,
#  'ridwan': 247,
#  'kamil': 248,
#  'adu': 249,
#  'mematikan': 250,
#  'kader': 251,
#  'produsen': 252,
#  'koruptor': 253,
#  'membagikan': 254,
#  'kaos': 255,
#  'memunculkan': 256,
#  'kerumunan': 257,
#  'virus': 258,
#  'khawatir': 259,
#  'membanggakan': 260,
#  'dukung': 261,
#  'menelusuri': 262,
#  'urusan': 263,
#  'tembakau': 264,
#  'mega': 265,
#  'ambil': 266,
#  'laporan': 267,
#  'sekolah': 268,
#  'seh': 269,
#  'pindah': 270,
#  'yah': 271,
#  'muak': 272,
#  'penjilat': 273,
#  'ganjar': 274,
#  'asu': 275,
#  'selamat': 276,
#  'ulang': 277,
#  'meneruskan': 278,
#  'cita': 279,
#  'doa': 280,
#  'kekuatan': 281,
#  'regenerasi': 282,
#  'berjalan': 283,
#  'mbak': 284,
#  'lonjakan': 285,
#  'masker': 286,
#  'lantai': 287,
#  'dasar': 288,
#  'rame': 289,
#  'pujian': 290,
#  'sindiran': 291,
#  'elite': 292,
#  'demokrat': 293,
#  'menjabat': 294,
#  'ri': 295,
#  'jateng': 296,
#  'sambit': 297,
#  'eh': 298,
#  'sambut': 299,
#  'lari': 300,
#  'lampung': 301,
#  'bro': 302,
#  'suka': 303,
#  'keren': 304,
#  'salam': 305,
#  'jari': 306,
#  'lupa': 307,
#  'pilih': 308,
#  'bismillah': 309,
#  'kursi': 310,
#  'terlibat': 311,
#  'masuk': 312,
#  'sel': 313,
#  'monyet': 314,
#  'luhut': 315,
#  'binsar': 316,
#  'mencuci': 317,
#  'songong': 318,
#  'matikan': 319,
#  'harga': 320,
#  'bahan': 321,
#  'bbm': 322,
#  'hidup': 323,
#  'jaya': 324,
#  'tolak': 325,
#  'interupsi': 326,
#  'rapat': 327,
#  'pengesahan': 328,
#  'ruu': 329,
#  'aduh': 330,
#  'sm': 331,
#  'sholat': 332,
#  'maghrib': 333,
#  'personil': 334,
#  'band': 335,
#  'mencalonkan': 336,
#  'gubernur': 337,
#  'pilkada': 338,
#  'pas': 339,
#  'pasang': 340,
#  'baliho': 341,
#  'memainkan': 342,
#  'identitas': 343,
#  'tanda': 344,
#  'terkenal': 345,
#  'kelakuannya': 346,
#  'rejeki': 347,
#  'mengalir': 348,
#  'sungai': 349,
#  'makasih': 350,
#  'menteri': 351,
#  'beserta': 352,
#  'rombongan': 353,
#  'kunjungan': 354,
#  'kehormatan': 355,
#  'klaten': 356,
#  'kehadiran': 357,
#  'tamu': 358,
#  'istimewa': 359,
#  'kamis': 360,
#  'berkah': 361,
#  'wisma': 362,
#  'atlit': 363,
#  'korupsi': 364,
#  'candi': 365,
#  'memindahkan': 366,
#  'negara': 367,
#  'pakde': 368,
#  'jokowi': 369,
#  'kecewa': 370,
#  'bupati': 371,
#  'maluku': 372,
#  'kapolda': 373,
#  'bantuan': 374,
#  'bantu': 375,
#  'desa': 376,
#  'tanggapan': 377,
#  'keadilan': 378,
#  'tanggung': 379,
#  'terbakar': 380,
#  'kek': 381,
#  'lee': 382,
#  'senang': 383,
#  'sepeda': 384,
#  'perempuan': 385,
#  'vaksin': 386,
#  'ria': 387,
#  'sia': 388,
#  'inti': 389,
#  'periode': 390,
#  'diam': 391,
#  'sebelah': 392,
#  'mata': 393,
#  'pedagang': 394,
#  'pasar': 395,
#  'dibakar': 396,
#  'senjata': 397,
#  'api': 398,
#  'kepedulian': 399,
#  'uang': 400,
#  'sebelas': 401,
#  'ribu': 402,
#  'triliun': 403,
#  'utang': 404,
#  'kantong': 405,
#  'garing': 406,
#  'protes': 407,
#  'krisis': 408,
#  'ekonomi': 409,
#  'ibukota': 410,
#  'nampak': 411,
#  'becus': 412,
#  'ni': 413,
#  'kaleng': 414,
#  'kejang': 415,
#  'silakan': 416,
#  'bodo': 417,
#  'ampe': 418,
#  'jual': 419,
#  'kapal': 420,
#  'perang': 421,
#  'dana': 422,
#  'mah': 423,
#  'korup': 424,
#  'kuat': 425,
#  'bejibun': 426,
#  'bangkrut': 427,
#  'nih': 428,
#  'biji': 429,
#  'yuk': 430,
#  'melek': 431,
#  'digital': 432,
#  'pemerintahan': 433,
#  'berdaulat': 434,
#  'penuh': 435,
#  'udara': 436,
#  'kawasan': 437,
#  'natuna': 438,
#  'kepulauan': 439,
#  'riau': 440,
#  'menghina': 441,
#  'dayak': 442,
#  'pro': 443,
#  'tersinggung': 444,
#  'pendukung': 445,
#  'bego': 446,
#  'wni': 447,
#  'singapura': 448,
#  'lucu': 449,
#  'cah': 450,
#  'pintar': 451,
#  'mengumpulkan': 452,
#  'data': 453,
#  'menyusun': 454,
#  'musuh': 455,
#  'tuh': 456,
#  'ambon': 457,
#  'rusuh': 458,
#  'bahas': 459,
#  'papua': 460,
#  'kemarin': 461,
#  'sadar': 462,
#  'paman': 463,
#  'kebohongan': 464,
#  '11000': 465,
#  'saku': 466,
#  'keuangan': 467,
#  'bpk': 468,
#  'kembaran': 469,
#  'mohon': 470,
#  'formalitas': 471,
#  'mendengar': 472,
#  'bapa': 473,
#  'woi': 474,
#  'dl': 475,
#  'umur': 476,
#  'video': 477,
#  'tua': 478,
#  'widodo': 479,
#  'raih': 480,
#  'kemenangan': 481,
#  'tips': 482,
#  'sukses': 483,
#  'era': 484,
#  'jilat': 485,
#  'radikal': 486,
#  'salah': 487,
#  'terealisasi': 488,
#  'gua': 489,
#  'salut': 490,
#  'sih': 491,
#  'pk': 492,
#  'infrastruktur': 493,
#  'menjalankan': 494,
#  'kasihan': 495,
#  'mundur': 496,
#  'menaikkan': 497,
#  'tagar': 498,
#  'hernia': 499,
#  'tangan': 500,
#  'analogi': 501,
#  'rancang': 502,
#  'kang': 503,
#  'semrawut': 504,
#  'kaum': 505,
#  'cebong': 506,
#  'menganggap': 507,
#  'jujur': 508,
#  'paksa': 509,
#  'parahiyangan': 510,
#  'banten': 511,
#  'sindir': 512,
#  'dugaan': 513,
#  'tunggak': 514,
#  'pajak': 515,
#  'dokter': 516,
#  'eva': 517,
#  'hoi': 518,
#  'tobat': 519,
#  'dusta': 520,
#  'citra': 521,
#  'aib': 522,
#  'bongkar': 523,
#  'mengorbankan': 524,
#  'oknum': 525,
#  'kepolisian': 526,
#  'nomor': 527,
#  'normal': 528,
#  'negeri': 529,
#  'politisi': 530,
#  'prestasi': 531,
#  'debat': 532,
#  'pamer': 533,
#  'kedegilan': 534,
#  'bergaya': 535,
#  'rasisme': 536,
#  'iya': 537,
#  'anies': 538,
#  'baswedan': 539,
#  'cek': 540,
#  'proyek': 541,
#  'sumur': 542,
#  'resapan': 543,
#  'tutup': 544,
#  't': 545,
#  'urus': 546,
#  'jogja': 547,
#  'berpihak': 548,
#  'kelas': 549,
#  'sehat': 550,
#  'berkarya': 551,
#  'ayo': 552,
#  'bangkit': 553,
#  'rasyid': 554,
#  'berbahasa': 555,
#  'inggris': 556,
#  'penerjemah': 557,
#  'cocok': 558,
#  'pa': 559,
#  'maju': 560,
#  'berkuasa': 561,
#  'ketemu': 562,
#  'kampanye': 563,
#  'jakarta': 564,
#  'tokoh': 565,
#  'kagum': 566,
#  'kepribadian': 567,
#  'terucap': 568,
#  'tersusun': 569,
#  'rapih': 570,
#  'makna': 571,
#  'senantiasa': 572,
#  'melindungi': 573,
#  'zalim': 574,
#  '😠': 575,
#  'untung': 576,
#  'nama': 577,
#  'doyan': 578,
#  'klaim': 579,
#  'penghargaan': 580,
#  'kinerja': 581,
#  'pimpin': 582,
#  'mimpi': 583,
#  'amburadul': 584,
#  'program': 585,
#  'kegiatan': 586,
#  'kenal': 587,
#  'julukan': 588,
#  'bodoh': 589,
#  'amanah': 590,
#  'bersyukur': 591,
#  'tumbal': 592,
#  'periksa': 593,
#  'relawan': 594,
#  'biang': 595,
#  'kerok': 596,
#  'ujaran': 597,
#  'kebencian': 598,
#  'warga': 599,
#  'bergerak': 600,
#  'dukungan': 601,
#  'sukabumi': 602,
#  'mendukung': 603,
#  'nkri': 604,
#  'duet': 605,
#  'muda': 606,
#  'cerdas': 607,
#  'patriotisme': 608,
#  'bangsa': 609,
#  'sejahtera': 610,
#  'kemendagri': 611,
#  'mengizinkan': 612,
#  'wan': 613,
#  'abud': 614,
#  'patut': 615,
#  'waspada': 616,
#  'pergerakan': 617,
#  'malu': 618,
#  'kapolri': 619,
#  'kayak': 620,
#  'pencitraan': 621,
#  'dg': 622,
#  'berhasil': 623,
#  'stadion': 624,
#  'najis': 625,
#  'senyap': 626,
#  'banjir': 627,
#  'bergemuruh': 628,
#  'hujan': 629,
#  'gue': 630,
#  'narasi': 631,
#  'instruksi': 632,
#  'kontribusi': 633,
#  'tukang': 634,
#  'sapu': 635,
#  'jalanan': 636,
#  'puas': 637,
#  '%': 638,
#  'bugis': 639,
#  'contoh': 640,
#  'kepemimpinan': 641,
#  'tingkat': 642,
#  'latar': 643,
#  'sisi': 644,
#  'terbaik': 645,
#  'ngerti': 646,
#  'berpikir': 647,
#  'buang': 648,
#  'duit': 649,
#  'puluhan': 650,
#  'miliar': 651,
#  'hambur': 652,
#  'rencana': 653,
#  'matang': 654,
#  'terkesan': 655,
#  'apresiasi': 656,
#  'melanjutkan': 657,
#  'penataan': 658,
#  'allah': 659,
#  'menjadikan': 660,
#  'takdir': 661,
#  'slogan': 662,
#  'bohong': 663,
#  'keras': 664,
#  'menyuarakan': 665,
#  'abas': 666,
#  'pikir': 667,
#  'payah': 668,
#  'cemen': 669,
#  'edi': 670,
#  'mulyadi': 671,
#  'tunggu': 672,
#  '2': 673,
#  'jam': 674,
#  'adik': 675,
#  'belajar': 676,
#  'pendidikan': 677,
#  'banget': 678,
#  'merendahkan': 679,
#  'sekian': 680,
#  'terima': 681,
#  'dadah': 682,
#  'provokator': 683,
#  'pemecah': 684,
#  'belah': 685,
#  'cinta': 686,
#  'damai': 687,
#  'sembunyi': 688,
#  'meja': 689,
#  'ketakutan': 690,
#  'bawa': 691,
#  'aliansi': 692,
#  'borneo': 693,
#  'panggil': 694,
#  'ayam': 695,
#  'sayur': 696,
#  'sungguh': 697,
#  'ironis': 698,
#  'memalukan': 699,
#  'wajar': 700,
#  'teror': 701,
#  'sampah': 702,
#  'd': 703,
#  'kapok': 704,
#  'membela': 705,
#  'terjaga': 706,
#  'pengecut': 707,
#  'kantor': 708,
#  'asosiasi': 709,
#  'perajin': 710,
#  'pengusaha': 711,
#  'batik': 712,
#  'murka': 713,
#  'gegara': 714,
#  'berjiwa': 715,
#  'klarifikasi': 716,
#  'mengancam': 717,
#  'g': 718,
#  'jaminan': 719,
#  'bagus': 720,
#  'sportif': 721,
#  'jantan': 722,
#  'suci': 723,
#  'amin': 724,
#  'perwakilan': 725,
#  'jin': 726,
#  'setan': 727,
#  'kuntilanak': 728,
#  'cermat': 729,
#  'demo': 730,
#  'pasukan': 731,
#  'mending': 732,
#  'telepon': 733,
#  'samper': 734,
#  'mandau': 735,
#  'terbang': 736,
#  'membayangkan': 737,
#  'kl': 738,
#  'mengadili': 739,
#  'islam': 740,
#  'menolak': 741,
#  'saudara': 742,
#  'tuduh': 743,
#  'anak': 744,
#  'lapor': 745,
#  'ancam': 746,
#  'keberanian': 747,
#  'sebatas': 748,
#  'bacot': 749,
#  'makan': 750,
#  'mati': 751,
#  'berdiri': 752,
#  'sahabat': 753,
#  'mu': 754,
#  'harimau': 755,
#  'mangkanya': 756,
#  'jaga': 757,
#  'sok': 758,
#  'tu': 759,
#  'menghadapi': 760,
#  'ribut': 761,
#  'ku': 762,
#  'kehilangan': 763,
#  'kekayaan': 764,
#  'alam': 765,
#  'menjemput': 766,
#  'repot': 767,
#  'soto': 768,
#  'gosong': 769,
#  'ruko': 770,
#  'bp': 771,
#  'sepenggal': 772,
#  'terhindar': 773,
#  'malapetaka': 774,
#  'proses': 775,
#  'melawan': 776,
#  'rezim': 777,
#  'gagal': 778,
#  'legislatif': 779,
#  'ketawa': 780,
#  'giliran': 781,
#  'ciut': 782,
#  'bau': 783,
#  'ketek': 784,
#  'wajib': 785,
#  'tata': 786,
#  'adad': 787,
#  'setuju': 788,
#  'tangkap': 789,
#  'penyebar': 790,
#  'muncul': 791,
#  'kanal': 792,
#  'youtube': 793,
#  'tahan': 794,
#  'berbahaya': 795,
#  'emosi': 796,
#  'lengah': 797,
#  'dikit': 798,
#  'nyawa': 799,
#  'taruhan': 800,
#  'tinggal': 801,
#  'laknat': 802,
#  'kejam': 803,
#  'mengaku': 804,
#  'gerombolan': 805,
#  'waras': 806,
#  'benci': 807,
#  'adil': 808,
#  'mampus': 809,
#  'perlahan': 810,
#  'menunggu': 811,
#  'azam': 812,
#  'bunuh': 813,
#  'tahi': 814,
#  'setimpal': 815,
#  'ampun': 816,
#  'bineka': 817,
#  'tunggal': 818,
#  'mendoakan': 819,
#  'asam': 820,
#  'bui': 821,
#  'perkataan': 822,
#  'kesalahan': 823,
#  'kosa': 824,
#  'saking': 825,
#  'memperhatikan': 826,
#  'maksud': 827,
#  'berdampak': 828,
#  'menyuruh': 829,
#  'menyakitkan': 830,
#  'hati': 831,
#  'penasaran': 832,
#  'nyenyak': 833,
#  'buruk': 834,
#  'bola': 835,
#  'perkembangan': 836,
#  'lepas': 837,
#  'gemetar': 838,
#  'aneh': 839,
#  'krn': 840,
#  'sikap': 841,
#  'berseberangan': 842,
#  'ancaman': 843,
#  'hukuman': 844,
#  'berlagak': 845,
#  'gila': 846,
#  'melecehkan': 847,
#  'profesi': 848,
#  'wartawan': 849,
#  'berlindung': 850,
#  'dng': 851,
#  'pers': 852,
#  'niat': 853,
#  'jerat': 854,
#  'provokasi': 855,
#  'bangsat': 856,
#  'kedatangan': 857,
#  'pecundang': 858,
#  'lihat': 859,
#  'ditampar': 860,
#  'penjara': 861,
#  'menerima': 862,
#  'ajar': 863,
#  'beban': 864,
#  'moral': 865,
#  'menebar': 866,
#  'hinaan': 867,
#  'bebas': 868,
#  'sprt': 869,
#  'kekalutan': 870,
#  'cuman': 871,
#  'omong': 872,
#  'gadis': 873,
#  'cantik': 874,
#  'gini': 875,
#  'kontol': 876,
#  'genderuwo': 877,
#  'parah': 878,
#  'bang': 879,
#  'titip': 880,
#  'telinga': 881,
#  'kosong': 882,
#  'giring': 883,
#  'otak': 884,
#  'mengajari': 885,
#  'toleransi': 886,
#  'sejati': 887,
#  'psi': 888,
#  'ente': 889,
#  'habis': 890,
#  'loh': 891,
#  'sibuk': 892,
#  'mengurus': 893,
#  'kunci': 894,
#  'kebanyakan': 895,
#  'beda': 896,
#  'bungkam': 897,
#  'serangan': 898,
#  'nyaman': 899,
#  'kebenaran': 900,
#  'ko': 901,
#  'kritisi': 902,
#  'menjilat': 903,
#  'penguasa': 904,
#  'laku': 905,
#  'bentar': 906,
#  'tabungan': 907,
#  'biaya': 908,
#  'menandai': 909,
#  'ring': 910,
#  'muka': 911,
#  'jelek': 912,
#  'kelakuan': 913,
#  'mengawasi': 914,
#  'berhenti': 915,
#  'berulah': 916,
#  'petugas': 917,
#  'konsultasi': 918,
#  'kepala': 919,
#  'mampet': 920,
#  '😊': 921,
#  'cerita': 922,
#  'eksploitasi': 923,
#  'nyanyi': 924,
#  'ganti': 925,
#  'kuliah': 926,
#  'tamat': 927,
#  'etika': 928,
#  'lurah': 929,
#  'hansip': 930,
#  'generasi': 931,
#  'milenial': 932,
#  'kemampuan': 933,
#  'miris': 934,
#  'iba': 935,
#  'kondisi': 936,
#  'janji': 937,
#  'caleg': 938,
#  'kodok': 939,
#  'tar': 940,
#  'ketinggian': 941,
#  'halusinasi': 942,
#  'firaun': 943,
#  'gam': 944,
#  'menjijikkan': 945,
#  'berkoar': 946,
#  'eks': 947,
#  'vokalis': 948,
#  'asbun': 949,
#  'asbut': 950,
#  'kebodohan': 951,
#  'kutipan': 952,
#  'sistem': 953,
#  'dunia': 954,
#  '1498084016561410049': 955,
#  'memperalat': 956,
#  'paham': 957,
#  'celah': 958,
#  'praktek': 959,
#  'mafia': 960,
#  'peradilan': 961,
#  '2022': 962,
#  '27': 963,
#  '00': 964,
#  'otoriter': 965,
#  'pemerintah': 966,
#  'berubah': 967,
#  'perekonomian': 968,
#  'mencekik': 969,
#  'kawal': 970,
#  'jalan': 971,
#  'lelah': 972,
#  'teman': 973,
#  'gatel': 974,
#  'nyali': 975,
#  'ih': 976,
#  '\xad': 977,
#  'sosial': 978,
#  'halo': 979,
#  'de': 980,
#  'kebaikan': 981,
#  'pembenci': 982,
#  'kelompok': 983,
#  'alias': 984,
#  'menyalahkan': 985,
#  'amit': 986,
#  'akumulasi': 987,
#  'hutang': 988,
#  'percaya': 989,
#  'menghentikan': 990,
#  'jenis': 991,
#  'bumi': 992,
#  'bangga': 993,
#  'merasakan': 994,
#  'susilo': 995,
#  'bambang': 996,
#  'yudhoyono': 997,
#  '1498083653020454912': 998,
#  'keluarga': 999,
#  ...}

# %%
# Menampilkan Dict id2word
id_2_word = glove_model.show_id2word()
id_2_word
# Out:
# {0: 'kawan',
#  1: 'sunda',
#  2: 'bersatu',
#  3: 'jemput',
#  4: 'arteria',
#  5: 'dahlan',
#  6: '😁',
#  7: 'sidang',
#  8: 'adat',
#  9: 'daerah',
#  10: 'menuntut',
#  11: 'hukum',
#  12: 'ga',
#  13: 'tafsir',
#  14: 'membanding',
#  15: 'membandingkan',
#  16: 'edy',
#  17: 'menegakkan',
#  18: 'divisi',
#  19: 'humas',
#  20: 'polri',
#  21: 'bilang',
#  22: 'palsu',
#  23: 'mengeluarkan',
#  24: 'membenarkan',
#  25: 'plat',
#  26: 'no',
#  27: 'asli',
#  28: 'urut',
#  29: 'dada',
#  30: 'deh',
#  31: 'kuasa',
#  32: 'mengerti',
#  33: 'tsb',
#  34: 'dengar',
#  35: 'pendapat',
#  36: 'gedung',
#  37: 'dpr',
#  38: 'memiliki',
#  39: 'kekebalan',
#  40: 'atur',
#  41: 'konstitusi',
#  42: 'n',
#  43: 'uu',
#  44: 'maaf',
#  45: 'memaafkan',
#  46: 'kubu',
#  47: 'saran',
#  48: 'dorong',
#  49: 'masyarakat',
#  50: 'jabar',
#  51: 'menangkap',
#  52: 'semoga',
#  53: 'berpegang',
#  54: 'komitmen',
#  55: 'menenggelamkan',
#  56: 'partai',
#  57: 'demokrasi',
#  58: 'indonesia',
#  59: 'perjuangan',
#  60: 'spt',
#  61: 'sumbar',
#  62: 'beruntung',
#  63: 'kabar',
#  64: 'e',
#  65: 'hina',
#  66: 'suku',
#  67: 'pejabat',
#  68: 'sakit',
#  69: 'jiwa',
#  70: 'menantang',
#  71: 'goblok',
#  72: 'rakyat',
#  73: 'turun',
#  74: 'kelar',
#  75: 'provinsi',
#  76: 'manusia',
#  77: 'pasteur',
#  78: 'bandung',
#  79: 'mulut',
#  80: 'busuk',
#  81: 'acara',
#  82: 'resmi',
#  83: 'pakai',
#  84: 'bahasa',
#  85: 'tp',
#  86: 'penyelenggaraan',
#  87: 'sanksi',
#  88: 'memecat',
#  89: 'congkak',
#  90: 'arogan',
#  91: 'yak',
#  92: 'coba',
#  93: 'mas',
#  94: 'kali',
#  95: 'mendadak',
#  96: 'mengganti',
#  97: 'mak',
#  98: 'bangun',
#  99: 'cerdik',
#  100: 'tamparan',
#  101: 'lu',
#  102: 'polisi',
#  103: 'terdaftar',
#  104: 'milik',
#  105: 'emang',
#  106: 'gemas',
#  107: 'ama',
#  108: 'elu',
#  109: 'takut',
#  110: 'doang',
#  111: '1',
#  112: 'gitu',
#  113: 'memperbaiki',
#  114: 'butuh',
#  115: 'suara',
#  116: '2024',
#  117: 'kau',
#  118: 'injakan',
#  119: 'kaki',
#  120: 'tanah',
#  121: 'komentar',
#  122: 'jahat',
#  123: 'pernyataan',
#  124: 'berbicara',
#  125: 'pecat',
#  126: 'bikin',
#  127: 'kena',
#  128: 'mental',
#  129: 'orang',
#  130: 'hajat',
#  131: 'pernikahan',
#  132: 'undang',
#  133: 'kusnandar',
#  134: 'cari',
#  135: 'guru',
#  136: 'santet',
#  137: 'jumawa',
#  138: 'kritik',
#  139: 'membangun',
#  140: 'hotel',
#  141: 'jawa',
#  142: 'barat',
#  143: 'minimal',
#  144: 'kasih',
#  145: 'kupon',
#  146: 'menginap',
#  147: 'gratis',
#  148: 'malam',
#  149: 'liat',
#  150: 'berani',
#  151: 'kagak',
#  152: 'silaturahmi',
#  153: 'beliau',
#  154: 'tuan',
#  155: 'terhormat',
#  156: 'cepat',
#  157: 'menikah',
#  158: 'dah',
#  159: 'rt',
#  160: 'bantai',
#  161: 'p',
#  162: 'perkosa',
#  163: 'puan',
#  164: 'maharani',
#  165: 'biar',
#  166: 'miskin',
#  167: 'rindu',
#  168: 'mikropon',
#  169: 'aja',
#  170: 'calon',
#  171: 'presiden',
#  172: 'cawapres',
#  173: 'menang',
#  174: 'lumayan',
#  175: 'pemimpin',
#  176: 'otorita',
#  177: 'kota',
#  178: 'bincang',
#  179: 'manis',
#  180: 'sosok',
#  181: 'semangat',
#  182: 'bu',
#  183: 'baca',
#  184: 'berita',
#  185: 'beras',
#  186: 'foto',
#  187: 'ah',
#  188: 'pos',
#  189: 'isi',
#  190: 'kerjaan',
#  191: 'w',
#  192: 'kaya',
#  193: 'ibuk',
#  194: 'maunya',
#  195: 'cipta',
#  196: 'kerja',
#  197: 'sahkan',
#  198: 'bayangkan',
#  199: 'coklat',
#  200: 'valentine',
#  201: 'gambar',
#  202: 'gatal',
#  203: 'ajak',
#  204: 'dialog',
#  205: 'rajin',
#  206: 'monolog',
#  207: 'pegang',
#  208: 'eman',
#  209: 'kecerdasan',
#  210: 'terkikis',
#  211: 'nikmat',
#  212: 'kekuasaan',
#  213: 'pemegang',
#  214: 'melahirkan',
#  215: 'celaka',
#  216: 'menyediakan',
#  217: 'ruang',
#  218: 'kangen',
#  219: 'konten',
#  220: 'akun',
#  221: 'drama',
#  222: 'megawati',
#  223: 'soekarno',
#  224: 'putri',
#  225: 'capres',
#  226: 'berpasangan',
#  227: 'prabowo',
#  228: 'subianto',
#  229: 'mintak',
#  230: 'rumah',
#  231: 'kalimantan',
#  232: 'timur',
#  233: 'tipe',
#  234: 'ac',
#  235: 'wifi',
#  236: 'tidur',
#  237: 'televisi',
#  238: 'angkat',
#  239: 'ketua',
#  240: 'main',
#  241: 'tau',
#  242: 'politik',
#  243: 'kotor',
#  244: 'rada',
#  245: 'susah',
#  246: 'kalo',
#  247: 'ridwan',
#  248: 'kamil',
#  249: 'adu',
#  250: 'mematikan',
#  251: 'kader',
#  252: 'produsen',
#  253: 'koruptor',
#  254: 'membagikan',
#  255: 'kaos',
#  256: 'memunculkan',
#  257: 'kerumunan',
#  258: 'virus',
#  259: 'khawatir',
#  260: 'membanggakan',
#  261: 'dukung',
#  262: 'menelusuri',
#  263: 'urusan',
#  264: 'tembakau',
#  265: 'mega',
#  266: 'ambil',
#  267: 'laporan',
#  268: 'sekolah',
#  269: 'seh',
#  270: 'pindah',
#  271: 'yah',
#  272: 'muak',
#  273: 'penjilat',
#  274: 'ganjar',
#  275: 'asu',
#  276: 'selamat',
#  277: 'ulang',
#  278: 'meneruskan',
#  279: 'cita',
#  280: 'doa',
#  281: 'kekuatan',
#  282: 'regenerasi',
#  283: 'berjalan',
#  284: 'mbak',
#  285: 'lonjakan',
#  286: 'masker',
#  287: 'lantai',
#  288: 'dasar',
#  289: 'rame',
#  290: 'pujian',
#  291: 'sindiran',
#  292: 'elite',
#  293: 'demokrat',
#  294: 'menjabat',
#  295: 'ri',
#  296: 'jateng',
#  297: 'sambit',
#  298: 'eh',
#  299: 'sambut',
#  300: 'lari',
#  301: 'lampung',
#  302: 'bro',
#  303: 'suka',
#  304: 'keren',
#  305: 'salam',
#  306: 'jari',
#  307: 'lupa',
#  308: 'pilih',
#  309: 'bismillah',
#  310: 'kursi',
#  311: 'terlibat',
#  312: 'masuk',
#  313: 'sel',
#  314: 'monyet',
#  315: 'luhut',
#  316: 'binsar',
#  317: 'mencuci',
#  318: 'songong',
#  319: 'matikan',
#  320: 'harga',
#  321: 'bahan',
#  322: 'bbm',
#  323: 'hidup',
#  324: 'jaya',
#  325: 'tolak',
#  326: 'interupsi',
#  327: 'rapat',
#  328: 'pengesahan',
#  329: 'ruu',
#  330: 'aduh',
#  331: 'sm',
#  332: 'sholat',
#  333: 'maghrib',
#  334: 'personil',
#  335: 'band',
#  336: 'mencalonkan',
#  337: 'gubernur',
#  338: 'pilkada',
#  339: 'pas',
#  340: 'pasang',
#  341: 'baliho',
#  342: 'memainkan',
#  343: 'identitas',
#  344: 'tanda',
#  345: 'terkenal',
#  346: 'kelakuannya',
#  347: 'rejeki',
#  348: 'mengalir',
#  349: 'sungai',
#  350: 'makasih',
#  351: 'menteri',
#  352: 'beserta',
#  353: 'rombongan',
#  354: 'kunjungan',
#  355: 'kehormatan',
#  356: 'klaten',
#  357: 'kehadiran',
#  358: 'tamu',
#  359: 'istimewa',
#  360: 'kamis',
#  361: 'berkah',
#  362: 'wisma',
#  363: 'atlit',
#  364: 'korupsi',
#  365: 'candi',
#  366: 'memindahkan',
#  367: 'negara',
#  368: 'pakde',
#  369: 'jokowi',
#  370: 'kecewa',
#  371: 'bupati',
#  372: 'maluku',
#  373: 'kapolda',
#  374: 'bantuan',
#  375: 'bantu',
#  376: 'desa',
#  377: 'tanggapan',
#  378: 'keadilan',
#  379: 'tanggung',
#  380: 'terbakar',
#  381: 'kek',
#  382: 'lee',
#  383: 'senang',
#  384: 'sepeda',
#  385: 'perempuan',
#  386: 'vaksin',
#  387: 'ria',
#  388: 'sia',
#  389: 'inti',
#  390: 'periode',
#  391: 'diam',
#  392: 'sebelah',
#  393: 'mata',
#  394: 'pedagang',
#  395: 'pasar',
#  396: 'dibakar',
#  397: 'senjata',
#  398: 'api',
#  399: 'kepedulian',
#  400: 'uang',
#  401: 'sebelas',
#  402: 'ribu',
#  403: 'triliun',
#  404: 'utang',
#  405: 'kantong',
#  406: 'garing',
#  407: 'protes',
#  408: 'krisis',
#  409: 'ekonomi',
#  410: 'ibukota',
#  411: 'nampak',
#  412: 'becus',
#  413: 'ni',
#  414: 'kaleng',
#  415: 'kejang',
#  416: 'silakan',
#  417: 'bodo',
#  418: 'ampe',
#  419: 'jual',
#  420: 'kapal',
#  421: 'perang',
#  422: 'dana',
#  423: 'mah',
#  424: 'korup',
#  425: 'kuat',
#  426: 'bejibun',
#  427: 'bangkrut',
#  428: 'nih',
#  429: 'biji',
#  430: 'yuk',
#  431: 'melek',
#  432: 'digital',
#  433: 'pemerintahan',
#  434: 'berdaulat',
#  435: 'penuh',
#  436: 'udara',
#  437: 'kawasan',
#  438: 'natuna',
#  439: 'kepulauan',
#  440: 'riau',
#  441: 'menghina',
#  442: 'dayak',
#  443: 'pro',
#  444: 'tersinggung',
#  445: 'pendukung',
#  446: 'bego',
#  447: 'wni',
#  448: 'singapura',
#  449: 'lucu',
#  450: 'cah',
#  451: 'pintar',
#  452: 'mengumpulkan',
#  453: 'data',
#  454: 'menyusun',
#  455: 'musuh',
#  456: 'tuh',
#  457: 'ambon',
#  458: 'rusuh',
#  459: 'bahas',
#  460: 'papua',
#  461: 'kemarin',
#  462: 'sadar',
#  463: 'paman',
#  464: 'kebohongan',
#  465: '11000',
#  466: 'saku',
#  467: 'keuangan',
#  468: 'bpk',
#  469: 'kembaran',
#  470: 'mohon',
#  471: 'formalitas',
#  472: 'mendengar',
#  473: 'bapa',
#  474: 'woi',
#  475: 'dl',
#  476: 'umur',
#  477: 'video',
#  478: 'tua',
#  479: 'widodo',
#  480: 'raih',
#  481: 'kemenangan',
#  482: 'tips',
#  483: 'sukses',
#  484: 'era',
#  485: 'jilat',
#  486: 'radikal',
#  487: 'salah',
#  488: 'terealisasi',
#  489: 'gua',
#  490: 'salut',
#  491: 'sih',
#  492: 'pk',
#  493: 'infrastruktur',
#  494: 'menjalankan',
#  495: 'kasihan',
#  496: 'mundur',
#  497: 'menaikkan',
#  498: 'tagar',
#  499: 'hernia',
#  500: 'tangan',
#  501: 'analogi',
#  502: 'rancang',
#  503: 'kang',
#  504: 'semrawut',
#  505: 'kaum',
#  506: 'cebong',
#  507: 'menganggap',
#  508: 'jujur',
#  509: 'paksa',
#  510: 'parahiyangan',
#  511: 'banten',
#  512: 'sindir',
#  513: 'dugaan',
#  514: 'tunggak',
#  515: 'pajak',
#  516: 'dokter',
#  517: 'eva',
#  518: 'hoi',
#  519: 'tobat',
#  520: 'dusta',
#  521: 'citra',
#  522: 'aib',
#  523: 'bongkar',
#  524: 'mengorbankan',
#  525: 'oknum',
#  526: 'kepolisian',
#  527: 'nomor',
#  528: 'normal',
#  529: 'negeri',
#  530: 'politisi',
#  531: 'prestasi',
#  532: 'debat',
#  533: 'pamer',
#  534: 'kedegilan',
#  535: 'bergaya',
#  536: 'rasisme',
#  537: 'iya',
#  538: 'anies',
#  539: 'baswedan',
#  540: 'cek',
#  541: 'proyek',
#  542: 'sumur',
#  543: 'resapan',
#  544: 'tutup',
#  545: 't',
#  546: 'urus',
#  547: 'jogja',
#  548: 'berpihak',
#  549: 'kelas',
#  550: 'sehat',
#  551: 'berkarya',
#  552: 'ayo',
#  553: 'bangkit',
#  554: 'rasyid',
#  555: 'berbahasa',
#  556: 'inggris',
#  557: 'penerjemah',
#  558: 'cocok',
#  559: 'pa',
#  560: 'maju',
#  561: 'berkuasa',
#  562: 'ketemu',
#  563: 'kampanye',
#  564: 'jakarta',
#  565: 'tokoh',
#  566: 'kagum',
#  567: 'kepribadian',
#  568: 'terucap',
#  569: 'tersusun',
#  570: 'rapih',
#  571: 'makna',
#  572: 'senantiasa',
#  573: 'melindungi',
#  574: 'zalim',
#  575: '😠',
#  576: 'untung',
#  577: 'nama',
#  578: 'doyan',
#  579: 'klaim',
#  580: 'penghargaan',
#  581: 'kinerja',
#  582: 'pimpin',
#  583: 'mimpi',
#  584: 'amburadul',
#  585: 'program',
#  586: 'kegiatan',
#  587: 'kenal',
#  588: 'julukan',
#  589: 'bodoh',
#  590: 'amanah',
#  591: 'bersyukur',
#  592: 'tumbal',
#  593: 'periksa',
#  594: 'relawan',
#  595: 'biang',
#  596: 'kerok',
#  597: 'ujaran',
#  598: 'kebencian',
#  599: 'warga',
#  600: 'bergerak',
#  601: 'dukungan',
#  602: 'sukabumi',
#  603: 'mendukung',
#  604: 'nkri',
#  605: 'duet',
#  606: 'muda',
#  607: 'cerdas',
#  608: 'patriotisme',
#  609: 'bangsa',
#  610: 'sejahtera',
#  611: 'kemendagri',
#  612: 'mengizinkan',
#  613: 'wan',
#  614: 'abud',
#  615: 'patut',
#  616: 'waspada',
#  617: 'pergerakan',
#  618: 'malu',
#  619: 'kapolri',
#  620: 'kayak',
#  621: 'pencitraan',
#  622: 'dg',
#  623: 'berhasil',
#  624: 'stadion',
#  625: 'najis',
#  626: 'senyap',
#  627: 'banjir',
#  628: 'bergemuruh',
#  629: 'hujan',
#  630: 'gue',
#  631: 'narasi',
#  632: 'instruksi',
#  633: 'kontribusi',
#  634: 'tukang',
#  635: 'sapu',
#  636: 'jalanan',
#  637: 'puas',
#  638: '%',
#  639: 'bugis',
#  640: 'contoh',
#  641: 'kepemimpinan',
#  642: 'tingkat',
#  643: 'latar',
#  644: 'sisi',
#  645: 'terbaik',
#  646: 'ngerti',
#  647: 'berpikir',
#  648: 'buang',
#  649: 'duit',
#  650: 'puluhan',
#  651: 'miliar',
#  652: 'hambur',
#  653: 'rencana',
#  654: 'matang',
#  655: 'terkesan',
#  656: 'apresiasi',
#  657: 'melanjutkan',
#  658: 'penataan',
#  659: 'allah',
#  660: 'menjadikan',
#  661: 'takdir',
#  662: 'slogan',
#  663: 'bohong',
#  664: 'keras',
#  665: 'menyuarakan',
#  666: 'abas',
#  667: 'pikir',
#  668: 'payah',
#  669: 'cemen',
#  670: 'edi',
#  671: 'mulyadi',
#  672: 'tunggu',
#  673: '2',
#  674: 'jam',
#  675: 'adik',
#  676: 'belajar',
#  677: 'pendidikan',
#  678: 'banget',
#  679: 'merendahkan',
#  680: 'sekian',
#  681: 'terima',
#  682: 'dadah',
#  683: 'provokator',
#  684: 'pemecah',
#  685: 'belah',
#  686: 'cinta',
#  687: 'damai',
#  688: 'sembunyi',
#  689: 'meja',
#  690: 'ketakutan',
#  691: 'bawa',
#  692: 'aliansi',
#  693: 'borneo',
#  694: 'panggil',
#  695: 'ayam',
#  696: 'sayur',
#  697: 'sungguh',
#  698: 'ironis',
#  699: 'memalukan',
#  700: 'wajar',
#  701: 'teror',
#  702: 'sampah',
#  703: 'd',
#  704: 'kapok',
#  705: 'membela',
#  706: 'terjaga',
#  707: 'pengecut',
#  708: 'kantor',
#  709: 'asosiasi',
#  710: 'perajin',
#  711: 'pengusaha',
#  712: 'batik',
#  713: 'murka',
#  714: 'gegara',
#  715: 'berjiwa',
#  716: 'klarifikasi',
#  717: 'mengancam',
#  718: 'g',
#  719: 'jaminan',
#  720: 'bagus',
#  721: 'sportif',
#  722: 'jantan',
#  723: 'suci',
#  724: 'amin',
#  725: 'perwakilan',
#  726: 'jin',
#  727: 'setan',
#  728: 'kuntilanak',
#  729: 'cermat',
#  730: 'demo',
#  731: 'pasukan',
#  732: 'mending',
#  733: 'telepon',
#  734: 'samper',
#  735: 'mandau',
#  736: 'terbang',
#  737: 'membayangkan',
#  738: 'kl',
#  739: 'mengadili',
#  740: 'islam',
#  741: 'menolak',
#  742: 'saudara',
#  743: 'tuduh',
#  744: 'anak',
#  745: 'lapor',
#  746: 'ancam',
#  747: 'keberanian',
#  748: 'sebatas',
#  749: 'bacot',
#  750: 'makan',
#  751: 'mati',
#  752: 'berdiri',
#  753: 'sahabat',
#  754: 'mu',
#  755: 'harimau',
#  756: 'mangkanya',
#  757: 'jaga',
#  758: 'sok',
#  759: 'tu',
#  760: 'menghadapi',
#  761: 'ribut',
#  762: 'ku',
#  763: 'kehilangan',
#  764: 'kekayaan',
#  765: 'alam',
#  766: 'menjemput',
#  767: 'repot',
#  768: 'soto',
#  769: 'gosong',
#  770: 'ruko',
#  771: 'bp',
#  772: 'sepenggal',
#  773: 'terhindar',
#  774: 'malapetaka',
#  775: 'proses',
#  776: 'melawan',
#  777: 'rezim',
#  778: 'gagal',
#  779: 'legislatif',
#  780: 'ketawa',
#  781: 'giliran',
#  782: 'ciut',
#  783: 'bau',
#  784: 'ketek',
#  785: 'wajib',
#  786: 'tata',
#  787: 'adad',
#  788: 'setuju',
#  789: 'tangkap',
#  790: 'penyebar',
#  791: 'muncul',
#  792: 'kanal',
#  793: 'youtube',
#  794: 'tahan',
#  795: 'berbahaya',
#  796: 'emosi',
#  797: 'lengah',
#  798: 'dikit',
#  799: 'nyawa',
#  800: 'taruhan',
#  801: 'tinggal',
#  802: 'laknat',
#  803: 'kejam',
#  804: 'mengaku',
#  805: 'gerombolan',
#  806: 'waras',
#  807: 'benci',
#  808: 'adil',
#  809: 'mampus',
#  810: 'perlahan',
#  811: 'menunggu',
#  812: 'azam',
#  813: 'bunuh',
#  814: 'tahi',
#  815: 'setimpal',
#  816: 'ampun',
#  817: 'bineka',
#  818: 'tunggal',
#  819: 'mendoakan',
#  820: 'asam',
#  821: 'bui',
#  822: 'perkataan',
#  823: 'kesalahan',
#  824: 'kosa',
#  825: 'saking',
#  826: 'memperhatikan',
#  827: 'maksud',
#  828: 'berdampak',
#  829: 'menyuruh',
#  830: 'menyakitkan',
#  831: 'hati',
#  832: 'penasaran',
#  833: 'nyenyak',
#  834: 'buruk',
#  835: 'bola',
#  836: 'perkembangan',
#  837: 'lepas',
#  838: 'gemetar',
#  839: 'aneh',
#  840: 'krn',
#  841: 'sikap',
#  842: 'berseberangan',
#  843: 'ancaman',
#  844: 'hukuman',
#  845: 'berlagak',
#  846: 'gila',
#  847: 'melecehkan',
#  848: 'profesi',
#  849: 'wartawan',
#  850: 'berlindung',
#  851: 'dng',
#  852: 'pers',
#  853: 'niat',
#  854: 'jerat',
#  855: 'provokasi',
#  856: 'bangsat',
#  857: 'kedatangan',
#  858: 'pecundang',
#  859: 'lihat',
#  860: 'ditampar',
#  861: 'penjara',
#  862: 'menerima',
#  863: 'ajar',
#  864: 'beban',
#  865: 'moral',
#  866: 'menebar',
#  867: 'hinaan',
#  868: 'bebas',
#  869: 'sprt',
#  870: 'kekalutan',
#  871: 'cuman',
#  872: 'omong',
#  873: 'gadis',
#  874: 'cantik',
#  875: 'gini',
#  876: 'kontol',
#  877: 'genderuwo',
#  878: 'parah',
#  879: 'bang',
#  880: 'titip',
#  881: 'telinga',
#  882: 'kosong',
#  883: 'giring',
#  884: 'otak',
#  885: 'mengajari',
#  886: 'toleransi',
#  887: 'sejati',
#  888: 'psi',
#  889: 'ente',
#  890: 'habis',
#  891: 'loh',
#  892: 'sibuk',
#  893: 'mengurus',
#  894: 'kunci',
#  895: 'kebanyakan',
#  896: 'beda',
#  897: 'bungkam',
#  898: 'serangan',
#  899: 'nyaman',
#  900: 'kebenaran',
#  901: 'ko',
#  902: 'kritisi',
#  903: 'menjilat',
#  904: 'penguasa',
#  905: 'laku',
#  906: 'bentar',
#  907: 'tabungan',
#  908: 'biaya',
#  909: 'menandai',
#  910: 'ring',
#  911: 'muka',
#  912: 'jelek',
#  913: 'kelakuan',
#  914: 'mengawasi',
#  915: 'berhenti',
#  916: 'berulah',
#  917: 'petugas',
#  918: 'konsultasi',
#  919: 'kepala',
#  920: 'mampet',
#  921: '😊',
#  922: 'cerita',
#  923: 'eksploitasi',
#  924: 'nyanyi',
#  925: 'ganti',
#  926: 'kuliah',
#  927: 'tamat',
#  928: 'etika',
#  929: 'lurah',
#  930: 'hansip',
#  931: 'generasi',
#  932: 'milenial',
#  933: 'kemampuan',
#  934: 'miris',
#  935: 'iba',
#  936: 'kondisi',
#  937: 'janji',
#  938: 'caleg',
#  939: 'kodok',
#  940: 'tar',
#  941: 'ketinggian',
#  942: 'halusinasi',
#  943: 'firaun',
#  944: 'gam',
#  945: 'menjijikkan',
#  946: 'berkoar',
#  947: 'eks',
#  948: 'vokalis',
#  949: 'asbun',
#  950: 'asbut',
#  951: 'kebodohan',
#  952: 'kutipan',
#  953: 'sistem',
#  954: 'dunia',
#  955: '1498084016561410049',
#  956: 'memperalat',
#  957: 'paham',
#  958: 'celah',
#  959: 'praktek',
#  960: 'mafia',
#  961: 'peradilan',
#  962: '2022',
#  963: '27',
#  964: '00',
#  965: 'otoriter',
#  966: 'pemerintah',
#  967: 'berubah',
#  968: 'perekonomian',
#  969: 'mencekik',
#  970: 'kawal',
#  971: 'jalan',
#  972: 'lelah',
#  973: 'teman',
#  974: 'gatel',
#  975: 'nyali',
#  976: 'ih',
#  977: '\xad',
#  978: 'sosial',
#  979: 'halo',
#  980: 'de',
#  981: 'kebaikan',
#  982: 'pembenci',
#  983: 'kelompok',
#  984: 'alias',
#  985: 'menyalahkan',
#  986: 'amit',
#  987: 'akumulasi',
#  988: 'hutang',
#  989: 'percaya',
#  990: 'menghentikan',
#  991: 'jenis',
#  992: 'bumi',
#  993: 'bangga',
#  994: 'merasakan',
#  995: 'susilo',
#  996: 'bambang',
#  997: 'yudhoyono',
#  998: '1498083653020454912',
#  999: 'keluarga',
#  ...}

# %%
# Menampilkan Dict word2count
word_2_count = glove_model.show_word2count()
word_2_count
# Out:
# {'kawan': 40,
#  'sunda': 19,
#  'bersatu': 14,
#  'jemput': 7,
#  'arteria': 35,
#  'dahlan': 31,
#  '😁': 492,
#  'sidang': 4,
#  'adat': 18,
#  'daerah': 45,
#  'menuntut': 6,
#  'hukum': 55,
#  'ga': 187,
#  'tafsir': 2,
#  'membanding': 1,
#  'membandingkan': 12,
#  'edy': 29,
#  'menegakkan': 8,
#  'divisi': 1,
#  'humas': 1,
#  'polri': 9,
#  'bilang': 63,
#  'palsu': 10,
#  'mengeluarkan': 4,
#  'membenarkan': 4,
#  'plat': 4,
#  'no': 16,
#  'asli': 38,
#  'urut': 1,
#  'dada': 2,
#  'deh': 32,
#  'kuasa': 9,
#  'mengerti': 10,
#  'tsb': 19,
#  'dengar': 12,
#  'pendapat': 9,
#  'gedung': 5,
#  'dpr': 64,
#  'memiliki': 53,
#  'kekebalan': 1,
#  'atur': 15,
#  'konstitusi': 11,
#  'n': 47,
#  'uu': 16,
#  'maaf': 67,
#  'memaafkan': 5,
#  'kubu': 38,
#  'saran': 7,
#  'dorong': 2,
#  'masyarakat': 171,
#  'jabar': 6,
#  'menangkap': 3,
#  'semoga': 207,
#  'berpegang': 2,
#  'komitmen': 22,
#  'menenggelamkan': 3,
#  'partai': 321,
#  'demokrasi': 130,
#  'indonesia': 475,
#  'perjuangan': 123,
#  'spt': 24,
#  'sumbar': 1,
#  'beruntung': 14,
#  'kabar': 17,
#  'e': 23,
#  'hina': 13,
#  'suku': 10,
#  'pejabat': 58,
#  'sakit': 28,
#  'jiwa': 33,
#  'menantang': 3,
#  'goblok': 46,
#  'rakyat': 322,
#  'turun': 39,
#  'kelar': 2,
#  'provinsi': 7,
#  'manusia': 71,
#  'pasteur': 1,
#  'bandung': 16,
#  'mulut': 26,
#  'busuk': 10,
#  'acara': 44,
#  'resmi': 12,
#  'pakai': 62,
#  'bahasa': 18,
#  'tp': 62,
#  'penyelenggaraan': 12,
#  'sanksi': 9,
#  'memecat': 1,
#  'congkak': 1,
#  'arogan': 3,
#  'yak': 7,
#  'coba': 50,
#  'mas': 55,
#  'kali': 66,
#  'mendadak': 13,
#  'mengganti': 6,
#  'mak': 6,
#  'bangun': 28,
#  'cerdik': 2,
#  'tamparan': 1,
#  'lu': 82,
#  'polisi': 27,
#  'terdaftar': 1,
#  'milik': 10,
#  'emang': 63,
#  'gemas': 2,
#  'ama': 23,
#  'elu': 23,
#  'takut': 50,
#  'doang': 32,
#  '1': 103,
#  'gitu': 47,
#  'memperbaiki': 12,
#  'butuh': 28,
#  'suara': 39,
#  '2024': 148,
#  'kau': 50,
#  'injakan': 1,
#  'kaki': 12,
#  'tanah': 21,
#  'komentar': 22,
#  'jahat': 6,
#  'pernyataan': 48,
#  'berbicara': 60,
#  'pecat': 18,
#  'bikin': 79,
#  'kena': 29,
#  'mental': 11,
#  'orang': 417,
#  'hajat': 8,
#  'pernikahan': 5,
#  'undang': 9,
#  'kusnandar': 1,
#  'cari': 49,
#  'guru': 9,
#  'santet': 2,
#  'jumawa': 2,
#  'kritik': 12,
#  'membangun': 59,
#  'hotel': 8,
#  'jawa': 47,
#  'barat': 26,
#  'minimal': 7,
#  'kasih': 52,
#  'kupon': 2,
#  'menginap': 1,
#  'gratis': 12,
#  'malam': 15,
#  'liat': 34,
#  'berani': 60,
#  'kagak': 7,
#  'silaturahmi': 8,
#  'beliau': 112,
#  'tuan': 20,
#  'terhormat': 10,
#  'cepat': 19,
#  'menikah': 5,
#  'dah': 39,
#  'rt': 75,
#  'bantai': 3,
#  'p': 16,
#  'perkosa': 2,
#  'puan': 414,
#  'maharani': 289,
#  'biar': 83,
#  'miskin': 25,
#  'rindu': 1,
#  'mikropon': 15,
#  'aja': 204,
#  'calon': 152,
#  'presiden': 401,
#  'cawapres': 40,
#  'menang': 37,
#  'lumayan': 7,
#  'pemimpin': 229,
#  'otorita': 1,
#  'kota': 37,
#  'bincang': 4,
#  'manis': 13,
#  'sosok': 60,
#  'semangat': 59,
#  'bu': 267,
#  'baca': 32,
#  'berita': 32,
#  'beras': 15,
#  'foto': 25,
#  'ah': 8,
#  'pos': 1,
#  'isi': 23,
#  'kerjaan': 11,
#  'w': 3,
#  'kaya': 47,
#  'ibuk': 7,
#  'maunya': 3,
#  'cipta': 1,
#  'kerja': 127,
#  'sahkan': 1,
#  'bayangkan': 4,
#  'coklat': 1,
#  'valentine': 1,
#  'gambar': 8,
#  'gatal': 1,
#  'ajak': 11,
#  'dialog': 2,
#  'rajin': 5,
#  'monolog': 2,
#  'pegang': 8,
#  'eman': 1,
#  'kecerdasan': 2,
#  'terkikis': 1,
#  'nikmat': 2,
#  'kekuasaan': 21,
#  'pemegang': 3,
#  'melahirkan': 4,
#  'celaka': 1,
#  'menyediakan': 4,
#  'ruang': 16,
#  'kangen': 3,
#  'konten': 4,
#  'akun': 19,
#  'drama': 22,
#  'megawati': 26,
#  'soekarno': 22,
#  'putri': 12,
#  'capres': 106,
#  'berpasangan': 5,
#  'prabowo': 235,
#  'subianto': 53,
#  'mintak': 1,
#  'rumah': 60,
#  'kalimantan': 38,
#  'timur': 11,
#  'tipe': 2,
#  'ac': 1,
#  'wifi': 1,
#  'tidur': 17,
#  'televisi': 1,
#  'angkat': 10,
#  'ketua': 142,
#  'main': 36,
#  'tau': 72,
#  'politik': 136,
#  'kotor': 7,
#  'rada': 4,
#  'susah': 24,
#  'kalo': 143,
#  'ridwan': 13,
#  'kamil': 9,
#  'adu': 4,
#  'mematikan': 4,
#  'kader': 32,
#  'produsen': 2,
#  'koruptor': 39,
#  'membagikan': 24,
#  'kaos': 41,
#  'memunculkan': 3,
#  'kerumunan': 3,
#  'virus': 34,
#  'khawatir': 9,
#  'membanggakan': 4,
#  'dukung': 68,
#  'menelusuri': 1,
#  'urusan': 35,
#  'tembakau': 3,
#  'mega': 21,
#  'ambil': 23,
#  'laporan': 10,
#  'sekolah': 19,
#  'seh': 1,
#  'pindah': 11,
#  'yah': 19,
#  'muak': 7,
#  'penjilat': 19,
#  'ganjar': 239,
#  'asu': 2,
#  'selamat': 30,
#  'ulang': 8,
#  'meneruskan': 7,
#  'cita': 14,
#  'doa': 18,
#  'kekuatan': 10,
#  'regenerasi': 2,
#  'berjalan': 15,
#  'mbak': 126,
#  'lonjakan': 5,
#  'masker': 7,
#  'lantai': 3,
#  'dasar': 17,
#  'rame': 10,
#  'pujian': 4,
#  'sindiran': 1,
#  'elite': 4,
#  'demokrat': 22,
#  'menjabat': 15,
#  'ri': 85,
#  'jateng': 20,
#  'sambit': 1,
#  'eh': 7,
#  'sambut': 4,
#  'lari': 3,
#  'lampung': 1,
#  'bro': 20,
#  'suka': 76,
#  'keren': 76,
#  'salam': 20,
#  'jari': 4,
#  'lupa': 20,
#  'pilih': 77,
#  'bismillah': 9,
#  'kursi': 7,
#  'terlibat': 2,
#  'masuk': 68,
#  'sel': 1,
#  'monyet': 10,
#  'luhut': 631,
#  'binsar': 393,
#  'mencuci': 1,
#  'songong': 2,
#  'matikan': 6,
#  'harga': 33,
#  'bahan': 12,
#  'bbm': 13,
#  'hidup': 66,
#  'jaya': 11,
#  'tolak': 31,
#  'interupsi': 1,
#  'rapat': 8,
#  'pengesahan': 1,
#  'ruu': 3,
#  'aduh': 7,
#  'sm': 23,
#  'sholat': 1,
#  'maghrib': 1,
#  'personil': 1,
#  'band': 5,
#  'mencalonkan': 15,
#  'gubernur': 74,
#  'pilkada': 6,
#  'pas': 33,
#  'pasang': 9,
#  'baliho': 5,
#  'memainkan': 5,
#  'identitas': 21,
#  'tanda': 7,
#  'terkenal': 3,
#  'kelakuannya': 1,
#  'rejeki': 1,
#  'mengalir': 4,
#  'sungai': 10,
#  'makasih': 36,
#  'menteri': 233,
#  'beserta': 4,
#  'rombongan': 4,
#  'kunjungan': 28,
#  'kehormatan': 4,
#  'klaten': 2,
#  'kehadiran': 8,
#  'tamu': 5,
#  'istimewa': 1,
#  'kamis': 12,
#  'berkah': 14,
#  'wisma': 1,
#  'atlit': 2,
#  'korupsi': 50,
#  'candi': 2,
#  'memindahkan': 1,
#  'negara': 181,
#  'pakde': 11,
#  'jokowi': 405,
#  'kecewa': 14,
#  'bupati': 6,
#  'maluku': 4,
#  'kapolda': 1,
#  'bantuan': 41,
#  'bantu': 11,
#  'desa': 26,
#  'tanggapan': 6,
#  'keadilan': 42,
#  'tanggung': 14,
#  'terbakar': 2,
#  'kek': 9,
#  'lee': 1,
#  'senang': 28,
#  'sepeda': 5,
#  'perempuan': 41,
#  'vaksin': 20,
#  'ria': 1,
#  'sia': 5,
#  'inti': 17,
#  'periode': 28,
#  'diam': 38,
#  'sebelah': 5,
#  'mata': 36,
#  'pedagang': 3,
#  'pasar': 10,
#  'dibakar': 4,
#  'senjata': 10,
#  'api': 9,
#  'kepedulian': 14,
#  'uang': 47,
#  'sebelas': 1,
#  'ribu': 6,
#  'triliun': 7,
#  'utang': 29,
#  'kantong': 3,
#  'garing': 1,
#  'protes': 5,
#  'krisis': 3,
#  'ekonomi': 25,
#  'ibukota': 4,
#  'nampak': 4,
#  'becus': 7,
#  'ni': 21,
#  'kaleng': 4,
#  'kejang': 8,
#  'silakan': 30,
#  'bodo': 1,
#  'ampe': 2,
#  'jual': 11,
#  'kapal': 6,
#  'perang': 16,
#  'dana': 13,
#  'mah': 30,
#  'korup': 7,
#  'kuat': 20,
#  'bejibun': 3,
#  'bangkrut': 3,
#  'nih': 75,
#  'biji': 3,
#  'yuk': 11,
#  'melek': 2,
#  'digital': 5,
#  'pemerintahan': 20,
#  'berdaulat': 6,
#  'penuh': 46,
#  'udara': 3,
#  'kawasan': 2,
#  'natuna': 1,
#  'kepulauan': 4,
#  'riau': 2,
#  'menghina': 18,
#  'dayak': 8,
#  'pro': 10,
#  'tersinggung': 4,
#  'pendukung': 40,
#  'bego': 18,
#  'wni': 3,
#  'singapura': 1,
#  'lucu': 127,
#  'cah': 1,
#  'pintar': 42,
#  'mengumpulkan': 2,
#  'data': 24,
#  'menyusun': 3,
#  'musuh': 14,
#  'tuh': 44,
#  'ambon': 1,
#  'rusuh': 2,
#  'bahas': 12,
#  'papua': 17,
#  'kemarin': 25,
#  'sadar': 26,
#  'paman': 29,
#  'kebohongan': 12,
#  '11000': 1,
#  'saku': 1,
#  'keuangan': 9,
#  'bpk': 29,
#  'kembaran': 2,
#  'mohon': 14,
#  'formalitas': 1,
#  'mendengar': 12,
#  'bapa': 3,
#  'woi': 4,
#  'dl': 5,
#  'umur': 9,
#  'video': 42,
#  'tua': 25,
#  'widodo': 21,
#  'raih': 5,
#  'kemenangan': 11,
#  'tips': 1,
#  'sukses': 36,
#  'era': 25,
#  'jilat': 3,
#  'radikal': 15,
#  'salah': 120,
#  'terealisasi': 2,
#  'gua': 19,
#  'salut': 12,
#  'sih': 99,
#  'pk': 12,
#  'infrastruktur': 13,
#  'menjalankan': 14,
#  'kasihan': 28,
#  'mundur': 14,
#  'menaikkan': 7,
#  'tagar': 8,
#  'hernia': 1,
#  'tangan': 39,
#  'analogi': 4,
#  'rancang': 6,
#  'kang': 9,
#  'semrawut': 2,
#  'kaum': 24,
#  'cebong': 19,
#  'menganggap': 2,
#  'jujur': 28,
#  'paksa': 14,
#  'parahiyangan': 1,
#  'banten': 1,
#  'sindir': 2,
#  'dugaan': 9,
#  'tunggak': 1,
#  'pajak': 13,
#  'dokter': 4,
#  'eva': 1,
#  'hoi': 2,
#  'tobat': 2,
#  'dusta': 3,
#  'citra': 16,
#  'aib': 2,
#  'bongkar': 7,
#  'mengorbankan': 6,
#  'oknum': 6,
#  'kepolisian': 2,
#  'nomor': 6,
#  'normal': 4,
#  'negeri': 77,
#  'politisi': 46,
#  'prestasi': 50,
#  'debat': 15,
#  'pamer': 18,
#  'kedegilan': 2,
#  'bergaya': 5,
#  'rasisme': 4,
#  'iya': 35,
#  'anies': 309,
#  'baswedan': 186,
#  'cek': 16,
#  'proyek': 27,
#  'sumur': 10,
#  'resapan': 11,
#  'tutup': 6,
#  't': 4,
#  'urus': 18,
#  'jogja': 7,
#  'berpihak': 5,
#  'kelas': 17,
#  'sehat': 65,
#  'berkarya': 4,
#  'ayo': 30,
#  'bangkit': 7,
#  'rasyid': 4,
#  'berbahasa': 2,
#  'inggris': 7,
#  'penerjemah': 2,
#  'cocok': 94,
#  'pa': 36,
#  'maju': 65,
#  'berkuasa': 17,
#  'ketemu': 19,
#  'kampanye': 13,
#  'jakarta': 144,
#  'tokoh': 37,
#  'kagum': 12,
#  'kepribadian': 5,
#  'terucap': 2,
#  'tersusun': 3,
#  'rapih': 3,
#  'makna': 7,
#  'senantiasa': 4,
#  'melindungi': 21,
#  'zalim': 11,
#  '😠': 434,
#  'untung': 12,
#  'nama': 117,
#  'doyan': 3,
#  'klaim': 8,
#  'penghargaan': 17,
#  'kinerja': 21,
#  'pimpin': 29,
#  'mimpi': 45,
#  'amburadul': 8,
#  'program': 91,
#  'kegiatan': 21,
#  'kenal': 11,
#  'julukan': 3,
#  'bodoh': 44,
#  'amanah': 12,
#  'bersyukur': 8,
#  'tumbal': 4,
#  'periksa': 8,
#  'relawan': 26,
#  'biang': 9,
#  'kerok': 6,
#  'ujaran': 3,
#  'kebencian': 8,
#  'warga': 65,
#  'bergerak': 4,
#  'dukungan': 41,
#  'sukabumi': 2,
#  'mendukung': 53,
#  'nkri': 49,
#  'duet': 25,
#  'muda': 50,
#  'cerdas': 26,
#  'patriotisme': 2,
#  'bangsa': 142,
#  'sejahtera': 32,
#  'kemendagri': 2,
#  'mengizinkan': 2,
#  'wan': 28,
#  'abud': 5,
#  'patut': 17,
#  'waspada': 11,
#  'pergerakan': 5,
#  'malu': 47,
#  'kapolri': 4,
#  'kayak': 56,
#  'pencitraan': 61,
#  'dg': 79,
#  'berhasil': 13,
#  'stadion': 19,
#  'najis': 19,
#  'senyap': 3,
#  'banjir': 14,
#  'bergemuruh': 2,
#  'hujan': 16,
#  'gue': 30,
#  'narasi': 15,
#  'instruksi': 4,
#  'kontribusi': 5,
#  'tukang': 17,
#  'sapu': 4,
#  'jalanan': 4,
#  'puas': 7,
#  '%': 32,
#  'bugis': 2,
#  'contoh': 47,
#  'kepemimpinan': 28,
#  'tingkat': 20,
#  'latar': 6,
#  'sisi': 4,
#  'terbaik': 48,
#  'ngerti': 14,
#  'berpikir': 18,
#  'buang': 15,
#  'duit': 20,
#  'puluhan': 5,
#  'miliar': 4,
#  'hambur': 1,
#  'rencana': 13,
#  'matang': 4,
#  'terkesan': 3,
#  'apresiasi': 7,
#  'melanjutkan': 24,
#  'penataan': 1,
#  'allah': 57,
#  'menjadikan': 33,
#  'takdir': 5,
#  'slogan': 4,
#  'bohong': 76,
#  'keras': 11,
#  'menyuarakan': 8,
#  'abas': 2,
#  'pikir': 45,
#  'payah': 6,
#  'cemen': 8,
#  'edi': 88,
#  'mulyadi': 106,
#  'tunggu': 15,
#  '2': 2,
#  'jam': 12,
#  'adik': 5,
#  'belajar': 32,
#  'pendidikan': 52,
#  'banget': 129,
#  'merendahkan': 6,
#  'sekian': 7,
#  'terima': 30,
#  'dadah': 10,
#  'provokator': 2,
#  'pemecah': 3,
#  'belah': 7,
#  'cinta': 36,
#  'damai': 10,
#  'sembunyi': 18,
#  'meja': 2,
#  'ketakutan': 6,
#  'bawa': 20,
#  'aliansi': 1,
#  'borneo': 1,
#  'panggil': 8,
#  'ayam': 3,
#  'sayur': 2,
#  'sungguh': 10,
#  'ironis': 1,
#  'memalukan': 5,
#  'wajar': 17,
#  'teror': 5,
#  'sampah': 20,
#  'd': 30,
#  'kapok': 4,
#  'membela': 20,
#  'terjaga': 2,
#  'pengecut': 12,
#  'kantor': 9,
#  'asosiasi': 1,
#  'perajin': 1,
#  'pengusaha': 8,
#  'batik': 3,
#  'murka': 6,
#  'gegara': 6,
#  'berjiwa': 4,
#  'klarifikasi': 5,
#  'mengancam': 1,
#  'g': 21,
#  'jaminan': 1,
#  'bagus': 71,
#  'sportif': 1,
#  'jantan': 7,
#  'suci': 14,
#  'amin': 37,
#  'perwakilan': 4,
#  'jin': 14,
#  'setan': 15,
#  'kuntilanak': 1,
#  'cermat': 3,
#  'demo': 13,
#  'pasukan': 15,
#  'mending': 40,
#  'telepon': 4,
#  'samper': 2,
#  'mandau': 2,
#  'terbang': 4,
#  'membayangkan': 4,
#  'kl': 33,
#  'mengadili': 6,
#  'islam': 48,
#  'menolak': 57,
#  'saudara': 16,
#  'tuduh': 5,
#  'anak': 155,
#  'lapor': 10,
#  'ancam': 7,
#  'keberanian': 5,
#  'sebatas': 6,
#  'bacot': 39,
#  'makan': 36,
#  'mati': 32,
#  'berdiri': 9,
#  'sahabat': 36,
#  'mu': 36,
#  'harimau': 3,
#  'mangkanya': 2,
#  'jaga': 19,
#  'sok': 24,
#  'tu': 13,
#  'menghadapi': 15,
#  'ribut': 8,
#  'ku': 15,
#  'kehilangan': 9,
#  'kekayaan': 12,
#  'alam': 14,
#  'menjemput': 5,
#  'repot': 5,
#  'soto': 2,
#  'gosong': 2,
#  'ruko': 2,
#  'bp': 14,
#  'sepenggal': 2,
#  'terhindar': 4,
#  'malapetaka': 2,
#  'proses': 19,
#  'melawan': 22,
#  'rezim': 31,
#  'gagal': 27,
#  'legislatif': 3,
#  'ketawa': 10,
#  'giliran': 9,
#  'ciut': 2,
#  'bau': 7,
#  'ketek': 2,
#  'wajib': 20,
#  'tata': 18,
#  'adad': 2,
#  'setuju': 48,
#  'tangkap': 38,
#  'penyebar': 3,
#  'muncul': 14,
#  'kanal': 4,
#  'youtube': 8,
#  'tahan': 11,
#  'berbahaya': 7,
#  'emosi': 2,
#  'lengah': 4,
#  'dikit': 7,
#  'nyawa': 8,
#  'taruhan': 5,
#  'tinggal': 21,
#  'laknat': 5,
#  'kejam': 6,
#  'mengaku': 23,
#  'gerombolan': 11,
#  'waras': 12,
#  'benci': 10,
#  'adil': 8,
#  'mampus': 6,
#  'perlahan': 2,
#  'menunggu': 13,
#  'azam': 2,
#  'bunuh': 12,
#  'tahi': 18,
#  'setimpal': 2,
#  'ampun': 5,
#  'bineka': 6,
#  'tunggal': 6,
#  'mendoakan': 13,
#  'asam': 3,
#  'bui': 3,
#  'perkataan': 6,
#  'kesalahan': 13,
#  'kosa': 2,
#  'saking': 10,
#  'memperhatikan': 10,
#  'maksud': 20,
#  'berdampak': 8,
#  'menyuruh': 3,
#  'menyakitkan': 2,
#  'hati': 59,
#  'penasaran': 2,
#  'nyenyak': 3,
#  'buruk': 24,
#  'bola': 32,
#  'perkembangan': 3,
#  'lepas': 16,
#  'gemetar': 2,
#  'aneh': 9,
#  'krn': 59,
#  'sikap': 25,
#  'berseberangan': 4,
#  'ancaman': 5,
#  'hukuman': 3,
#  'berlagak': 7,
#  'gila': 14,
#  'melecehkan': 4,
#  'profesi': 3,
#  'wartawan': 6,
#  'berlindung': 6,
#  'dng': 6,
#  'pers': 5,
#  'niat': 8,
#  'jerat': 2,
#  'provokasi': 4,
#  'bangsat': 44,
#  'kedatangan': 11,
#  'pecundang': 8,
#  'lihat': 65,
#  'ditampar': 2,
#  'penjara': 13,
#  'menerima': 23,
#  'ajar': 6,
#  'beban': 9,
#  'moral': 4,
#  'menebar': 6,
#  'hinaan': 2,
#  'bebas': 31,
#  'sprt': 7,
#  'kekalutan': 9,
#  'cuman': 15,
#  'omong': 14,
#  'gadis': 2,
#  'cantik': 22,
#  'gini': 31,
#  'kontol': 4,
#  'genderuwo': 2,
#  'parah': 17,
#  'bang': 29,
#  'titip': 5,
#  'telinga': 4,
#  'kosong': 17,
#  'giring': 4,
#  'otak': 44,
#  'mengajari': 4,
#  'toleransi': 5,
#  'sejati': 8,
#  'psi': 11,
#  'ente': 20,
#  'habis': 31,
#  'loh': 21,
#  'sibuk': 14,
#  'mengurus': 5,
#  'kunci': 8,
#  'kebanyakan': 24,
#  'beda': 47,
#  'bungkam': 5,
#  'serangan': 3,
#  'nyaman': 5,
#  'kebenaran': 34,
#  'ko': 12,
#  'kritisi': 4,
#  'menjilat': 8,
#  'penguasa': 20,
#  'laku': 13,
#  'bentar': 2,
#  'tabungan': 3,
#  'biaya': 17,
#  'menandai': 8,
#  'ring': 8,
#  'muka': 40,
#  'jelek': 20,
#  'kelakuan': 8,
#  'mengawasi': 5,
#  'berhenti': 6,
#  'berulah': 2,
#  'petugas': 19,
#  'konsultasi': 3,
#  'kepala': 29,
#  'mampet': 2,
#  '😊': 323,
#  'cerita': 26,
#  'eksploitasi': 2,
#  'nyanyi': 5,
#  'ganti': 18,
#  'kuliah': 10,
#  'tamat': 3,
#  'etika': 3,
#  'lurah': 5,
#  'hansip': 2,
#  'generasi': 32,
#  'milenial': 7,
#  'kemampuan': 18,
#  'miris': 2,
#  'iba': 2,
#  'kondisi': 14,
#  'janji': 25,
#  'caleg': 6,
#  'kodok': 4,
#  'tar': 6,
#  'ketinggian': 3,
#  'halusinasi': 7,
#  'firaun': 120,
#  'gam': 2,
#  'menjijikkan': 6,
#  'berkoar': 4,
#  'eks': 4,
#  'vokalis': 3,
#  'asbun': 3,
#  'asbut': 2,
#  'kebodohan': 7,
#  'kutipan': 4,
#  'sistem': 10,
#  'dunia': 85,
#  '1498084016561410049': 1,
#  'memperalat': 2,
#  'paham': 43,
#  'celah': 3,
#  'praktek': 6,
#  'mafia': 4,
#  'peradilan': 2,
#  '2022': 41,
#  '27': 10,
#  '00': 24,
#  'otoriter': 4,
#  'pemerintah': 70,
#  'berubah': 14,
#  'perekonomian': 7,
#  'mencekik': 2,
#  'kawal': 17,
#  'jalan': 59,
#  'lelah': 3,
#  'teman': 19,
#  'gatel': 2,
#  'nyali': 8,
#  'ih': 2,
#  '\xad': 3,
#  'sosial': 35,
#  'halo': 12,
#  'de': 2,
#  'kebaikan': 14,
#  'pembenci': 10,
#  'kelompok': 25,
#  'alias': 18,
#  'menyalahkan': 12,
#  'amit': 7,
#  'akumulasi': 2,
#  'hutang': 26,
#  'percaya': 34,
#  'menghentikan': 7,
#  'jenis': 5,
#  'bumi': 13,
#  'bangga': 30,
#  'merasakan': 14,
#  'susilo': 11,
#  'bambang': 17,
#  'yudhoyono': 44,
#  '1498083653020454912': 2,
#  'keluarga': 55,
#  ...}

# %%
# Menampilkan hasil dari Cooccurence Matrix
co_matrix = glove_model.show_comatrix()

co_matrix

# %%
# # Generate image Matrix Coocurrence
# generateCooMatrix = glove_model.generate_coomatrix_image()

# generateCooMatrix

# %%
word_embeddings = glove_model.get_embeddings('😁')

print(word_embeddings)
# Out:
# {'😁': array([ 1.72645141e-01,  1.71961818e-01, -3.73728948e-01, -9.87215801e-02,
#        -1.65630300e-01,  3.53403565e-02, -1.13989931e-01, -4.13518879e-04,
#         2.03586811e-02,  2.08648730e-01, -2.28418170e-01,  2.21924810e-01,
#         1.27003214e-01, -2.24139276e-01,  2.12033890e-01,  2.50670914e-01,
#        -2.74668844e-01,  3.65106566e-02,  4.63040180e-01, -7.15745470e-02,
#        -9.38696518e-02,  6.13933602e-02,  1.21242208e-02, -3.39973347e-01,
#        -1.77595772e-01,  1.72527504e-01, -1.83191871e-01,  3.81987463e-01,
#         8.89362484e-02, -7.24733172e-02, -1.83640962e-01, -1.94120072e-01,
#        -9.94743823e-02,  2.23597988e-01, -9.49098061e-02, -1.98927905e-01,
#        -1.79419053e-01,  1.35371998e-01, -6.73529118e-02, -8.57824847e-02,
#         1.35596207e-01, -8.98471000e-04, -2.80628501e-01,  3.38253533e-02,
#        -9.55979106e-02,  9.48067895e-02,  3.42090082e-02, -1.14943440e-01,
#         8.82328337e-02, -1.61705073e-01, -5.45124060e-02, -3.18995974e-02,
#         2.97581927e-02, -3.46186990e-02, -2.13967010e-01, -7.05757284e-02,
#        -2.28965820e-01, -5.53060849e-02,  5.38889551e-03,  1.58934599e-01,
#        -2.82352777e-01,  1.40580152e-01,  9.76782794e-03,  7.46100458e-03,
#         5.68067370e-02,  3.35791157e-01,  1.47321957e-01,  4.51583116e-02,
#        -2.20237190e-01, -5.14270843e-02,  1.93145575e-01,  3.18174611e-01,
#         1.93918270e-01, -5.37282667e-02, -1.79921109e-01,  3.68499839e-01,
#         4.88383878e-02,  1.26073631e-01, -9.36659927e-02,  2.10571851e-01,
#        -4.74714005e-01,  3.18732673e-01, -5.87637507e-01,  7.13869515e-02,
#        -2.66105709e-01,  3.63122032e-01, -3.90355354e-01,  4.62448845e-01,
#        -1.88285295e-01, -1.31763533e-01,  5.69446476e-02,  1.39791833e-01,
#        -8.35210809e-03, -3.68777247e-02, -3.61662525e-04,  4.31043048e-01,
#         7.64737437e-02,  2.79609153e-01, -1.03703404e-01, -1.88202494e-02,
#        -2.64399533e-01, -8.38335118e-02,  2.53278120e-03, -2.74260682e-02,
#         1.16611191e-02,  2.81326268e-01, -4.49873566e-01,  1.13453645e-01,
#        -2.17835115e-02,  3.44571629e-01, -1.88325009e-01, -9.54369916e-02,
#        -9.29806072e-03, -3.64546761e-02, -1.78912882e-01, -3.71232857e-01,
#         4.07699875e-02,  3.15443091e-01, -8.20905899e-02, -2.74761739e-02,
#        -1.83793595e-01, -1.65000057e-01, -2.00108264e-01, -2.48476026e-01,
#         7.87888602e-02,  9.83462317e-02, -2.70384687e-01, -1.40752042e-01,
#         1.51346746e-01,  1.27162362e-01, -3.37853735e-01,  2.99594091e-01,
#        -1.53496682e-01,  1.65707152e-01, -3.25847822e-01,  8.18829936e-02,
#         7.59193762e-02,  3.76332224e-02,  4.43322234e-02,  3.34299634e-01,
#         1.87030572e-01, -2.19893227e-01,  8.09021520e-02,  1.26761974e-01,
#        -1.77642909e-01, -6.53616683e-02,  3.67894632e-01, -6.91586371e-02,
#        -1.10954647e-01, -1.96058616e-01])}

# %%
embedding_by_id = glove_model.get_embeddings_by_id(6)

embedding_by_id
# Out:
# array([ 1.72645141e-01,  1.71961818e-01, -3.73728948e-01, -9.87215801e-02,
#        -1.65630300e-01,  3.53403565e-02, -1.13989931e-01, -4.13518879e-04,
#         2.03586811e-02,  2.08648730e-01, -2.28418170e-01,  2.21924810e-01,
#         1.27003214e-01, -2.24139276e-01,  2.12033890e-01,  2.50670914e-01,
#        -2.74668844e-01,  3.65106566e-02,  4.63040180e-01, -7.15745470e-02,
#        -9.38696518e-02,  6.13933602e-02,  1.21242208e-02, -3.39973347e-01,
#        -1.77595772e-01,  1.72527504e-01, -1.83191871e-01,  3.81987463e-01,
#         8.89362484e-02, -7.24733172e-02, -1.83640962e-01, -1.94120072e-01,
#        -9.94743823e-02,  2.23597988e-01, -9.49098061e-02, -1.98927905e-01,
#        -1.79419053e-01,  1.35371998e-01, -6.73529118e-02, -8.57824847e-02,
#         1.35596207e-01, -8.98471000e-04, -2.80628501e-01,  3.38253533e-02,
#        -9.55979106e-02,  9.48067895e-02,  3.42090082e-02, -1.14943440e-01,
#         8.82328337e-02, -1.61705073e-01, -5.45124060e-02, -3.18995974e-02,
#         2.97581927e-02, -3.46186990e-02, -2.13967010e-01, -7.05757284e-02,
#        -2.28965820e-01, -5.53060849e-02,  5.38889551e-03,  1.58934599e-01,
#        -2.82352777e-01,  1.40580152e-01,  9.76782794e-03,  7.46100458e-03,
#         5.68067370e-02,  3.35791157e-01,  1.47321957e-01,  4.51583116e-02,
#        -2.20237190e-01, -5.14270843e-02,  1.93145575e-01,  3.18174611e-01,
#         1.93918270e-01, -5.37282667e-02, -1.79921109e-01,  3.68499839e-01,
#         4.88383878e-02,  1.26073631e-01, -9.36659927e-02,  2.10571851e-01,
#        -4.74714005e-01,  3.18732673e-01, -5.87637507e-01,  7.13869515e-02,
#        -2.66105709e-01,  3.63122032e-01, -3.90355354e-01,  4.62448845e-01,
#        -1.88285295e-01, -1.31763533e-01,  5.69446476e-02,  1.39791833e-01,
#        -8.35210809e-03, -3.68777247e-02, -3.61662525e-04,  4.31043048e-01,
#         7.64737437e-02,  2.79609153e-01, -1.03703404e-01, -1.88202494e-02,
#        -2.64399533e-01, -8.38335118e-02,  2.53278120e-03, -2.74260682e-02,
#         1.16611191e-02,  2.81326268e-01, -4.49873566e-01,  1.13453645e-01,
#        -2.17835115e-02,  3.44571629e-01, -1.88325009e-01, -9.54369916e-02,
#        -9.29806072e-03, -3.64546761e-02, -1.78912882e-01, -3.71232857e-01,
#         4.07699875e-02,  3.15443091e-01, -8.20905899e-02, -2.74761739e-02,
#        -1.83793595e-01, -1.65000057e-01, -2.00108264e-01, -2.48476026e-01,
#         7.87888602e-02,  9.83462317e-02, -2.70384687e-01, -1.40752042e-01,
#         1.51346746e-01,  1.27162362e-01, -3.37853735e-01,  2.99594091e-01,
#        -1.53496682e-01,  1.65707152e-01, -3.25847822e-01,  8.18829936e-02,
#         7.59193762e-02,  3.76332224e-02,  4.43322234e-02,  3.34299634e-01,
#         1.87030572e-01, -2.19893227e-01,  8.09021520e-02,  1.26761974e-01,
#        -1.77642909e-01, -6.53616683e-02,  3.67894632e-01, -6.91586371e-02,
#        -1.10954647e-01, -1.96058616e-01])

# %%
all_embedding = glove_model.get_all_embeddings()

all_embedding['kawan']
# Out:
# array([ 0.13866269,  0.21890234,  0.09218679,  0.23154498,  0.05260381,
#        -0.18254332,  0.0148109 , -0.24716445, -0.09289539, -0.05341877,
#        -0.03588736, -0.11396067, -0.14686196, -0.11092585,  0.17777542,
#        -0.10708508,  0.07685054,  0.08196429, -0.06430258, -0.04463621,
#        -0.10190072, -0.09209554,  0.05473403,  0.03048467,  0.13933763,
#         0.00675469,  0.17380573, -0.01266973,  0.06970052, -0.18607045,
#        -0.16362255, -0.27978825,  0.15206938,  0.23410425, -0.15367573,
#         0.18008264,  0.1425858 ,  0.14058182,  0.08179359,  0.02329865,
#        -0.07711526,  0.22278682, -0.03484566,  0.31960768,  0.1649335 ,
#         0.12605916,  0.14018289, -0.15323181, -0.14750196, -0.05776078,
#        -0.00943602, -0.20468867,  0.11759507,  0.0376124 ,  0.20652019,
#        -0.07633969, -0.17153993,  0.06926615,  0.02995884,  0.09424945,
#         0.1868265 ,  0.09858819, -0.10814667,  0.10034625,  0.06492498,
#         0.00934756,  0.18294062, -0.2825197 ,  0.0352203 , -0.06048576,
#        -0.27475691, -0.05468606, -0.04406116, -0.04659285, -0.05868441,
#         0.23289238,  0.02418027,  0.0031575 ,  0.16112306, -0.04849048,
#        -0.09460938,  0.09651247, -0.15394086,  0.03767625,  0.05489325,
#         0.2475884 , -0.12863868,  0.12969612, -0.19867115,  0.13092861,
#         0.0867346 , -0.09229247,  0.02886012,  0.08839602, -0.27042834,
#        -0.08861565,  0.36666746, -0.02050483, -0.25998567, -0.09395455,
#        -0.29491739, -0.19358187, -0.05113295,  0.07577771, -0.20657192,
#         0.1040452 ,  0.10838861,  0.14228916,  0.08715933, -0.08653653,
#        -0.14066835,  0.05518414, -0.04186915,  0.07703418,  0.03900909,
#         0.17907965,  0.04938253,  0.09007312, -0.0432981 , -0.08732514,
#        -0.1027925 , -0.03432807,  0.17190848, -0.12487654,  0.16288317,
#         0.12279023,  0.2883317 , -0.11267616, -0.02068991,  0.16908285,
#        -0.12304209, -0.16925814,  0.16739311, -0.19806764, -0.09910554,
#         0.01576891, -0.0924113 ,  0.03779257, -0.02774312,  0.24566128,
#        -0.00355722, -0.01123865, -0.03326014, -0.20973596, -0.02671154,
#        -0.18047093, -0.12473802, -0.08958831, -0.23457607, -0.10735202])

# %%
# # Menyimpan embedding ke file teks

# embeddings = glove_model.get_all_embeddings()

# output_file = "Misc/Embeddings/embeddings150D_300E.txt"
# with open(output_file, "w", encoding="utf-8") as file:
#     for word, embedding in embeddings.items():
#         embedding_line = "{} {}\n".format(word, " ".join(str(value) for value in embedding))
#         file.write(embedding_line)

# print("Embedding telah berhasil disimpan ke: {}".format(output_file))
# Out:
# Embedding telah berhasil disimpan ke: Misc/Embeddings/embeddings150D_300E.txt

# %% [markdown]
# <h1>Create New Feature for Word Embeddings</h1>

# %%
# df_ready['embedding'] = df_ready['text_emoji'].apply(lambda x: glove_model.get_glove_embedding(x))

# %%
# df_ready.head()

# %% [markdown]
# <h2>Fungsi untuk merubah token menjadi representasi word embedding</h2>

# %%
def replace_token_with_word_embedding(text):
    embeddings = []
    for word in text.split():
        if word in all_embedding:
            embeddings.append(all_embedding[word])
    
    return np.array(embeddings)

# %%
kalimat = df['text_emoji'][0]
output = []

for sentence in kalimat.split():
    if sentence in all_embedding:
        output.append(all_embedding[sentence])
    
print(len(np.array(output)))

# %%
df['vector'] = df['text_emoji'].apply(replace_token_with_word_embedding)

# %%
df.head()

# %%
# df_ready['text_emoji'].duplicated().sum()

# %%
# df_ready.head()

# %%
# df_ready['text_emoji'][0]

# %%
# embedding2word = glove_model.embedding2word()

# embedding2word[tuple(df_ready['text_emoji'][0][0])]

# %% [markdown]
# <h1>Implement SMOTE</h1>

# %%
df['Sarcasm'] = df['Sarcasm'].replace('Positif', 1)
df['Sarcasm'] = df['Sarcasm'].replace('Negatif', 0)

# %%
X = np.array(df['text_emoji'])
y = np.array(df['Sarcasm'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Cek class minoritas
print(f'Total Sample for each class:\n{y_train.value_counts()}')

# %% [markdown]
# <p>Terlihat Bahwa class minoritas adalah class dengan nilai 1(Positif)</p>

# %%
y_train

# %%
np.where(y_train == 1)[0]

# %%
X_train[np.where(y_train == 1)[0]]

# %%
max_len = 39
len_voc = 40000

# %%
df_train_min = X_train[np.where(y_train == 1)[0]]
df_train_maj = X_train[np.where(y_train == 0)[0]]

df_test = X_test

# %%
df_train_min

# %%
new_arrays_train_min = []

for i in df_train_min:
    new_array = np.delete(i, -1)
    new_arrays_train_min.append(new_array)

df_train_min_text = np.concatenate(new_arrays_train_min)

# %%
df_train_min_text

# %%
new_arrays_train_maj = []

for i in df_train_maj:
    new_array = np.delete(i, -1)
    new_arrays_train_maj.append(new_array)

df_train_maj_text = np.concatenate(new_arrays_train_maj)

# %%
new_arrays_test = []

for i in df_test:
    new_array = np.delete(i, -1)
    new_arrays_test.append(new_array)

df_test_text = np.concatenate(new_arrays_test)

# %%
len(df_train_min_text)

# %%
len(df_train_maj_text)

# %%
len(df_test_text)

# %%
# df_ready_min = pd.concat([df_train_min, df_test_min])
# df_ready_maj = pd.concat([df_train_maj, df_test_maj])

# %%
# Tokenizing
def make_tokenizer(texts, len_voc):
    from keras.preprocessing.text import Tokenizer
    t = Tokenizer(num_words=len_voc)
    t.fit_on_texts(texts)
    
    return t

# %% [markdown]
# <h2>Tokenizer</h2>

# %%
tokenizer = make_tokenizer(X_train, len_voc)

# %%
# tokenizer_test = make_tokenizer(X_test, len_voc)

# %%
tokenizer_train_min = make_tokenizer(df_train_min_text, len_voc)
tokenizer_train_maj = make_tokenizer(df_train_maj_text, len_voc)
tokenizer_test = make_tokenizer(df_test_text, len_voc)

# %%
word_index = tokenizer.word_index

# %% [markdown]
# <h2>Sequence</h2>

# %%
X_train_Sequence = tokenizer.texts_to_sequences(X_train)

# %%
X_test_Sequence = tokenizer.texts_to_sequences(X_test)

# %%
X_train_min = tokenizer_train_min.texts_to_sequences(df_train_min_text)
X_train_major = tokenizer_train_maj.texts_to_sequences(df_train_maj_text)
X_test = tokenizer_test.texts_to_sequences(df_test_text)

# X_train_Sentiment = df_train['Sentimen_Text']
# X_test_Sentiment = df_test['Sentimen_Text']

# %%
X_train_min

# %%
X_train_major

# %% [markdown]
# <h2>Padding</h2>

# %%
from keras.utils import pad_sequences

X_train_Padded = pad_sequences(X_train_Sequence, maxlen=max_len, padding='post', truncating='post')

# %%
X_test_Padded = pad_sequences(X_test_Sequence, maxlen=max_len, padding='post', truncating='post')

# %%
from keras.utils import pad_sequences

X_train_min = pad_sequences(X_train_min, maxlen=max_len, padding='post', truncating='post')
X_train_major = pad_sequences(X_train_major, maxlen=max_len, padding='post', truncating='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post', truncating='post')

# %%
X_train_min

# %% [markdown]
# <h2>Stacking Label Minority</h2>

# %%
y_train_min = y_train[np.where(y_train == 1)[0]]

# %%
y_train_min.shape

# %% [markdown]
# <h2>Stacking Label Majority</h2>

# %%
y_train_maj = y_train[np.where(y_train == 0)[0]]

# %%
y_train_maj.shape

# %% [markdown]
# <h2>Stacking Sentiment Minority</h2>

# %%
X_train_sentiment_min = []
for i in range(len(df_train_min)):
    X_train_sentiment_min.append(df_train_min[i][1])

X_train_sentiment_min = np.array(X_train_sentiment_min)

# %%
X_train_sentiment_min = X_train_sentiment_min.reshape(X_train_sentiment_min.shape[0], 1)

# %%
X_train_sentiment_min

# %%
X_train_sentiment_min.shape

# %% [markdown]
# <h2>Stacking Sentiment Majority</h2>

# %%
X_train_sentiment_maj = []
for i in range(len(df_train_maj)):
    X_train_sentiment_maj.append(df_train_maj[i][1])

X_train_sentiment_maj = np.array(X_train_sentiment_maj)

# %%
X_train_sentiment_maj = X_train_sentiment_maj.reshape(X_train_sentiment_maj.shape[0], 1)

# %%
X_train_sentiment_maj

# %%
X_train_sentiment_maj.shape

# %% [markdown]
# <h2>Stacking Sentiment Testing</h2>

# %%
X_test_sentiment = []
for i in range(len(df_test)):
    X_test_sentiment.append(df_test[i][1])

X_test_sentiment = np.array(X_test_sentiment)

# %%
X_test_sentiment = X_test_sentiment.reshape(X_test_sentiment.shape[0], 1)

# %%
X_test_sentiment

# %%
X_test_sentiment.shape

# %%
def get_coefs(word,*arr): 
    return word, np.asarray(arr, dtype='float32')

def load_embedding(file):
    embeddings_index = dict(get_coefs(*i.split(" ")) for i in open(file, encoding='utf-8'))
    
    return embeddings_index

# %%
def make_embedding_matrix(embedding, tokenizer, len_voc):
    all_embs = np.stack(embedding.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]
    word_index = tokenizer.word_index
    embedding_matrix = np.random.normal(emb_mean, emb_std, (len_voc, embed_size))
    # embedding_matrix = np.zeros((len_voc, embed_size))
    
    for word, i in word_index.items():
        if i >= len_voc:
            continue
        embedding_vector = embedding.get(word)
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
    
    return embedding_matrix

# %%
glove_50D = load_embedding('Misc/Embeddings/embeddings50D_300E.txt')
glove_100D = load_embedding('Misc/Embeddings/embeddings100D_300E.txt')
glove_150D = load_embedding('Misc/Embeddings/embeddings150D_300E.txt')

# %%
embed_matrix_50D = make_embedding_matrix(glove_50D, tokenizer, len_voc)
embed_matrix_100D = make_embedding_matrix(glove_100D, tokenizer, len_voc)
embed_matrix_150D = make_embedding_matrix(glove_150D, tokenizer, len_voc)
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3378: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
X_train_embedding = embed_matrix_100D[X_train_Padded]

# %%
# embed_matrix_test = make_embedding_matrix(glove, tokenizer_test, len_voc)

X_test_embedding = embed_matrix_100D[X_test_Padded]

# %%
train_size, max_len, embed_size = X_train_embedding.shape
X_train_embedding_r = X_train_embedding.reshape(train_size, max_len*embed_size)

test_size, max_len, embed_size = X_test_embedding.shape
X_test_embedding_r = X_test_embedding.reshape(test_size, max_len*embed_size)

# %%
smote = SMOTE()

X_oversampled, y_oversampled = smote.fit_resample(X_train_embedding_r, y_train)

# %%
unique_values, value_counts = np.unique(y_oversampled, return_counts=True)

for value, counts in zip(unique_values, value_counts):
    print(f'{value}: {counts}')
# Out:
# 0: 1804
# 1: 1804

# %%
embed_mat_train_min = make_embedding_matrix(glove, tokenizer_train_min, len_voc)
embed_mat_train_maj = make_embedding_matrix(glove, tokenizer_train_maj, len_voc)

embed_mat_test = make_embedding_matrix(glove, tokenizer_test, len_voc)

# %%
embed_mat_train_min.shape

# %%
X_train_emb_minority = embed_mat_train_min[X_train_min]
X_train_emb_majority = embed_mat_train_maj[X_train_major]

X_test_emb = embed_mat_test[X_test]

# %%
X_train_emb_minority

# %%
train_size_min, max_len_min, embed_size_min = X_train_emb_minority.shape
X_train_emb_r_min = X_train_emb_minority.reshape(train_size_min, max_len*embed_size_min)

train_size_maj, max_len_maj, embed_size_maj = X_train_emb_majority.shape
X_train_emb_r_maj = X_train_emb_majority.reshape(train_size_maj, max_len*embed_size_maj)

# %%
X_train_emb_r_min.shape

# %%
X_train_emb_r_maj.shape

# %%
test_size, max_len, embed_size = X_test_emb.shape
X_test_emb_r = X_test_emb.reshape(test_size, max_len*embed_size)

# %%
X_test_emb_r.shape

# %% [markdown]
# <h2>Stacking All Data Minority & Majority</h2>

# %%
stack_train_minority = np.hstack((X_train_emb_r_min, X_train_sentiment_min))
stack_train_majority = np.hstack((X_train_emb_r_maj, X_train_sentiment_maj))

stack_testing = np.hstack((X_test_emb_r, X_test_sentiment))

# %%
print(f'Shape stack minority: {stack_train_minority.shape}')
print(f'Shape stack majority: {stack_train_majority.shape}')

# %%
# test_size, max_len, embed_size = X_test_emb.shape
# X_test_emb_r = X_test_emb.reshape(test_size, max_len*embed_size)

# %%
# X = df_ready['embedding']
# X_sentiment = np.array(df_ready['Sentimen_Text']).reshape(-1, 1)
# y = np.array(df_ready['Sarcasm'])

# %%
# from sklearn.model_selection import train_test_split
# # Bagi dataset menjadi train set dan test set
# X_train, X_test, X_sentiment_train, X_sentiment_test, y_train, y_test = train_test_split(X, X_sentiment, y, test_size=0.4, random_state=42)

# %%
# X_minority = X_train[y_train == 1]
# X_sentiment_minority = X_sentiment_train[y_train == 1]
# y_minority = y_train[y_train == 1]

# %%
# len(X_minority)

# %%
from sklearn.metrics.pairwise import euclidean_distances

def euclidean_distance(X1, X2):
    return euclidean_distances(X1, X2)

def get_neighbors(distances, k):
    return np.argsort(distances)[:, 1:k+1]

def generate_synthetic_samples(X_minority, neighbors, k_neighbors):
    synthetic_samples = []

    for i in range(len(X_minority)):
        minority_neighbors = neighbors[i][neighbors[i] < len(X_minority)]
        nn = np.random.choice(minority_neighbors, size=min(k_neighbors, len(minority_neighbors)), replace=False)
        alpha = np.random.uniform(0, 1)
        synthetic_sample = X_minority[i] + alpha * (X_minority[nn] - X_minority[i])
        
        if synthetic_sample.size > 1:
            synthetic_sample = synthetic_sample[:1]

        print(synthetic_sample)
        
        synthetic_samples.append(synthetic_sample)

    data_synthetic = np.vstack(synthetic_samples)
    for i in range(len(synthetic_samples)):
        print(synthetic_samples[i].shape)
    return data_synthetic

def smote(X_minority, X_majority, y_minority, k):
    minority_size = X_minority.shape[0]
    majority_size = X_majority.shape[0]  # Asumsi jumlah sampel mayoritas sama dengan jumlah sampel minoritas
    
    # Menghitung jumlah tetangga terdekat berdasarkan perbandingan antara jumlah sampel minoritas dan mayoritas
    k_neighbors = int((majority_size / minority_size) * k)
    
    if k_neighbors > k:
        k_neighbors = k

    # Menghitung jarak antara sampel minoritas dan mayoritas
    distances = euclidean_distance(X_minority, X_majority)
    print('Distance\n')
    print(f'{distances}\n')
    
    # Mendapatkan tetangga terdekat untuk setiap sampel minoritas
    neighbors = get_neighbors(distances, k_neighbors)
    print('Neighbors\n')
    print(f'{neighbors}\n')
    print(f'Length : {neighbors.shape[0]}\n')
    
    # Menghasilkan sampel sintetis
    print('Synthetic Data\n')
    synthetic_samples = generate_synthetic_samples(X_minority, neighbors, k_neighbors)
    synthetic_labels = np.ones(len(synthetic_samples))
    
    # Menggabungkan sampel minoritas asli dengan sampel sintetis
    X_oversampled = np.vstack((X_minority, synthetic_samples))
    y_oversampled = np.hstack((y_minority, synthetic_labels))
    
    return X_oversampled, y_oversampled

# %%
total_size = train_size_maj + train_size_min + test_size

# %%
# Menjalankan SMOTE pada data stack
X_minority = stack_train_minority
y_minority = y_train_min
X_majority = stack_train_minority
y_majority = y_train_maj

X_oversampled, y_oversampled = smote(X_minority, X_majority, y_minority, k=5)

# Memisahkan kembali data menjadi train dan test set
X_train_oversampled = X_oversampled[:total_size]
X_test_oversampled = X_oversampled[total_size:]

y_train_oversampled = y_oversampled[:total_size]
y_test_oversampled = y_oversampled[total_size:]

# %%
final_stack = np.vstack((stack_train_majority, X_oversampled))

# %%
len(final_stack)

# %%
final_stack = np.delete(final_stack, np.s_[4024::], axis=0)

# %%
final_stack.shape

# %%
final_stack_label = np.hstack((y_train_maj, y_oversampled))

# %%
final_stack_label = np.delete(final_stack_label, np.s_[4024::], axis=0)

# %%
print(f'Final Shape Data: {final_stack.shape}\n')

# %%
print(f'Final Shape Label: {final_stack_label.shape}\n')

# %%
# Menghitung Jumlah Akhir Sample pada Class 0 dan 1
unique, counts = np.unique(final_stack_label, return_counts=True)
result = np.asarray((unique, counts)).T.astype(int)

print(result[0][1])

# %%
import matplotlib.pyplot as plt

x = ['Sebelum', 'Sesudah']
y = [len(X_train_emb_r_min) + len(X_train_emb_r_maj), len(final_stack)]


plt.bar(x, y, color=[(0.38, 0.62, 0.79), (0.98, 0.64, 0.33)], edgecolor='black', linewidth=1.5)

for i in range(len(x)):
    plt.text(x[i], y[i], str(y[i]), ha='center', va='bottom')

plt.ylabel('Jumlah Sample')
plt.title('Perbandingan Data Training Setelah Diimplementasi SMOTE')

plt.show()

# %%
x = ['0', '1']
y = [1794, 1718]


plt.bar(x, y, color=[(0.38, 0.62, 0.79), (0.98, 0.64, 0.33)], edgecolor='black', linewidth=1.5)

for i in range(len(x)):
    plt.text(x[i], y[i], str(y[i]), ha='center', va='bottom')

plt.ylabel('Jumlah Sample')
plt.title('Jumlah Sample Masing-Masing Kelas Pada Data Training Sebelum Di Implementasi SMOTE')

plt.show()

# %%
x = ['0', '1']
y = [result[0][1], result[1][1]]


plt.bar(x, y, color=[(0.38, 0.62, 0.79), (0.98, 0.64, 0.33)], edgecolor='black', linewidth=1.5)

for i in range(len(x)):
    plt.text(x[i], y[i], str(y[i]), ha='center', va='bottom')

plt.ylabel('Jumlah Sample')
plt.title('Jumlah Sample Masing-Masing Kelas Setelah Di Implementasi SMOTE')

plt.show()

# %%
# X_embedding = np.array(df_ready['embedding'][:2]).reshape(-1, 1)
# sentiment_values = np.array(df_ready['Sentimen_Text'][:2]).reshape(-1, 1)

# num_rows = X_embedding.shape[0]

# X_sentiment = np.empty((num_rows, 1), dtype=np.str_)

# for i in range(num_rows):
#     X_sentiment[i] = sentiment_values[i % sentiment_values.shape[0]]

# X = np.hstack((X_embedding, X_sentiment))

# X

# %%
# y = df_ready['Sarcasm']

# y

# %%
# from sklearn.neighbors import NearestNeighbors

# def get_k_nearest_neighbors(X, sample, k):
#     # Mencari tetangga terdekat menggunakan k-NN
#     knn = NearestNeighbors(n_neighbors=k+1)
#     knn.fit(X)
    
#     # Mengembalikan indeks tetangga terdekat untuk sampel
#     _, indices = knn.kneighbors([sample])
#     indices_1d = indices.flatten()  # Mengubah menjadi 1D array
    
#     return indices_1d[1:]  # Menghilangkan indeks diri sendiri

# %%
# import pandas as pd
# import numpy as np
# import math

# def SMOTE(df, k, oversampling_ratio):
#     # Mendapatkan array numpy dari fitur embedding, sentiment, dan label
#     embeddings = np.vstack(df['embedding'].to_numpy())
#     labels = df['Sarcasm'].to_numpy()
    
#     # Menginisialisasi array untuk menyimpan sampel sintetis yang dihasilkan
#     synthetic_samples = []
    
#     # Mencari indeks sampel minoritas dan mayoritas
#     minority_indices = np.where(labels == 1)[0]
#     majority_indices = np.where(labels == 0)[0]
    
#     # Menghitung jumlah sampel sintetis yang akan dibuat untuk kelas minoritas
#     num_minority_samples = len(minority_indices)
#     num_majority_samples = len(majority_indices)
    
#     num_synthetic_samples = min(num_majority_samples - num_minority_samples, math.ceil(num_minority_samples * oversampling_ratio))
    
#     if num_synthetic_samples <= 0:
#         return pd.DataFrame()  # Return empty DataFrame jika tidak ada sampel sintetis yang perlu dibuat
    
#     # Looping melalui setiap sampel minoritas
#     for i in minority_indices:
#         sample = embeddings[i]
        
#         # Mencari tetangga terdekat untuk sampel minoritas
#         neighbors = get_k_nearest_neighbors(embeddings, sample, k)
        
#         # Menghasilkan sampel sintetis
#         for j in range(num_synthetic_samples):
#             # Memilih satu tetangga acak
#             neighbor_index = np.random.choice(neighbors)
            
#             if neighbor_index >= len(embeddings):
#                 continue  # Skip jika indeks tetangga melebihi ukuran data yang valid
            
#             neighbor = embeddings[neighbor_index]
            
#             # Menghitung selisih antara sampel dan tetangga
#             diff = neighbor - sample
            
#             # Menghasilkan sampel sintetis dengan proporsi acak
#             proportion = np.random.uniform(0, 1, size=1)
#             synthetic_sample = sample + proportion * diff
            
#             # Menambahkan sampel sintetis ke array
#             synthetic_samples.append(synthetic_sample)
    
#     # Mengubah array numpy ke DataFrame
#     embedding_array = np.vstack(synthetic_samples)
#     embedding_df = pd.DataFrame(embedding_array, columns=['embedding'] * embedding_array.shape[1])
#     sarcasm_df = pd.DataFrame(np.zeros((embedding_array.shape[0], 1)), columns=['Sarcasm'])
#     synthetic_df = pd.concat([embedding_df, sarcasm_df], axis=1)
    
#     # Menambahkan label kelas minoritas pada data sintetis
#     synthetic_df['Sarcasm'] = 1

#     return synthetic_df

# %%
# oversampled_df = SMOTE(df_ready, k=5, oversampling_ratio=1.0)

# %% [markdown]
# <h1>Training Bi-LSTM<h1>

# %%
# Bi-LSTM Algorithm

import numpy as np
import pickle as pkl

# activation function sigmoid
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Turunan activation function sigmoid
def sigmoid_derivative(x):
    return x * (1 - x)

# activation function tanh
def tanh(x):
    return np.tanh(x)

# Turunan activation function tanh
def tanh_derivative(x):
    return 1 - x**2

class BiLSTM:
    # Constructor
    def __init__(self, input_size, hidden_size, output_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        
        # Parameter untuk Input Gate Menggunakan Metode Xavier
        self.W_i = np.random.uniform(-1, 1, (hidden_size, input_size)) * np.sqrt(1 / input_size)
        self.U_i = np.random.uniform(-1, 1, (hidden_size, hidden_size)) * np.sqrt(1 / hidden_size)
        self.b_i = np.zeros((hidden_size, 1))
        
        # Parameter untuk Forget Gate Menggunakan Metode Xavier
        self.W_f = np.random.uniform(-1, 1, (hidden_size, input_size)) * np.sqrt(1 / input_size)
        self.U_f = np.random.uniform(-1, 1, (hidden_size, hidden_size)) * np.sqrt(1 / hidden_size)
        self.b_f = np.zeros((hidden_size, 1))
        
        # Parameter untuk Output Gate Menggunakan Metode Xavier
        self.W_o = np.random.uniform(-1, 1, (hidden_size, input_size)) * np.sqrt(1 / input_size)
        self.U_o = np.random.uniform(-1, 1, (hidden_size, hidden_size)) * np.sqrt(1 / hidden_size)
        self.b_o = np.zeros((hidden_size, 1))
        
        # Parameter untuk Cell State Menggunakan Metode Xavier
        self.W_c = np.random.uniform(-1, 1, (hidden_size, input_size)) * np.sqrt(1 / input_size)
        self.U_c = np.random.uniform(-1, 1, (hidden_size, hidden_size)) * np.sqrt(1 / hidden_size)
        self.b_c = np.zeros((hidden_size, 1))
        
        # Parameter untuk output layer Menggunakan Metode Xavier
        self.W_y = np.random.uniform(-1, 1, (output_size, hidden_size*2)) * np.sqrt(1 / (hidden_size*2))
        self.b_y = np.zeros((output_size, 1))

        # Parameter m dan v pada Adam Optimizer untuk setiap parameter
        self.mW_i, self.vW_i = np.zeros_like(self.W_i), np.zeros_like(self.W_i)
        self.mU_i, self.vU_i = np.zeros_like(self.U_i), np.zeros_like(self.U_i)
        self.mb_i, self.vb_i = np.zeros_like(self.b_i), np.zeros_like(self.b_i)
        
        self.mW_f, self.vW_f = np.zeros_like(self.W_f), np.zeros_like(self.W_f)
        self.mU_f, self.vU_f = np.zeros_like(self.U_f), np.zeros_like(self.U_f)
        self.mb_f, self.vb_f = np.zeros_like(self.b_f), np.zeros_like(self.b_f)

        self.mW_o, self.vW_o = np.zeros_like(self.W_o), np.zeros_like(self.W_o)
        self.mU_o, self.vU_o = np.zeros_like(self.U_o), np.zeros_like(self.U_o)
        self.mb_o, self.vb_o = np.zeros_like(self.b_o), np.zeros_like(self.b_o)

        self.mW_c, self.vW_c = np.zeros_like(self.W_c), np.zeros_like(self.W_c)
        self.mU_c, self.vU_c = np.zeros_like(self.U_c), np.zeros_like(self.U_c)
        self.mb_c, self.vb_c = np.zeros_like(self.b_c), np.zeros_like(self.b_c)

        self.mW_y, self.vW_y = np.zeros_like(self.W_y), np.zeros_like(self.W_y)
        self.mb_y, self.vb_y = np.zeros_like(self.b_y), np.zeros_like(self.b_y)

        self.count = 0
        
    def forward_backward(self, x):
        T = len(x)
        # print(T)
        self.count += 1

        self.h_forward = np.zeros((T + 1, self.hidden_size))
        self.c_forward = np.zeros((T + 1, self.hidden_size))
        self.h_backward = np.zeros((T + 1, self.hidden_size))
        self.c_backward = np.zeros((T + 1, self.hidden_size))
        self.gates_forward = np.zeros((T, self.hidden_size*4, self.hidden_size))
        self.gates_backward = np.zeros((T, self.hidden_size*4, self.hidden_size))
        self.outputs = np.zeros((T, self.output_size))
        
        for t in range(T):
            # Forward
            self.gates_forward[t] = np.concatenate([
                sigmoid(self.W_i @ x[t] + self.U_i @ self.h_forward[t] + self.b_i),
                sigmoid(self.W_f @ x[t] + self.U_f @ self.h_forward[t] + self.b_f),
                sigmoid(self.W_o @ x[t] + self.U_o @ self.h_forward[t] + self.b_o),
                tanh(self.W_c @ x[t] + self.U_c @ self.h_forward[t] + self.b_c)
            ])
        
            # print(f'Forget Gate Forward Iterasi {self.count}: {sigmoid(self.W_f @ x[t] + self.U_f @ self.h_forward[t] + self.b_f)}\n')
            # print(f'Input Gate Forward Iterasi {self.count}: {sigmoid(self.W_i @ x[t] + self.U_i @ self.h_forward[t] + self.b_i)}\n')
            # print(f'Output Gate Forward Iterasi {self.count}: {sigmoid(self.W_o @ x[t] + self.U_o @ self.h_forward[t] + self.b_o)}\n')
            self.c_forward[t + 1] = self.gates_forward[t, 1] * self.c_forward[t] + self.gates_forward[t, 0] * self.gates_forward[t, 3]
            self.h_forward[t + 1] = self.gates_forward[t, 2] * tanh(self.c_forward[t + 1])

            # print(f'Cell State Forward Iterasi {self.count}: {self.gates_forward[t, 1] * self.c_forward[t] + self.gates_forward[t, 0] * self.gates_forward[t, 3]}\n')
            # print(f'Hidden State Forward Iterasi {self.count}: {self.gates_forward[t, 2] * tanh(self.c_forward[t + 1])}\n')

            # backward
            t_backward = T - t - 1
            self.gates_backward[t_backward] = np.concatenate([
                sigmoid(self.W_i @ x[t_backward] + self.U_i @ self.h_backward[t_backward] + self.b_i),
                sigmoid(self.W_f @ x[t_backward] + self.U_f @ self.h_backward[t_backward] + self.b_f),
                sigmoid(self.W_o @ x[t_backward] + self.U_o @ self.h_backward[t_backward] + self.b_o),
                tanh(self.W_c @ x[t_backward] + self.U_c @ self.h_backward[t_backward] + self.b_c)
            ])
            
            # print(f'Forget Gate Backward Iterasi {self.count}: {sigmoid(self.W_f @ x[t_backward] + self.U_f @ self.h_backward[t_backward] + self.b_f)}\n')
            # print(f'Input Gate Backward Iterasi {self.count}: {sigmoid(self.W_i @ x[t_backward] + self.U_i @ self.h_backward[t_backward] + self.b_i)}\n')
            # print(f'Output Gate Backward Iterasi {self.count}: {sigmoid(self.W_o @ x[t_backward] + self.U_o @ self.h_backward[t_backward] + self.b_o)}\n')
            self.c_backward[t_backward + 1] = self.gates_backward[t_backward, 1] * self.c_backward[t_backward] + self.gates_backward[t_backward, 0] * self.gates_backward[t_backward, 3]
            self.h_backward[t_backward + 1] = self.gates_backward[t_backward, 2] * tanh(self.c_backward[t_backward + 1])

            # print(f'Cell State Backward Iterasi {self.count}: {self.gates_backward[t_backward, 1] * self.c_backward[t_backward] + self.gates_backward[t_backward, 0] * self.gates_backward[t_backward, 3]}\n')
            # print(f'Hidden State Backward Iterasi {self.count}: {self.gates_backward[t_backward, 2] * tanh(self.c_backward[t_backward + 1])}\n')

            # Merged Forward and Backward LSTM
            merged_output = np.concatenate([self.h_forward[t + 1], self.h_backward[t_backward + 1]])
            # h_reshaped = np.reshape(merged_output, (self.hidden_size*2,))
            # print(f'Final Output Reshape: {h_reshaped}\n')
            sigmoids = sigmoid(self.W_y @ merged_output + self.b_y)
            # print(f'Sigmoids: {sigmoids.shape}\n')
            self.outputs[t] = sigmoids[0]
        # print(f'Merged Output: {merged_output}\n')
        # print(f'final Outputs{self.outputs}\n')
        
        return self.outputs
    
    def backPropagation(self, x, y, learning_rate, beta1=0.9, beta2=0.999, epsilon=1e-8):
        T = len(x)
        dW_i, dU_i, db_i = np.zeros_like(self.W_i), np.zeros_like(self.U_i), np.zeros_like(self.b_i)
        dW_f, dU_f, db_f = np.zeros_like(self.W_f), np.zeros_like(self.U_f), np.zeros_like(self.b_f)
        dW_o, dU_o, db_o = np.zeros_like(self.W_o), np.zeros_like(self.U_o), np.zeros_like(self.b_o)
        dW_c, dU_c, db_c = np.zeros_like(self.W_c), np.zeros_like(self.U_c), np.zeros_like(self.b_c)
        dW_y, db_y = np.zeros_like(self.W_y), np.zeros_like(self.b_y)
        dc_next = np.zeros((1, self.hidden_size))
        dh_next = np.zeros((1, self.hidden_size))
        
        for t in reversed(range(T)):
            dy = self.outputs[t]
            # print(f'Outputs: {dy}\n')
            # print(f'{y[t]}\n')
            dy[y[t]] -= 1
            # print(f'Outputs minus 1{dy}\n')
            dy_transpose = dy.reshape(1, -1).T
            # print(f'Shape dy_transpose: {dy_transpose.shape}\n')
            # print(f'Shape self.W_y.T : {self.W_y.shape}\n')
            dh_forward = self.W_y.T @ dy_transpose + dh_next
            # print(f'Shape dh_forward: {dh_forward.shape}\n')
            dc_forward = dh_forward * self.gates_forward[t, 2] * tanh_derivative(tanh(self.c_forward[t + 1])) + dc_next
            dh_backward = self.W_y.T @ dy_transpose + dh_next
            dc_backward = dh_backward * self.gates_backward[t, 2] * tanh_derivative(tanh(self.c_backward[t + 1])) + dc_next
            
            # print(f'Shape dy_transpose: {dy_transpose.shape}\n')
            # print(f'Shape dW_y: {dW_y.shape}\n')
            # print(f'Shape self.h_forward: {self.h_forward[t + 1].shape}\n')
            # dW_y += dy_transpose @ np.expand_dims(self.h_forward[t + 1], axis=0) + dy_transpose @ np.expand_dims(self.h_backward[t + 1], axis=0) # Salah
            dW_y += dy_transpose @ np.expand_dims(np.concatenate([self.h_forward[t + 1], self.h_backward[t + 1][:self.hidden_size]]), axis=0) # Benar
            db_y += dy_transpose
            
            # print(f'dc_forward: {dc_forward.shape}, self.gates_forward[t, 3]: {self.gates_forward[t, 3].shape}\n')
            dg_forward = dc_forward * self.gates_forward[t, 2] * tanh_derivative(self.gates_forward[t, 3])
            dg_backward = dc_backward * self.gates_backward[t, 3]

            dgates_forward = self.gates_forward[t]
            # print(f'Shape dgates_forward[3]: {dgates_forward.shape}\n')
            # dg_forward_expanded = np.expand_dims(dg_forward, axis=0)
            dgated = dg_forward * tanh_derivative(dgates_forward[3])
            # print(f'tanh_derivative Shape: {dgated.shape}\n')
            # print(f'Shape dg_forward : {dg_forward.shape}')
            dgates_forward[3][:self.hidden_size] = np.sum(dg_forward[:self.hidden_size] * tanh_derivative(dgates_forward[3])[:self.hidden_size], axis=1) # Error disini
            dgates_forward[0][:self.hidden_size] = np.sum(dc_forward[:self.hidden_size] * self.gates_forward[t, 0], axis=1)
            dgates_forward[1][:self.hidden_size] = np.sum(dc_forward[:self.hidden_size] * self.c_forward[t], axis=1)
            dgates_forward[2][:self.hidden_size] = np.sum(dh_forward[:self.hidden_size] * tanh(self.c_forward[t + 1]) * sigmoid_derivative(dgates_forward[2]), axis=1)

            dgates_backward = self.gates_backward[t]
            dgates_backward[3][:self.hidden_size] = np.sum(dg_backward[:self.hidden_size] * tanh_derivative(dgates_backward[3]))
            dgates_backward[0][:self.hidden_size] = np.sum(dc_backward[:self.hidden_size] * self.gates_backward[t, 0])
            dgates_backward[1][:self.hidden_size] = np.sum(dc_backward[:self.hidden_size] * self.c_backward[t])
            dgates_backward[2][:self.hidden_size] = np.sum(dh_backward[:self.hidden_size] * tanh(self.c_backward[t + 1]) * sigmoid_derivative(dgates_backward[2]))
            
            x_transpose = np.array([x[t]])
            dgates_transpose_forward_0 = np.array([dgates_forward[0]])
            dgates_transpose_forward_1 = np.array([dgates_forward[1]])
            dgates_transpose_forward_2 = np.array([dgates_forward[2]])
            dgates_transpose_forward_3 = np.array([dgates_forward[3]])

            dgates_transpose_backward_0 = np.array([dgates_backward[0]])
            dgates_transpose_backward_1 = np.array([dgates_backward[1]])
            dgates_transpose_backward_2 = np.array([dgates_backward[2]])
            dgates_transpose_backward_3 = np.array([dgates_backward[3]])
            
            dW_i += dgates_transpose_forward_0.T @ x_transpose + dgates_transpose_backward_0.T @ x_transpose
            dU_i += dgates_forward[0] @ self.h_forward[t].T + dgates_backward[0] @ self.h_backward[t].T
            db_i += dgates_transpose_forward_0.T + dgates_transpose_backward_0.T
            
            dW_f += dgates_transpose_forward_1.T @ x_transpose + dgates_transpose_backward_1.T @ x_transpose # Error disini
            dU_f += dgates_forward[1] @ self.h_forward[t].T + dgates_backward[1] @ self.h_backward[t].T
            db_f += dgates_transpose_forward_1.T + dgates_transpose_backward_1.T
            
            dW_o += dgates_transpose_forward_2.T @ x_transpose + dgates_transpose_backward_2.T @ x_transpose
            dU_o += dgates_forward[2] @ self.h_forward[t].T + dgates_backward[2] @ self.h_backward[t].T
            db_o += dgates_transpose_forward_2.T + dgates_transpose_backward_2.T
            
            dW_c += dgates_transpose_forward_3.T @ x_transpose + dgates_transpose_backward_3.T @ x_transpose
            dU_c += dgates_forward[3] @ self.h_forward[t].T + dgates_backward[3] @ self.h_backward[t].T
            db_c += dgates_transpose_forward_3.T + dgates_transpose_backward_3.T
            
            dh_next = self.U_i.T @ dgates_forward[0] + self.U_f.T @ dgates_forward[1] + self.U_o.T @ dgates_forward[2] + self.U_c.T @ dgates_forward[3]
            dc_next = dc_forward * self.gates_forward[t, 1]
        
        # Adam Optimizer
        for param, dparam, m, v in zip([self.W_i, self.U_i, self.b_i, self.W_f, self.U_f, self.b_f, self.W_o, self.U_o, self.b_o, self.W_c, self.U_c, self.b_c, self.W_y, self.b_y],
                               [dW_i, dU_i, db_i, dW_f, dU_f, db_f, dW_o, dU_o, db_o, dW_c, dU_c, db_c, dW_y, db_y],
                               [self.mW_i, self.mU_i, self.mb_i, self.mW_f, self.mU_f, self.mb_f, self.mW_o, self.mU_o, self.mb_o, self.mW_c, self.mU_c, self.mb_c, self.mW_y, self.mb_y],
                               [self.vW_i, self.vU_i, self.vb_i, self.vW_f, self.vU_f, self.vb_f, self.vW_o, self.vU_o, self.vb_o, self.vW_c, self.vU_c, self.vb_c, self.vW_y, self.vb_y]):
            # print(f'Nilai Gradien Awal:\n{dparam}\n')
            m = beta1 * m + (1 - beta1) * dparam
            # print(f'Memperbaharui Estimasi momen pertama yang bias:\n {m}\n')
            v = beta2 * v + (1 - beta2) * (dparam ** 2)
            # print(f'Memperbaharui perkiraan momen kedua yang bias:\n {v}\n')
            m_hat = m / (1 - beta1)
            # print(f'Hasil perhitungan estimasi momen pertama yang dikoreksi bias:\n {m_hat}\n')
            v_hat = v / (1 - beta2)
            # print(f'Hasil perhitungan estimasi momen mentah kedua yang dikoreksi bias:\n {v_hat}\n')
            param -= learning_rate * m_hat / (np.sqrt(v_hat) + epsilon)
            # print(f'Nilai Update Parameter yang akan digunakan untuk epochs berikutnya: \n{param}')
        
        # for param in [dW_i, dU_i, db_i, dW_f, dU_f, db_f, dW_o, dU_o, db_o, dW_c, dU_c, db_c, dW_y, db_y]:
        #     np.clip(param, -1, 1, out=param)
        
        # self.W_i -= learning_rate * dW_i
        # self.U_i -= learning_rate * dU_i
        # self.b_i -= learning_rate * db_i
        
        # self.W_f -= learning_rate * dW_f
        # self.U_f -= learning_rate * dU_f
        # self.b_f -= learning_rate * db_f
        
        # self.W_o -= learning_rate * dW_o
        # self.U_o -= learning_rate * dU_o
        # self.b_o -= learning_rate * db_o
        
        # self.W_c -= learning_rate * dW_c
        # self.U_c -= learning_rate * dU_c
        # self.b_c -= learning_rate * db_c
        
        # self.W_y -= learning_rate * dW_y
        # self.b_y -= learning_rate * db_y
    
    def train(self, x, y, epochs, learning_rate):
        for epoch in range(epochs):
            outputs = self.forward_backward(x)
            self.backPropagation(x, y, learning_rate)
            # print(f'Hasil Prediksi {outputs}')
            outputs = np.clip(outputs, 1e-15, None)
            loss = -np.mean(np.log(outputs[np.arange(len(y)), y]))
            
            print(f'Epoch {epoch + 1}/{epochs}, Loss: {loss:.4f}')
    
    def predict(self, x):
        T = len(x)
        h_forward = np.zeros((T + 1, self.hidden_size))
        c_forward = np.zeros((T + 1, self.hidden_size))
        h_backward = np.zeros((T + 1, self.hidden_size))
        c_backward = np.zeros((T + 1, self.hidden_size))
        outputs = np.zeros((T, self.output_size))
        
        for t in range(T):
            # Forward
            gates_forward = np.concatenate([
                sigmoid(self.W_i @ x[t] + self.U_i @ h_forward[t] + self.b_i),
                sigmoid(self.W_f @ x[t] + self.U_f @ h_forward[t] + self.b_f),
                sigmoid(self.W_o @ x[t] + self.U_o @ h_forward[t] + self.b_o),
                tanh(self.W_c @ x[t] + self.U_c @ h_forward[t] + self.b_c)
            ])
                
            c_forward[t + 1] = gates_forward[1] * c_forward[t] + gates_forward[0] * gates_forward[3]
            h_forward[t + 1] = gates_forward[2] * tanh(c_forward[t + 1])
                
            # Backward
            t_backward = T - t - 1
            gates_backward = np.concatenate([
                sigmoid(self.W_i @ x[t_backward] + self.U_i @ h_backward[t_backward] + self.b_i),
                sigmoid(self.W_f @ x[t_backward] + self.U_f @ h_backward[t_backward] + self.b_f),
                sigmoid(self.W_o @ x[t_backward] + self.U_o @ h_backward[t_backward] + self.b_o),
                tanh(self.W_c @ x[t_backward] + self.U_c @ h_backward[t_backward] + self.b_c)
            ])
                
            c_backward[t_backward + 1] = gates_backward[1] * c_backward[t_backward] + gates_backward[0] * gates_backward[3]
            h_backward[t_backward + 1] = gates_backward[2] * tanh(c_backward[t_backward + 1])

            merged_output = np.concatenate([h_forward[t + 1], h_backward[t_backward + 1]])
            sigmoids = sigmoid(self.W_y @ merged_output + self.b_y)
            outputs[t] = sigmoids[0]
        
        return np.argmax(outputs, axis=1)
    
    def save_model(self, model, filename):
        with open(filename, 'wb') as f:
            pkl.dump(model, f)

# %% [markdown]
# <h2>Training & Testing Model</h2>

# %% [markdown]
# <h3>Train Model Bi-LSTM (Parameter embedding_size = 50)</h3>

# %% [markdown]
# <p>Bi-LSTM</p>

# %%
x_train = X_train_embedding_r
x_train = np.array(x_train)
# label = final_stack_label.astype('int')
y_trains = y_train

# Inisialisasi model Bi-LSTM
input_size = x_train.shape[1]
hidden_size = 6
output_size = 2
model_bilstm_embedsize_50 = BiLSTM(input_size, hidden_size, output_size)

# %%
x_train.shape
# Out:
# (3537, 3900)

# %%
y_trains.shape
# Out:
# (3537,)

# %%
X_test_embedding_r.shape
# Out:
# (394, 3900)

# %%
# Train ML Model
epochs = 300
learning_rate = 0.001
model_bilstm_embedsize_50.train(x_train, y_trains, epochs, learning_rate)
# Out:
# Epoch 1/300, Loss: 34.5388
# Epoch 2/300, Loss: 34.5388
# Epoch 3/300, Loss: 34.5388
# Epoch 4/300, Loss: 34.5388
# Epoch 5/300, Loss: 34.5388
# Epoch 6/300, Loss: 34.5388
# Epoch 7/300, Loss: 34.5388
# Epoch 8/300, Loss: 34.5388
# Epoch 9/300, Loss: 34.5388
# Epoch 10/300, Loss: 34.5388
# Epoch 11/300, Loss: 34.5388
# Epoch 12/300, Loss: 34.5388
# Epoch 13/300, Loss: 34.5388
# Epoch 14/300, Loss: 34.5388
# Epoch 15/300, Loss: 34.5388
# Epoch 16/300, Loss: 34.5388
# Epoch 17/300, Loss: 34.5388
# Epoch 18/300, Loss: 34.5388
# Epoch 19/300, Loss: 34.5388
# Epoch 20/300, Loss: 34.5388
# Epoch 21/300, Loss: 34.5388
# Epoch 22/300, Loss: 34.5388
# Epoch 23/300, Loss: 34.5388
# Epoch 24/300, Loss: 34.5388
# Epoch 25/300, Loss: 34.5388
# Epoch 26/300, Loss: 34.5388
# Epoch 27/300, Loss: 34.5388
# Epoch 28/300, Loss: 34.5388
# Epoch 29/300, Loss: 34.5388
# Epoch 30/300, Loss: 34.5388
# Epoch 31/300, Loss: 34.5388
# Epoch 32/300, Loss: 34.5388
# Epoch 33/300, Loss: 34.5388
# Epoch 34/300, Loss: 34.5388
# Epoch 35/300, Loss: 34.5388
# Epoch 36/300, Loss: 34.5388
# Epoch 37/300, Loss: 34.5388
# Epoch 38/300, Loss: 34.5388
# Epoch 39/300, Loss: 34.5388
# Epoch 40/300, Loss: 34.5388
# Epoch 41/300, Loss: 34.5388
# Epoch 42/300, Loss: 34.5388
# Epoch 43/300, Loss: 34.5388
# Epoch 44/300, Loss: 34.5388
# Epoch 45/300, Loss: 34.5388
# Epoch 46/300, Loss: 34.5388
# Epoch 47/300, Loss: 34.5388
# Epoch 48/300, Loss: 34.5388
# Epoch 49/300, Loss: 34.5388
# Epoch 50/300, Loss: 34.5388
# Epoch 51/300, Loss: 34.5388
# Epoch 52/300, Loss: 34.5388
# Epoch 53/300, Loss: 34.5388
# Epoch 54/300, Loss: 34.5388
# Epoch 55/300, Loss: 34.5388
# Epoch 56/300, Loss: 34.5388
# Epoch 57/300, Loss: 34.5388
# Epoch 58/300, Loss: 34.5388
# Epoch 59/300, Loss: 34.5388
# Epoch 60/300, Loss: 34.5388
# Epoch 61/300, Loss: 34.5388
# Epoch 62/300, Loss: 34.5388
# Epoch 63/300, Loss: 34.5388
# Epoch 64/300, Loss: 34.5388
# Epoch 65/300, Loss: 34.5388
# Epoch 66/300, Loss: 34.5388
# Epoch 67/300, Loss: 34.5388
# Epoch 68/300, Loss: 34.5388
# Epoch 69/300, Loss: 34.5388
# Epoch 70/300, Loss: 34.5388
# Epoch 71/300, Loss: 34.5388
# Epoch 72/300, Loss: 34.5388
# Epoch 73/300, Loss: 34.5388
# Epoch 74/300, Loss: 34.5388
# Epoch 75/300, Loss: 34.5388
# Epoch 76/300, Loss: 34.5388
# Epoch 77/300, Loss: 34.5388
# Epoch 78/300, Loss: 34.5388
# Epoch 79/300, Loss: 34.5388
# Epoch 80/300, Loss: 34.5388
# Epoch 81/300, Loss: 34.5388
# Epoch 82/300, Loss: 34.5388
# Epoch 83/300, Loss: 34.5388
# Epoch 84/300, Loss: 34.5388
# Epoch 85/300, Loss: 34.5388
# Epoch 86/300, Loss: 34.5388
# Epoch 87/300, Loss: 34.5388
# Epoch 88/300, Loss: 34.5388
# Epoch 89/300, Loss: 34.5388
# Epoch 90/300, Loss: 34.5388
# Epoch 91/300, Loss: 34.5388
# Epoch 92/300, Loss: 34.5388
# Epoch 93/300, Loss: 34.5388
# Epoch 94/300, Loss: 34.5388
# Epoch 95/300, Loss: 34.5388
# Epoch 96/300, Loss: 34.5388
# Epoch 97/300, Loss: 34.5388
# Epoch 98/300, Loss: 34.5388
# Epoch 99/300, Loss: 34.5388
# Epoch 100/300, Loss: 34.5388
# Epoch 101/300, Loss: 34.5388
# Epoch 102/300, Loss: 34.5388
# Epoch 103/300, Loss: 34.5388
# Epoch 104/300, Loss: 34.5388
# Epoch 105/300, Loss: 34.5388
# Epoch 106/300, Loss: 34.5388
# Epoch 107/300, Loss: 34.5388
# Epoch 108/300, Loss: 34.5388
# Epoch 109/300, Loss: 34.5388
# Epoch 110/300, Loss: 34.5388
# Epoch 111/300, Loss: 34.5388
# Epoch 112/300, Loss: 34.5388
# Epoch 113/300, Loss: 34.5388
# Epoch 114/300, Loss: 34.5388
# Epoch 115/300, Loss: 34.5388
# Epoch 116/300, Loss: 34.5388
# Epoch 117/300, Loss: 34.5388
# Epoch 118/300, Loss: 34.5388
# Epoch 119/300, Loss: 34.5388
# Epoch 120/300, Loss: 34.5388
# Epoch 121/300, Loss: 34.5388
# Epoch 122/300, Loss: 34.5388
# Epoch 123/300, Loss: 34.5388
# Epoch 124/300, Loss: 34.5388
# Epoch 125/300, Loss: 34.5388
# Epoch 126/300, Loss: 34.5388
# Epoch 127/300, Loss: 34.5388
# Epoch 128/300, Loss: 34.5388
# Epoch 129/300, Loss: 34.5388
# Epoch 130/300, Loss: 34.5388
# Epoch 131/300, Loss: 34.5388
# Epoch 132/300, Loss: 34.5388
# Epoch 133/300, Loss: 34.5388
# Epoch 134/300, Loss: 34.5388
# Epoch 135/300, Loss: 34.5388
# Epoch 136/300, Loss: 34.5388
# Epoch 137/300, Loss: 34.5388
# Epoch 138/300, Loss: 34.5388
# Epoch 139/300, Loss: 34.5388
# Epoch 140/300, Loss: 34.5388
# Epoch 141/300, Loss: 34.5388
# Epoch 142/300, Loss: 34.5388
# Epoch 143/300, Loss: 34.5388
# Epoch 144/300, Loss: 34.5388
# Epoch 145/300, Loss: 34.5388
# Epoch 146/300, Loss: 34.5388
# Epoch 147/300, Loss: 34.5388
# Epoch 148/300, Loss: 34.5388
# Epoch 149/300, Loss: 34.5388
# Epoch 150/300, Loss: 34.5388
# Epoch 151/300, Loss: 34.5388
# Epoch 152/300, Loss: 34.5388
# Epoch 153/300, Loss: 34.5388
# Epoch 154/300, Loss: 34.5388
# Epoch 155/300, Loss: 34.5388
# Epoch 156/300, Loss: 34.5388
# Epoch 157/300, Loss: 34.5388
# Epoch 158/300, Loss: 34.5388
# Epoch 159/300, Loss: 34.5388
# Epoch 160/300, Loss: 34.5388
# Epoch 161/300, Loss: 34.5388
# Epoch 162/300, Loss: 34.5388
# Epoch 163/300, Loss: 34.5388
# Epoch 164/300, Loss: 34.5388
# Epoch 165/300, Loss: 34.5388
# Epoch 166/300, Loss: 34.5388
# Epoch 167/300, Loss: 34.5388
# Epoch 168/300, Loss: 34.5388
# Epoch 169/300, Loss: 34.5388
# Epoch 170/300, Loss: 34.5388
# Epoch 171/300, Loss: 34.5388
# Epoch 172/300, Loss: 34.5388
# Epoch 173/300, Loss: 34.5388
# Epoch 174/300, Loss: 34.5388
# Epoch 175/300, Loss: 34.5388
# Epoch 176/300, Loss: 34.5388
# Epoch 177/300, Loss: 34.5388
# Epoch 178/300, Loss: 34.5388
# Epoch 179/300, Loss: 34.5388
# Epoch 180/300, Loss: 34.5388
# Epoch 181/300, Loss: 34.5388
# Epoch 182/300, Loss: 34.5388
# Epoch 183/300, Loss: 34.5388
# Epoch 184/300, Loss: 34.5388
# Epoch 185/300, Loss: 34.5388
# Epoch 186/300, Loss: 34.5388
# Epoch 187/300, Loss: 34.5388
# Epoch 188/300, Loss: 34.5388
# Epoch 189/300, Loss: 34.5388
# Epoch 190/300, Loss: 34.5388
# Epoch 191/300, Loss: 34.5388
# Epoch 192/300, Loss: 34.5388
# Epoch 193/300, Loss: 34.5388
# Epoch 194/300, Loss: 34.5388
# Epoch 195/300, Loss: 34.5388
# Epoch 196/300, Loss: 34.5388
# Epoch 197/300, Loss: 34.5388
# Epoch 198/300, Loss: 34.5388
# Epoch 199/300, Loss: 34.5388
# Epoch 200/300, Loss: 34.5388
# Epoch 201/300, Loss: 34.5388
# Epoch 202/300, Loss: 34.5388
# Epoch 203/300, Loss: 34.5388
# Epoch 204/300, Loss: 34.5388
# Epoch 205/300, Loss: 34.5388
# Epoch 206/300, Loss: 34.5388
# Epoch 207/300, Loss: 34.5388
# Epoch 208/300, Loss: 34.5388
# Epoch 209/300, Loss: 34.5388
# Epoch 210/300, Loss: 34.5388
# Epoch 211/300, Loss: 34.5388
# Epoch 212/300, Loss: 34.5388
# Epoch 213/300, Loss: 34.5388
# Epoch 214/300, Loss: 34.5388
# Epoch 215/300, Loss: 34.5388
# Epoch 216/300, Loss: 34.5388
# Epoch 217/300, Loss: 34.5388
# Epoch 218/300, Loss: 34.5388
# Epoch 219/300, Loss: 34.5388
# Epoch 220/300, Loss: 34.5388
# Epoch 221/300, Loss: 34.5388
# Epoch 222/300, Loss: 34.5388
# Epoch 223/300, Loss: 34.5388
# Epoch 224/300, Loss: 34.5388
# Epoch 225/300, Loss: 34.5388
# Epoch 226/300, Loss: 34.5388
# Epoch 227/300, Loss: 34.5388
# Epoch 228/300, Loss: 34.5388
# Epoch 229/300, Loss: 34.5388
# Epoch 230/300, Loss: 34.5388
# Epoch 231/300, Loss: 34.5388
# Epoch 232/300, Loss: 34.5388
# Epoch 233/300, Loss: 34.5388
# Epoch 234/300, Loss: 34.5388
# Epoch 235/300, Loss: 34.5388
# Epoch 236/300, Loss: 34.5388
# Epoch 237/300, Loss: 34.5388
# Epoch 238/300, Loss: 34.5388
# Epoch 239/300, Loss: 34.5388
# Epoch 240/300, Loss: 34.5388
# Epoch 241/300, Loss: 34.5388
# Epoch 242/300, Loss: 34.5388
# Epoch 243/300, Loss: 34.5388
# Epoch 244/300, Loss: 34.5388
# Epoch 245/300, Loss: 34.5388
# Epoch 246/300, Loss: 34.5388
# Epoch 247/300, Loss: 34.5388
# Epoch 248/300, Loss: 34.5388
# Epoch 249/300, Loss: 34.5388
# Epoch 250/300, Loss: 34.5388
# Epoch 251/300, Loss: 34.5388
# Epoch 252/300, Loss: 34.5388
# Epoch 253/300, Loss: 34.5388
# Epoch 254/300, Loss: 34.5388
# Epoch 255/300, Loss: 34.5388
# Epoch 256/300, Loss: 34.5388
# Epoch 257/300, Loss: 34.5388
# Epoch 258/300, Loss: 34.5388
# Epoch 259/300, Loss: 34.5388
# Epoch 260/300, Loss: 34.5388
# Epoch 261/300, Loss: 34.5388
# Epoch 262/300, Loss: 34.5388
# Epoch 263/300, Loss: 34.5388
# Epoch 264/300, Loss: 34.5388
# Epoch 265/300, Loss: 34.5388
# Epoch 266/300, Loss: 34.5388
# Epoch 267/300, Loss: 34.5388
# Epoch 268/300, Loss: 34.5388
# Epoch 269/300, Loss: 34.5388
# Epoch 270/300, Loss: 34.5388
# Epoch 271/300, Loss: 34.5388
# Epoch 272/300, Loss: 34.5388
# Epoch 273/300, Loss: 34.5388
# Epoch 274/300, Loss: 34.5388
# Epoch 275/300, Loss: 34.5388
# Epoch 276/300, Loss: 34.5388
# Epoch 277/300, Loss: 34.5388
# Epoch 278/300, Loss: 34.5388
# Epoch 279/300, Loss: 34.5388
# Epoch 280/300, Loss: 34.5388
# Epoch 281/300, Loss: 34.5388
# Epoch 282/300, Loss: 34.5388
# Epoch 283/300, Loss: 34.5388
# Epoch 284/300, Loss: 34.5388
# Epoch 285/300, Loss: 34.5388
# Epoch 286/300, Loss: 34.5388
# Epoch 287/300, Loss: 34.5388
# Epoch 288/300, Loss: 34.5388
# Epoch 289/300, Loss: 34.5388
# Epoch 290/300, Loss: 34.5388
# Epoch 291/300, Loss: 34.5388
# Epoch 292/300, Loss: 34.5388
# Epoch 293/300, Loss: 34.5388
# Epoch 294/300, Loss: 34.5388
# Epoch 295/300, Loss: 34.5388
# Epoch 296/300, Loss: 34.5388
# Epoch 297/300, Loss: 34.5388
# Epoch 298/300, Loss: 34.5388
# Epoch 299/300, Loss: 34.5388
# Epoch 300/300, Loss: 34.5388

# %%
# Predict
output_predict = []
for i in range(len(X_test_embedding_r)):
    output_predict.append(model_bilstm_embedsize_50.predict(np.array([X_test_embedding_r[i]])))

# %%
output_predict
# Out:
# [array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64),
#  array([0], dtype=int64)]

# %% [markdown]
# <h2>Pengujian Performansi</h2>

# %% [markdown]
# <h3>Bi-LSTM Without SMOTE</h3>

# %%
df_result_WS = pd.DataFrame.from_records(output_predict, columns=['Predict'])

# %%
df_result_WS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Predict  394 non-null    int64
# dtypes: int64(1)
# memory usage: 3.2 KB

# %%
output_actual_WS = []

for i in y_test:
    output_actual_WS.append(i)

# %%
df_actual_WS = pd.DataFrame(output_actual_WS, columns=['Actual'])

# %%
df_final_result_WS = df_result_WS.join(df_actual_WS)

# %%
df_final_result_WS.head()
# Out:
#    Predict  Actual
# 0        0       0
# 1        0       1
# 2        0       0
# 3        0       1
# 4        0       1

# %%
for i in range(len(df_final_result_WS)):
  if (df_final_result_WS.iloc[i]['Predict'] == 1 and df_final_result_WS.iloc[i]['Actual'] == 1):
    df_final_result_WS.loc[i, 'Category'] = 'TP'
  elif (df_final_result_WS.iloc[i]['Predict'] == 0 and df_final_result_WS.iloc[i]['Actual'] == 0):
    df_final_result_WS.loc[i, 'Category'] = 'TN'
  elif (df_final_result_WS.iloc[i]['Predict'] == 1 and df_final_result_WS.iloc[i]['Actual'] == 0):
    df_final_result_WS.loc[i, 'Category'] = 'FP'
  elif (df_final_result_WS.iloc[i]['Predict'] == 0 and df_final_result_WS.iloc[i]['Actual'] == 1):
    df_final_result_WS.loc[i, 'Category'] = 'FN'

# %%
TP_WS = len(df_final_result_WS[df_final_result_WS['Category']=='TP'])
TN_WS = len(df_final_result_WS[df_final_result_WS['Category']=='TN'])
FP_WS = len(df_final_result_WS[df_final_result_WS['Category']=='FP'])
FN_WS = len(df_final_result_WS[df_final_result_WS['Category']=='FN'])

accuracy_WS = round((TP_WS + TN_WS) / (TP_WS + TN_WS + FP_WS + FN_WS), 2) * 100
precision_WS = 0 if TP_WS == 0 or FP_WS == 0 else round(TP_WS / (TP_WS + FP_WS), 2) * 100
recall_WS = round(TP_WS / (TP_WS + FN_WS), 2) * 100
f_measure_WS = 0 if precision_WS == 0 else round(2 * precision_WS * recall_WS / (precision_WS + recall_WS), 2)

# %%
print(f'TP Bi-LSTM Scratch: {TP_WS}\n')
print(f'TN Bi-LSTM Scratch: {TN_WS}\n')
print(f'FP Bi-LSTM Scratch: {FP_WS}\n')
print(f'FN Bi-LSTM Scratch: {FN_WS}\n')
# Out:
# TP Bi-LSTM Scratch: 0
#
# TN Bi-LSTM Scratch: 209
#
# FP Bi-LSTM Scratch: 0
#
# FN Bi-LSTM Scratch: 185

# %%
print(f'Accuracy: {accuracy_WS}%')
print(f'Precision: {precision_WS}%')
print(f'Recall: {recall_WS}%')
print(f'F1-Score: {f_measure_WS}%')
# Out:
# Accuracy: 53.0%
# Precision: 0%
# Recall: 0.0%
# F1-Score: 0%

# %% [markdown]
# <h3>Bi-LSTM + SMOTE</h3>

# %%
df_result = pd.DataFrame.from_records(output_predict, columns=['Predict'])

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Predict  394 non-null    int64
# dtypes: int64(1)
# memory usage: 3.2 KB

# %%
output_actual = []

for i in y_test:
    output_actual.append(i)

# %%
df_actual = pd.DataFrame(output_actual, columns=['Actual'])

# %%
df_final_result = df_result.join(df_actual)

# %%
df_final_result.head(11)
# Out:
#     Predict  Actual
# 0         0       0
# 1         0       1
# 2         0       0
# 3         0       1
# 4         0       1
# 5         0       1
# 6         0       0
# 7         1       1
# 8         1       0
# 9         1       0
# 10        1       1

# %%
for i in range(len(df_final_result)):
  if (df_final_result.iloc[i]['Predict'] == 1 and df_final_result.iloc[i]['Actual'] == 1):
    df_final_result.loc[i, 'Category'] = 'TP'
  elif (df_final_result.iloc[i]['Predict'] == 0 and df_final_result.iloc[i]['Actual'] == 0):
    df_final_result.loc[i, 'Category'] = 'TN'
  elif (df_final_result.iloc[i]['Predict'] == 1 and df_final_result.iloc[i]['Actual'] == 0):
    df_final_result.loc[i, 'Category'] = 'FP'
  elif (df_final_result.iloc[i]['Predict'] == 0 and df_final_result.iloc[i]['Actual'] == 1):
    df_final_result.loc[i, 'Category'] = 'FN'

# %%
TP = len(df_final_result[df_final_result['Category']=='TP'])
TN = len(df_final_result[df_final_result['Category']=='TN'])
FP = len(df_final_result[df_final_result['Category']=='FP'])
FN = len(df_final_result[df_final_result['Category']=='FN'])

accuracy = round((TP + TN) / (TP + TN + FP + FN), 2) * 100
precision = round(TP / (TP + FP), 2) * 100
recall = round(TP / (TP + FN), 2) * 100
f_measure = round(2 * precision * recall / (precision + recall), 2)

# %%
print(f'TP Bi-LSTM Scratch: {TP}\n')
print(f'TN Bi-LSTM Scratch: {TN}\n')
print(f'FP Bi-LSTM Scratch: {FP}\n')
print(f'FN Bi-LSTM Scratch: {FN}\n')
# Out:
# TP Bi-LSTM Scratch: 135
#
# TN Bi-LSTM Scratch: 118
#
# FP Bi-LSTM Scratch: 91
#
# FN Bi-LSTM Scratch: 50

# %%
print(f'Accuracy: {accuracy}%')
print(f'Precision: {precision}%')
print(f'Recall: {recall}%')
print(f'F1-Score: {f_measure}%')
# Out:
# Accuracy: 64.0%
# Precision: 60.0%
# Recall: 73.0%
# F1-Score: 65.86%

# %% [markdown]
# <h1>Saving Model</h1>

# %%
# import h5py

# # Nama file .h5 untuk menyimpan model
# filename = 'modelBiLSTM_Scratch.h5'

# # Membuka file .h5 untuk penulisan
# with h5py.File(filename, 'w') as hf:
#     # Simpan parameter-parameter objek Bi-LSTM ke dalam grup 'bilstm'
#     bilstm_group = hf.create_group('bilstm')
    
#     bilstm_group.create_dataset('W_i', data=model_bilstm_embedsize_50.W_i)
#     bilstm_group.create_dataset('U_i', data=model_bilstm_embedsize_50.U_i)
#     bilstm_group.create_dataset('b_i', data=model_bilstm_embedsize_50.b_i)

#     bilstm_group.create_dataset('W_i', data=model_bilstm_embedsize_50.W_i)
#     bilstm_group.create_dataset('U_i', data=model_bilstm_embedsize_50.U_i)
#     bilstm_group.create_dataset('b_i', data=model_bilstm_embedsize_50.b_i)
    
#     # Simpan parameter-parameter lainnya ...
    
# print(f'Model disimpan dalam file {filename}')

# %% [markdown]
# <h3>Testing Result</h3>
# <p>July 20 : 50%</p>
# <p>July 21 : 53%</p>
# <p>July 22 : 54%</p>
# <p>July 25 : 61%</p>
# <p>August 2 : 66%</p>

# %% [markdown]
# <h1>Sample Datasets BAB 3</h1>

# %%
df_bab3 = pd.read_excel('Misc/Sample_Datasets_Bab3_Ready.xlsx')
df_bab3.info()
df_bab3.head()

# %%
# Remove unused column/feature
df_bab3 = df_bab3.drop(columns='Unnamed: 0')
df_bab3 = df_bab3.drop(columns='Text')
df_bab3 = df_bab3.drop(columns='emoji')
df_bab3 = df_bab3.drop(columns='Tokenized')
df_bab3 = df_bab3.drop(columns='final_text')
df_bab3 = df_bab3.drop(columns='Pos_Word')
df_bab3 = df_bab3.drop(columns='Neg_Word')
df_bab3 = df_bab3.drop(columns='Total_Word')
df_bab3 = df_bab3.drop(columns='Pos_Ratio')
df_bab3 = df_bab3.drop(columns='Neg_Ratio')
df_bab3 = df_bab3.drop(columns='Tokenize_Emoji')
df_bab3 = df_bab3.drop(columns='Pos_Emoji')
df_bab3 = df_bab3.drop(columns='Neg_Emoji')
df_bab3 = df_bab3.drop(columns='Sentimen_Emoji')

# %%
df_bab3['Sarcasm'].value_counts()

# %%
df_bab3['text_emoji'][0]

# %% [markdown]
# <h2>Word Embedding</h2>

# %%
# Membangun model GloVe
glove_model = GloVe(df_bab3['text_emoji'])

# Membangun vocabulary
glove_model.build_vocab_information()

# Membangun co-occurrence matrix
glove_model.build_co_matrix()

# Melatih model GloVe
glove_model.train()

# %%
for word, id in glove_model.word2count.items():
    print(f'{word}: {id}')

# %%
# glove_model.generate_coomatrix_image()

# %%
glove_model.get_all_embeddings()

# %% [markdown]
# <h2>SMOTE</h2>

# %%
df_bab3['Sentimen_Text'] = df_bab3['Sentimen_Text'].replace('Positif', 1)
df_bab3['Sentimen_Text'] = df_bab3['Sentimen_Text'].replace('Negatif', 0)

df_bab3['Sarcasm'] = df_bab3['Sarcasm'].replace('Positif', 1)
df_bab3['Sarcasm'] = df_bab3['Sarcasm'].replace('Negatif', 0)

# %%
# Cek class minoritas
df_bab3['Sarcasm'].value_counts()

# %%
max_len = 50
len_voc = 40000

from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_bab3, test_size=0.3, random_state=42, shuffle=False)

df_train_min = df_train[df_train['Sarcasm'] == 0]
df_train_maj = df_train[df_train['Sarcasm'] == 1]

df_test_min = df_test[df_test['Sarcasm'] == 0]
df_test_maj = df_test[df_test['Sarcasm'] == 1]

df_ready_min = pd.concat([df_train_min, df_test_min])
df_ready_maj = pd.concat([df_train_maj, df_test_maj])

# %%
# Tokenizer
tokenizer_min = make_tokenizer(df_ready_min['text_emoji'], len_voc)
tokenizer_maj = make_tokenizer(df_ready_maj['text_emoji'], len_voc)

# %%
# Sequence
X_train_min = tokenizer_min.texts_to_sequences(df_train_min['text_emoji'])
X_test_min = tokenizer_min.texts_to_sequences(df_test_min['text_emoji'])
X_train_major = tokenizer_maj.texts_to_sequences(df_train_maj['text_emoji'])
X_test_major = tokenizer_maj.texts_to_sequences(df_test_maj['text_emoji'])

# %%
df_train_min

# %%
X_train_min

# %%
# Padding
from keras.utils import pad_sequences

X_train_min = pad_sequences(X_train_min, maxlen=max_len, padding='post', truncating='post')
X_test_min = pad_sequences(X_test_min, maxlen=max_len, padding='post', truncating='post')
X_train_major = pad_sequences(X_train_major, maxlen=max_len, padding='post', truncating='post')
X_test_major = pad_sequences(X_test_major, maxlen=max_len, padding='post', truncating='post')

# %%
# Stacking Label Minority
y_train_min = df_train_min['Sarcasm'].values
y_test_min = df_test_min['Sarcasm'].values

stack_label_min = np.hstack((y_train_min, y_test_min))

stack_label_min.shape

# %%
# Stacking Label Majority
y_train_maj = df_train_maj['Sarcasm'].values
y_test_maj = df_test_maj['Sarcasm'].values

stack_label_maj = np.hstack((y_train_maj, y_test_maj))

stack_label_maj.shape

# %%
# Stacking All Data Minority & Majority
embed_mat_min = make_embedding_matrix(glove, tokenizer_min, len_voc)
embed_mat_maj = make_embedding_matrix(glove, tokenizer_maj, len_voc)

X_train_emb_minority = embed_mat_min[X_train_min]
X_test_emb_minority = embed_mat_min[X_test_min]

X_train_emb_majority = embed_mat_maj[X_train_major]
X_test_emb_majority = embed_mat_maj[X_test_major]

train_size_min, max_len_min, embed_size_min = X_train_emb_minority.shape
X_train_emb_r_min = X_train_emb_minority.reshape(train_size_min, max_len*embed_size_min)

test_size_min, max_len_min, embed_size_min = X_test_emb_minority.shape
X_test_emb_r_min = X_test_emb_minority.reshape(test_size_min, max_len*embed_size_min)

train_size_maj, max_len_maj, embed_size_maj = X_train_emb_majority.shape
X_train_emb_r_maj = X_train_emb_majority.reshape(train_size_maj, max_len*embed_size_maj)

test_size_maj, max_len_maj, embed_size_maj = X_test_emb_majority.shape
X_test_emb_r_maj = X_test_emb_majority.reshape(test_size_maj, max_len*embed_size_maj)

stack_minority = np.vstack((X_train_emb_r_min, X_test_emb_r_min))

stack_majority = np.vstack((X_train_emb_r_maj, X_test_emb_r_maj))

# %%
X_train_emb_minority[1]

# %%
print(f'Shape stack minority: {stack_minority.shape}')
print(f'Shape stack majority{stack_majority.shape}')

# %%
# Running SMOTE
total_size = train_size_maj + train_size_min + test_size_maj + test_size_min

X_minority = stack_minority
y_minority = stack_label_min
X_majority = stack_majority
y_majority = stack_label_maj

X_oversampled, y_oversampled = smote(X_minority, X_majority, y_minority, k=3)

# %%
final_stack = np.vstack((stack_majority, X_oversampled))

len(final_stack)

# %%
final_stack = np.delete(final_stack, np.s_[10::], axis=0)

# %%
final_stack_label = np.hstack((stack_label_maj, y_oversampled))

final_stack_label = np.delete(final_stack_label, np.s_[10::], axis=0)

# %%
print(f'Shape : {final_stack.shape}\n')
print(final_stack)

# %%
import matplotlib.pyplot as plt

x = ['Sebelum', 'Sesudah']
y = [len(stack_majority) + len(stack_minority), len(final_stack)]


plt.bar(x, y, color=[(0.38, 0.62, 0.79), (0.98, 0.64, 0.33)], edgecolor='black', linewidth=1.5)

for i in range(len(x)):
    plt.text(x[i], y[i], str(y[i]), ha='center', va='bottom')

plt.ylabel('Jumlah Sample')
plt.title('Perbandingan Data Setelah Diimplementasi SMOTE')

plt.show()

# %%
x = ['0', '1']
y = [df_bab3['Sarcasm'].value_counts()[0], df_bab3['Sarcasm'].value_counts()[1]]


plt.bar(x, y, color=[(0.38, 0.62, 0.79), (0.98, 0.64, 0.33)], edgecolor='black', linewidth=1.5)

for i in range(len(x)):
    plt.text(x[i], y[i], str(y[i]), ha='center', va='bottom')

plt.ylabel('Jumlah Sample')
plt.title('Jumlah Sample Masing-Masing Kelas Sebelum Di Implementasi SMOTE')

plt.show()

# %%
# Menghitung Jumlah Akhir Sample pada Class 0 dan 1
unique, counts = np.unique(final_stack_label, return_counts=True)
result = np.asarray((unique, counts)).T.astype(int)

print(result)

# %%
x = ['0', '1']
y = [result[0][1], result[1][1]]


plt.bar(x, y, color=[(0.38, 0.62, 0.79), (0.98, 0.64, 0.33)], edgecolor='black', linewidth=1.5)

for i in range(len(x)):
    plt.text(x[i], y[i], str(y[i]), ha='center', va='bottom')

plt.ylabel('Jumlah Sample')
plt.title('Jumlah Sample Masing-Masing Kelas Setelah Di Implementasi SMOTE')

plt.show()

# %% [markdown]
# <h2>Bi-LSTM</h2>

# %%
x_train = final_stack
x_train = np.array(x_train)
label = final_stack_label.astype('int')
y_train = label

# Inisialisasi model Bi-LSTM
input_size = x_train.shape[1]
hidden_size = 8
output_size = 2
bilstm = BiLSTM(input_size, hidden_size, output_size)

# %%
x_train

# %%
# Train ML Model
epochs = 100
learning_rate = 0.01
bilstm.train(x_train, y_train, epochs, learning_rate)

# %%
y_train

# %%
x_train[9]

# %%
# Predict ML Model
print(f'Predict Data 1 : {bilstm.predict(np.array([x_train[0]]))}\n')
print(f'Predict Data 2 : {bilstm.predict(np.array([x_train[1]]))}\n')
print(f'Predict Data 3 : {bilstm.predict(np.array([x_train[2]]))}\n')
print(f'Predict Data 4 : {bilstm.predict(np.array([x_train[3]]))}\n')
print(f'Predict Data 5 : {bilstm.predict(np.array([x_train[4]]))}\n')
print(f'Predict Data 6 : {bilstm.predict(np.array([x_train[5]]))}\n')
print(f'Predict Data 7 : {bilstm.predict(np.array([x_train[6]]))}\n')
print(f'Predict Data 8 : {bilstm.predict(np.array([x_train[7]]))}\n')
print(f'Predict Data 9 : {bilstm.predict(np.array([x_train[8]]))}\n')
print(f'Predict Data 10 : {bilstm.predict(np.array([x_train[9]]))}\n')
